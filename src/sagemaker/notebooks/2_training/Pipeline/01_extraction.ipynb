# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Pre-procesamiento de DAiSEE (Engagement) con EfficientNet-B0 + TensorFlow 2.x
Autor: (tu nombre)
"""

from utils.extraction import *
import os, cv2, glob
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel("ERROR")
# Out:
# 2025-05-12 20:10:50.390060: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747098650.415022  410401 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747098650.422066  410401 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747098650.440267  410401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747098650.441034  410401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747098650.441037  410401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747098650.441039  410401 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-12 20:10:50.446834: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# ---------- 1.  Carga de EfficientNet solo una vez ------------------------
base_model = tf.keras.applications.EfficientNetB0(
    include_top=False, pooling="avg", weights="imagenet", input_shape=TARGET_SIZE + (3,)
)
preprocess = tf.keras.applications.efficientnet.preprocess_input

# ---------- 2.  Utilidades -------------------------------------------------
def sample_frame_indices(num_total, num_needed):
    """Devuelve índices equiespaciados (redondeados)"""
    if num_total <= num_needed:
        return list(range(num_total))  # no subsampling
    step = num_total / num_needed
    return [int(step * i) for i in range(num_needed)]

def load_and_preprocess_frames(video_path, num_frames=NUM_FRAMES):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise IOError(f"Imposible abrir {video_path}")

    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    idxs  = sample_frame_indices(total, num_frames)
    frames = []

    for i in range(total):
        ret, frame = cap.read()
        if not ret: break
        if i in idxs:
            # BGR → RGB
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            # Resize manteniendo aspecto (letterbox + crop/resize rápido)
            frame = tf.image.resize(frame, TARGET_SIZE, method="bilinear").numpy()
            frames.append(frame)
    cap.release()

    if len(frames) < num_frames:   # padding si un vídeo es muy corto
        pad = np.repeat(frames[-1][None, ...], num_frames - len(frames), axis=0)
        frames = np.concatenate([np.asarray(frames), pad], axis=0)
    else:
        frames = np.asarray(frames[:num_frames])

    frames = preprocess(frames.astype("float32"))
    return frames  # shape: (num_frames, H, W, 3)

def extract_features(frames):
    # Procesamos de golpe para velocidad (GPU friendly)
    feats = base_model.predict(frames, verbose=0)
    return feats.astype(FEATURE_DTYPE)  # shape: (num_frames, feat_dim)

def ensure_dir(path):
    os.makedirs(os.path.dirname(path), exist_ok=True)

# ---------- 3.  Bucle principal de extracción -----------------------------
for split in SPLITS:
    print(f"\n=== Procesando split: {split} ===")
    for cls in CLASSES:
        pattern = os.path.join(ROOT_DIR, cls, split, "*.[aA][vV][iI]")
        pattern_mp4 = os.path.join(ROOT_DIR, cls, split, "*.[mM][pP]4")
        video_files = glob.glob(pattern) + glob.glob(pattern_mp4)

        for vid in video_files:
            rel   = os.path.relpath(vid, ROOT_DIR)
            feat_path = os.path.join(OUTPUT_FEATURES, os.path.splitext(rel)[0] + ".npy")
            if os.path.exists(feat_path):   # omitir si ya se procesó
                continue

            try:
                frames  = load_and_preprocess_frames(vid)
                feats   = extract_features(frames)  # (NUM_FRAMES, 1280)
                ensure_dir(feat_path)
                np.save(feat_path, feats)
                print(f"✓ {rel} -> {feat_path}")
            except Exception as e:
                print(f"✗ {rel} -> error: {e}")
# Out:
# ✓ 2/test/2100511059.avi -> ../../DAiSEE/features/2/test/2100511059.npy
# ✓ 2/test/3100771071.avi -> ../../DAiSEE/features/2/test/3100771071.npy
# ✓ 2/test/4100251011.avi -> ../../DAiSEE/features/2/test/4100251011.npy
# ✓ 2/test/3100752057.avi -> ../../DAiSEE/features/2/test/3100752057.npy
# ✓ 2/test/5100422058.avi -> ../../DAiSEE/features/2/test/5100422058.npy
# ✓ 2/test/3422270153.avi -> ../../DAiSEE/features/2/test/3422270153.npy
# ✓ 2/test/2100561079.avi -> ../../DAiSEE/features/2/test/2100561079.npy
# ✓ 2/test/4100322041.avi -> ../../DAiSEE/features/2/test/4100322041.npy
# ✓ 2/test/2100521013.avi -> ../../DAiSEE/features/2/test/2100521013.npy
# ✓ 2/test/240846023.avi -> ../../DAiSEE/features/2/test/240846023.npy
# ✓ 2/test/1100171002.avi -> ../../DAiSEE/features/2/test/1100171002.npy
# ✓ 2/test/3100822059.avi -> ../../DAiSEE/features/2/test/3100822059.npy
# ✓ 2/test/2100571057.avi -> ../../DAiSEE/features/2/test/2100571057.npy
# ✓ 2/test/4000231010.avi -> ../../DAiSEE/features/2/test/4000231010.npy
# ✓ 2/test/2000542007.avi -> ../../DAiSEE/features/2/test/2000542007.npy
# ✓ 2/test/2100601075.avi -> ../../DAiSEE/features/2/test/2100601075.npy
# ✓ 2/test/5000671029.avi -> ../../DAiSEE/features/2/test/5000671029.npy
# ✓ 2/test/5100462082.avi -> ../../DAiSEE/features/2/test/5100462082.npy
# ✓ 2/test/4100201026.avi -> ../../DAiSEE/features/2/test/4100201026.npy
# ✓ 2/test/3100642003.avi -> ../../DAiSEE/features/2/test/3100642003.npy
# ✓ 2/test/3100721011.avi -> ../../DAiSEE/features/2/test/3100721011.npy
# ✓ 2/test/1813740119.avi -> ../../DAiSEE/features/2/test/1813740119.npy
# ✓ 2/test/9403280236.avi -> ../../DAiSEE/features/2/test/9403280236.npy
# ✓ 2/test/4000332046.avi -> ../../DAiSEE/features/2/test/4000332046.npy
# ✓ 2/test/3100751058.avi -> ../../DAiSEE/features/2/test/3100751058.npy
# ✓ 2/test/2100522062.avi -> ../../DAiSEE/features/2/test/2100522062.npy
# ✓ 2/test/3100762053.avi -> ../../DAiSEE/features/2/test/3100762053.npy
# ✓ 2/test/4100302024.avi -> ../../DAiSEE/features/2/test/4100302024.npy
# ✓ 2/test/1100021015.avi -> ../../DAiSEE/features/2/test/1100021015.npy
# ✓ 2/test/5000431025.avi -> ../../DAiSEE/features/2/test/5000431025.npy
# ✓ 2/test/4100292043.avi -> ../../DAiSEE/features/2/test/4100292043.npy
# ✓ 2/test/4000221035.avi -> ../../DAiSEE/features/2/test/4000221035.npy
# ✓ 2/test/2100522042.avi -> ../../DAiSEE/features/2/test/2100522042.npy
# ✓ 2/test/3100792021.avi -> ../../DAiSEE/features/2/test/3100792021.npy
# ✓ 2/test/5100091051.avi -> ../../DAiSEE/features/2/test/5100091051.npy
# ✓ 2/test/2100531061.avi -> ../../DAiSEE/features/2/test/2100531061.npy
# ✓ 2/test/2100521050.avi -> ../../DAiSEE/features/2/test/2100521050.npy
# ✓ 2/test/4000332052.avi -> ../../DAiSEE/features/2/test/4000332052.npy
# ✓ 2/test/2056010261.avi -> ../../DAiSEE/features/2/test/2056010261.npy
# ✓ 2/test/3100782069.avi -> ../../DAiSEE/features/2/test/3100782069.npy
# ✓ 2/test/5100382007.avi -> ../../DAiSEE/features/2/test/5100382007.npy
# ✓ 2/test/5100461010.avi -> ../../DAiSEE/features/2/test/5100461010.npy
# ✓ 2/test/4000331058.avi -> ../../DAiSEE/features/2/test/4000331058.npy
# ✓ 2/test/4100262038.avi -> ../../DAiSEE/features/2/test/4100262038.npy
# ✓ 2/test/4000332038.avi -> ../../DAiSEE/features/2/test/4000332038.npy
# ✓ 2/test/2260510162.avi -> ../../DAiSEE/features/2/test/2260510162.npy
# ✓ 2/test/4110311019.avi -> ../../DAiSEE/features/2/test/4110311019.npy
# ✓ 2/test/1100071041.avi -> ../../DAiSEE/features/2/test/1100071041.npy
# ✓ 2/test/4140810257.avi -> ../../DAiSEE/features/2/test/4140810257.npy
# ✓ 2/test/5000392071.avi -> ../../DAiSEE/features/2/test/5000392071.npy
# ✓ 2/test/9403280157.avi -> ../../DAiSEE/features/2/test/9403280157.npy
# ✓ 2/test/3100751015.avi -> ../../DAiSEE/features/2/test/3100751015.npy
# ✓ 2/test/2100522064.avi -> ../../DAiSEE/features/2/test/2100522064.npy
# ✓ 2/test/2100611031.avi -> ../../DAiSEE/features/2/test/2100611031.npy
# ✓ 2/test/4100241042.avi -> ../../DAiSEE/features/2/test/4100241042.npy
# ✓ 2/test/2100511035.avi -> ../../DAiSEE/features/2/test/2100511035.npy
# ✓ 2/test/5000441069.avi -> ../../DAiSEE/features/2/test/5000441069.npy
# ✓ 2/test/3100641008.avi -> ../../DAiSEE/features/2/test/3100641008.npy
# ✓ 2/test/2056010137.avi -> ../../DAiSEE/features/2/test/2056010137.npy
# ✓ 2/test/5100401033.avi -> ../../DAiSEE/features/2/test/5100401033.npy
# ✓ 2/test/2056010113.avi -> ../../DAiSEE/features/2/test/2056010113.npy
# ✓ 2/test/1100142059.avi -> ../../DAiSEE/features/2/test/1100142059.npy
# ✓ 2/test/5000392025.avi -> ../../DAiSEE/features/2/test/5000392025.npy
# ✓ 2/test/5100341022.avi -> ../../DAiSEE/features/2/test/5100341022.npy
# ✓ 2/test/2100611045.avi -> ../../DAiSEE/features/2/test/2100611045.npy
# ✓ 2/test/1100142017.avi -> ../../DAiSEE/features/2/test/1100142017.npy
# ✓ 2/test/3100821021.avi -> ../../DAiSEE/features/2/test/3100821021.npy
# ✓ 2/test/5100421061.avi -> ../../DAiSEE/features/2/test/5100421061.npy
# ✓ 2/test/3100831036.avi -> ../../DAiSEE/features/2/test/3100831036.npy
# ✓ 2/test/1100041023.avi -> ../../DAiSEE/features/2/test/1100041023.npy
# ✓ 2/test/3100751028.avi -> ../../DAiSEE/features/2/test/3100751028.npy
# ✓ 2/test/4110212041.avi -> ../../DAiSEE/features/2/test/4110212041.npy
# ✓ 2/test/3100811042.avi -> ../../DAiSEE/features/2/test/3100811042.npy
# ✓ 2/test/3100771022.avi -> ../../DAiSEE/features/2/test/3100771022.npy
# ✓ 2/test/8264120159.avi -> ../../DAiSEE/features/2/test/8264120159.npy
# ✓ 2/test/5100351020.avi -> ../../DAiSEE/features/2/test/5100351020.npy
# ✓ 2/test/3100662053.avi -> ../../DAiSEE/features/2/test/3100662053.npy
# ✓ 2/test/5100462057.avi -> ../../DAiSEE/features/2/test/5100462057.npy
# ✓ 2/test/5000442056.avi -> ../../DAiSEE/features/2/test/5000442056.npy
# ✓ 2/test/5100462038.avi -> ../../DAiSEE/features/2/test/5100462038.npy
# ✓ 2/test/2100601054.avi -> ../../DAiSEE/features/2/test/2100601054.npy
# ✓ 2/test/2100601027.avi -> ../../DAiSEE/features/2/test/2100601027.npy
# ✓ 2/test/4100252010.avi -> ../../DAiSEE/features/2/test/4100252010.npy
# ✓ 2/test/4100281030.avi -> ../../DAiSEE/features/2/test/4100281030.npy
# ✓ 2/test/1100411049.avi -> ../../DAiSEE/features/2/test/1100411049.npy
# ✓ 2/test/3503610133.avi -> ../../DAiSEE/features/2/test/3503610133.npy
# ✓ 2/test/2100511036.avi -> ../../DAiSEE/features/2/test/2100511036.npy
# ✓ 2/test/2100522028.avi -> ../../DAiSEE/features/2/test/2100522028.npy
# ✓ 2/test/1100111032.avi -> ../../DAiSEE/features/2/test/1100111032.npy
# ✓ 2/test/5100091006.avi -> ../../DAiSEE/features/2/test/5100091006.npy
# ✓ 2/test/4000222013.avi -> ../../DAiSEE/features/2/test/4000222013.npy
# ✓ 2/test/5100422014.avi -> ../../DAiSEE/features/2/test/5100422014.npy
# ✓ 2/test/5100091017.avi -> ../../DAiSEE/features/2/test/5100091017.npy
# ✓ 2/test/2000541054.avi -> ../../DAiSEE/features/2/test/2000541054.npy
# ✓ 2/test/4100202040.avi -> ../../DAiSEE/features/2/test/4100202040.npy
# ✓ 2/test/5100421041.avi -> ../../DAiSEE/features/2/test/5100421041.npy
# ✓ 2/test/2100591017.avi -> ../../DAiSEE/features/2/test/2100591017.npy
# ✓ 2/test/1100072079.avi -> ../../DAiSEE/features/2/test/1100072079.npy
# ✓ 2/test/4100291014.avi -> ../../DAiSEE/features/2/test/4100291014.npy
# ✓ 2/test/5100381038.avi -> ../../DAiSEE/features/2/test/5100381038.npy
# ✓ 2/test/2100611067.avi -> ../../DAiSEE/features/2/test/2100611067.npy
# ✓ 2/test/1100141020.avi -> ../../DAiSEE/features/2/test/1100141020.npy
# ✓ 2/test/4110312008.avi -> ../../DAiSEE/features/2/test/4110312008.npy
# ✓ 2/test/3100632012.avi -> ../../DAiSEE/features/2/test/3100632012.npy
# ✓ 2/test/5000391038.avi -> ../../DAiSEE/features/2/test/5000391038.npy
# ✓ 2/test/1100051076.avi -> ../../DAiSEE/features/2/test/1100051076.npy
# ✓ 2/test/2100581071.avi -> ../../DAiSEE/features/2/test/2100581071.npy
# ✓ 2/test/5100352042.avi -> ../../DAiSEE/features/2/test/5100352042.npy
# ✓ 2/test/2100571015.avi -> ../../DAiSEE/features/2/test/2100571015.npy
# ✓ 2/test/3100771062.avi -> ../../DAiSEE/features/2/test/3100771062.npy
# ✓ 2/test/3100642006.avi -> ../../DAiSEE/features/2/test/3100642006.npy
# ✓ 2/test/2100611047.avi -> ../../DAiSEE/features/2/test/2100611047.npy
# ✓ 2/test/5100422018.avi -> ../../DAiSEE/features/2/test/5100422018.npy
# ✓ 2/test/7698620131.avi -> ../../DAiSEE/features/2/test/7698620131.npy
# ✓ 2/test/8264120223.avi -> ../../DAiSEE/features/2/test/8264120223.npy
# ✓ 2/test/2000502062.avi -> ../../DAiSEE/features/2/test/2000502062.npy
# ✓ 2/test/1100152015.avi -> ../../DAiSEE/features/2/test/1100152015.npy
# ✓ 2/test/5100352032.avi -> ../../DAiSEE/features/2/test/5100352032.npy
# ✓ 2/test/4100251003.avi -> ../../DAiSEE/features/2/test/4100251003.npy
# ✓ 2/test/826412019.avi -> ../../DAiSEE/features/2/test/826412019.npy
# ✓ 2/test/2100522060.avi -> ../../DAiSEE/features/2/test/2100522060.npy
# ✓ 2/test/2100571069.avi -> ../../DAiSEE/features/2/test/2100571069.npy
# ✓ 2/test/5100421011.avi -> ../../DAiSEE/features/2/test/5100421011.npy
# ✓ 2/test/4000232054.avi -> ../../DAiSEE/features/2/test/4000232054.npy
# ✓ 2/test/5100462062.avi -> ../../DAiSEE/features/2/test/5100462062.npy
# ✓ 2/test/2100592027.avi -> ../../DAiSEE/features/2/test/2100592027.npy
# ✓ 2/test/3100701043.avi -> ../../DAiSEE/features/2/test/3100701043.npy
# ✓ 2/test/3100712014.avi -> ../../DAiSEE/features/2/test/3100712014.npy
# ✓ 2/test/2100531050.avi -> ../../DAiSEE/features/2/test/2100531050.npy
# ✓ 2/test/1100141034.avi -> ../../DAiSEE/features/2/test/1100141034.npy
# ✓ 2/test/5100471011.avi -> ../../DAiSEE/features/2/test/5100471011.npy
# ✓ 2/test/4140810273.avi -> ../../DAiSEE/features/2/test/4140810273.npy
# ✓ 2/test/1100011012.avi -> ../../DAiSEE/features/2/test/1100011012.npy
# ✓ 2/test/3100631022.avi -> ../../DAiSEE/features/2/test/3100631022.npy
# ✓ 2/test/5100472064.avi -> ../../DAiSEE/features/2/test/5100472064.npy
# ✓ 2/test/1110032025.avi -> ../../DAiSEE/features/2/test/1110032025.npy
# ✓ 2/test/350361016.avi -> ../../DAiSEE/features/2/test/350361016.npy
# ✓ 2/test/4000181069.avi -> ../../DAiSEE/features/2/test/4000181069.npy
# ✓ 2/test/2100581010.avi -> ../../DAiSEE/features/2/test/2100581010.npy
# ✓ 2/test/4100261013.avi -> ../../DAiSEE/features/2/test/4100261013.npy
# ✓ 2/test/5100381065.avi -> ../../DAiSEE/features/2/test/5100381065.npy
# ✓ 2/test/1100051055.avi -> ../../DAiSEE/features/2/test/1100051055.npy
# ✓ 2/test/2408460274.avi -> ../../DAiSEE/features/2/test/2408460274.npy
# ✓ 2/test/4100242066.avi -> ../../DAiSEE/features/2/test/4100242066.npy
# ✓ 2/test/2100602034.avi -> ../../DAiSEE/features/2/test/2100602034.npy
# ✓ 2/test/350361013.avi -> ../../DAiSEE/features/2/test/350361013.npy
# ✓ 2/test/2100582028.avi -> ../../DAiSEE/features/2/test/2100582028.npy
# ✓ 2/test/5100341037.avi -> ../../DAiSEE/features/2/test/5100341037.npy
# ✓ 2/test/3100771078.avi -> ../../DAiSEE/features/2/test/3100771078.npy
# ✓ 2/test/2100552017.avi -> ../../DAiSEE/features/2/test/2100552017.npy
# ✓ 2/test/5100382073.avi -> ../../DAiSEE/features/2/test/5100382073.npy
# ✓ 2/test/1100151010.avi -> ../../DAiSEE/features/2/test/1100151010.npy
# ✓ 2/test/1100051025.avi -> ../../DAiSEE/features/2/test/1100051025.npy
# ✓ 2/test/29042801220.mp4 -> ../../DAiSEE/features/2/test/29042801220.npy
# ✓ 2/test/88265402480.mp4 -> ../../DAiSEE/features/2/test/88265402480.npy
# ✓ 2/test/826382021.mp4 -> ../../DAiSEE/features/2/test/826382021.npy
# ✓ 2/test/29042801550.mp4 -> ../../DAiSEE/features/2/test/29042801550.npy
# ✓ 2/test/826382028.mp4 -> ../../DAiSEE/features/2/test/826382028.npy
# ✓ 2/test/79940201510.mp4 -> ../../DAiSEE/features/2/test/79940201510.npy
# ✓ 2/test/79940202820.mp4 -> ../../DAiSEE/features/2/test/79940202820.npy
# ✓ 2/test/303830148.mp4 -> ../../DAiSEE/features/2/test/303830148.npy
# ✓ 2/test/33702101600.mp4 -> ../../DAiSEE/features/2/test/33702101600.npy
# ✓ 2/test/2026140220.mp4 -> ../../DAiSEE/features/2/test/2026140220.npy
# ✓ 2/test/2026140124.mp4 -> ../../DAiSEE/features/2/test/2026140124.npy
# ✓ 2/test/33702101540.mp4 -> ../../DAiSEE/features/2/test/33702101540.npy
# ✓ 2/test/79940201560.mp4 -> ../../DAiSEE/features/2/test/79940201560.npy
# ✓ 2/test/8263820269.mp4 -> ../../DAiSEE/features/2/test/8263820269.npy
# ✓ 3/test/5100372001.avi -> ../../DAiSEE/features/3/test/5100372001.npy
# ✓ 3/test/3100751068.avi -> ../../DAiSEE/features/3/test/3100751068.npy
# ✓ 3/test/4140810143.avi -> ../../DAiSEE/features/3/test/4140810143.npy
# ✓ 3/test/2100562004.avi -> ../../DAiSEE/features/3/test/2100562004.npy
# ✓ 3/test/1100411011.avi -> ../../DAiSEE/features/3/test/1100411011.npy
# ✓ 3/test/1110031037.avi -> ../../DAiSEE/features/3/test/1110031037.npy
# ✓ 3/test/1100071077.avi -> ../../DAiSEE/features/3/test/1100071077.npy
# ✓ 3/test/5100451056.avi -> ../../DAiSEE/features/3/test/5100451056.npy
# ✓ 3/test/342227013.avi -> ../../DAiSEE/features/3/test/342227013.npy
# ✓ 3/test/4140810277.avi -> ../../DAiSEE/features/3/test/4140810277.npy
# ✓ 3/test/2100561013.avi -> ../../DAiSEE/features/3/test/2100561013.npy
# ✓ 3/test/1100152019.avi -> ../../DAiSEE/features/3/test/1100152019.npy
# ✓ 3/test/2000481038.avi -> ../../DAiSEE/features/3/test/2000481038.npy
# ✓ 3/test/5000442059.avi -> ../../DAiSEE/features/3/test/5000442059.npy
# ✓ 3/test/3503610152.avi -> ../../DAiSEE/features/3/test/3503610152.npy
# ✓ 3/test/5000441041.avi -> ../../DAiSEE/features/3/test/5000441041.npy
# ✓ 3/test/4599990231.avi -> ../../DAiSEE/features/3/test/4599990231.npy
# ✓ 3/test/5221290127.avi -> ../../DAiSEE/features/3/test/5221290127.npy
# ✓ 3/test/3100741039.avi -> ../../DAiSEE/features/3/test/3100741039.npy
# ✓ 3/test/5100451060.avi -> ../../DAiSEE/features/3/test/5100451060.npy
# ✓ 3/test/5674960215.avi -> ../../DAiSEE/features/3/test/5674960215.npy
# ✓ 3/test/3100791033.avi -> ../../DAiSEE/features/3/test/3100791033.npy
# ✓ 3/test/5912920154.avi -> ../../DAiSEE/features/3/test/5912920154.npy
# ✓ 3/test/5000671001.avi -> ../../DAiSEE/features/3/test/5000671001.npy
# ✓ 3/test/2000541056.avi -> ../../DAiSEE/features/3/test/2000541056.npy
# ✓ 3/test/2000541031.avi -> ../../DAiSEE/features/3/test/2000541031.npy
# ✓ 3/test/3100621014.avi -> ../../DAiSEE/features/3/test/3100621014.npy
# ✓ 3/test/5674960114.avi -> ../../DAiSEE/features/3/test/5674960114.npy
# ✓ 3/test/4000332050.avi -> ../../DAiSEE/features/3/test/4000332050.npy
# ✓ 3/test/2100591022.avi -> ../../DAiSEE/features/3/test/2100591022.npy
# ✓ 3/test/3100822058.avi -> ../../DAiSEE/features/3/test/3100822058.npy
# ✓ 3/test/3100811050.avi -> ../../DAiSEE/features/3/test/3100811050.npy
# ✓ 3/test/3100831026.avi -> ../../DAiSEE/features/3/test/3100831026.npy
# ✓ 3/test/2100521072.avi -> ../../DAiSEE/features/3/test/2100521072.npy
# ✓ 3/test/3100721015.avi -> ../../DAiSEE/features/3/test/3100721015.npy
# ✓ 3/test/2100572018.avi -> ../../DAiSEE/features/3/test/2100572018.npy
# ✓ 3/test/4100261035.avi -> ../../DAiSEE/features/3/test/4100261035.npy
# ✓ 3/test/4599990139.avi -> ../../DAiSEE/features/3/test/4599990139.npy
# ✓ 3/test/2100531051.avi -> ../../DAiSEE/features/3/test/2100531051.npy
# ✓ 3/test/4100241051.avi -> ../../DAiSEE/features/3/test/4100241051.npy
# ✓ 3/test/2100612060.avi -> ../../DAiSEE/features/3/test/2100612060.npy
# ✓ 3/test/4100192062.avi -> ../../DAiSEE/features/3/test/4100192062.npy
# ✓ 3/test/3100702005.avi -> ../../DAiSEE/features/3/test/3100702005.npy
# ✓ 3/test/3100742018.avi -> ../../DAiSEE/features/3/test/3100742018.npy
# ✓ 3/test/181374016.avi -> ../../DAiSEE/features/3/test/181374016.npy
# ✓ 3/test/2100532024.avi -> ../../DAiSEE/features/3/test/2100532024.npy
# ✓ 3/test/2100601010.avi -> ../../DAiSEE/features/3/test/2100601010.npy
# ✓ 3/test/2100571008.avi -> ../../DAiSEE/features/3/test/2100571008.npy
# ✓ 3/test/5000671026.avi -> ../../DAiSEE/features/3/test/5000671026.npy
# ✓ 3/test/1100112036.avi -> ../../DAiSEE/features/3/test/1100112036.npy
# ✓ 3/test/5100352013.avi -> ../../DAiSEE/features/3/test/5100352013.npy
# ✓ 3/test/2100511063.avi -> ../../DAiSEE/features/3/test/2100511063.npy
# ✓ 3/test/3100722026.avi -> ../../DAiSEE/features/3/test/3100722026.npy
# ✓ 3/test/1100152020.avi -> ../../DAiSEE/features/3/test/1100152020.npy
# ✓ 3/test/3100792042.avi -> ../../DAiSEE/features/3/test/3100792042.npy
# ✓ 3/test/4140810138.avi -> ../../DAiSEE/features/3/test/4140810138.npy
# ✓ 3/test/2100511074.avi -> ../../DAiSEE/features/3/test/2100511074.npy
# ✓ 3/test/4000331044.avi -> ../../DAiSEE/features/3/test/4000331044.npy
# ✓ 3/test/3503610277.avi -> ../../DAiSEE/features/3/test/3503610277.npy
# ✓ 3/test/3100772010.avi -> ../../DAiSEE/features/3/test/3100772010.npy
# ✓ 3/test/3422270254.avi -> ../../DAiSEE/features/3/test/3422270254.npy
# ✓ 3/test/4110212013.avi -> ../../DAiSEE/features/3/test/4110212013.npy
# ✓ 3/test/5100462053.avi -> ../../DAiSEE/features/3/test/5100462053.npy
# ✓ 3/test/4100242004.avi -> ../../DAiSEE/features/3/test/4100242004.npy
# ✓ 3/test/2100591057.avi -> ../../DAiSEE/features/3/test/2100591057.npy
# ✓ 3/test/3100781023.avi -> ../../DAiSEE/features/3/test/3100781023.npy
# ✓ 3/test/3100752052.avi -> ../../DAiSEE/features/3/test/3100752052.npy
# ✓ 3/test/1813740127.avi -> ../../DAiSEE/features/3/test/1813740127.npy
# ✓ 3/test/2100611015.avi -> ../../DAiSEE/features/3/test/2100611015.npy
# ✓ 3/test/5100472004.avi -> ../../DAiSEE/features/3/test/5100472004.npy
# ✓ 3/test/2260510172.avi -> ../../DAiSEE/features/3/test/2260510172.npy
# ✓ 3/test/2100612029.avi -> ../../DAiSEE/features/3/test/2100612029.npy
# ✓ 3/test/5100341067.avi -> ../../DAiSEE/features/3/test/5100341067.npy
# ✓ 3/test/1100111010.avi -> ../../DAiSEE/features/3/test/1100111010.npy
# ✓ 3/test/5564630217.avi -> ../../DAiSEE/features/3/test/5564630217.npy
# ✓ 3/test/9877360156.avi -> ../../DAiSEE/features/3/test/9877360156.npy
# ✓ 3/test/2100592017.avi -> ../../DAiSEE/features/3/test/2100592017.npy
# ✓ 3/test/4100281019.avi -> ../../DAiSEE/features/3/test/4100281019.npy
# ✓ 3/test/2100592015.avi -> ../../DAiSEE/features/3/test/2100592015.npy
# ✓ 3/test/4100272056.avi -> ../../DAiSEE/features/3/test/4100272056.npy
# ✓ 3/test/3100742067.avi -> ../../DAiSEE/features/3/test/3100742067.npy
# ✓ 3/test/5100421056.avi -> ../../DAiSEE/features/3/test/5100421056.npy
# ✓ 3/test/3100821068.avi -> ../../DAiSEE/features/3/test/3100821068.npy
# ✓ 3/test/7698620129.avi -> ../../DAiSEE/features/3/test/7698620129.npy
# ✓ 3/test/3100721045.avi -> ../../DAiSEE/features/3/test/3100721045.npy
# ✓ 3/test/5100401038.avi -> ../../DAiSEE/features/3/test/5100401038.npy
# ✓ 3/test/5100461061.avi -> ../../DAiSEE/features/3/test/5100461061.npy
# ✓ 3/test/2100521044.avi -> ../../DAiSEE/features/3/test/2100521044.npy
# ✓ 3/test/2100512007.avi -> ../../DAiSEE/features/3/test/2100512007.npy
# ✓ 3/test/2100582025.avi -> ../../DAiSEE/features/3/test/2100582025.npy
# ✓ 3/test/4100252012.avi -> ../../DAiSEE/features/3/test/4100252012.npy
# ✓ 3/test/4100322059.avi -> ../../DAiSEE/features/3/test/4100322059.npy
# ✓ 3/test/8264120233.avi -> ../../DAiSEE/features/3/test/8264120233.npy
# ✓ 3/test/3100741077.avi -> ../../DAiSEE/features/3/test/3100741077.npy
# ✓ 3/test/5100341050.avi -> ../../DAiSEE/features/3/test/5100341050.npy
# ✓ 3/test/5100372026.avi -> ../../DAiSEE/features/3/test/5100372026.npy
# ✓ 3/test/5674960251.avi -> ../../DAiSEE/features/3/test/5674960251.npy
# ✓ 3/test/5000391015.avi -> ../../DAiSEE/features/3/test/5000391015.npy
# ✓ 3/test/181374019.avi -> ../../DAiSEE/features/3/test/181374019.npy
# ✓ 3/test/5100461053.avi -> ../../DAiSEE/features/3/test/5100461053.npy
# ✓ 3/test/5100092027.avi -> ../../DAiSEE/features/3/test/5100092027.npy
# ✓ 3/test/5221290145.avi -> ../../DAiSEE/features/3/test/5221290145.npy
# ✓ 3/test/4100192025.avi -> ../../DAiSEE/features/3/test/4100192025.npy
# ✓ 3/test/8264120117.avi -> ../../DAiSEE/features/3/test/8264120117.npy
# ✓ 3/test/3100721052.avi -> ../../DAiSEE/features/3/test/3100721052.npy
# ✓ 3/test/4110312030.avi -> ../../DAiSEE/features/3/test/4110312030.npy
# ✓ 3/test/4000232068.avi -> ../../DAiSEE/features/3/test/4000232068.npy
# ✓ 3/test/5674960228.avi -> ../../DAiSEE/features/3/test/5674960228.npy
# ✓ 3/test/5221290270.avi -> ../../DAiSEE/features/3/test/5221290270.npy
# ✓ 3/test/5000442037.avi -> ../../DAiSEE/features/3/test/5000442037.npy
# ✓ 3/test/2100511003.avi -> ../../DAiSEE/features/3/test/2100511003.npy
# ✓ 3/test/9403280277.avi -> ../../DAiSEE/features/3/test/9403280277.npy
# ✓ 3/test/2056010212.avi -> ../../DAiSEE/features/3/test/2056010212.npy
# ✓ 3/test/2100531082.avi -> ../../DAiSEE/features/3/test/2100531082.npy
# ✓ 3/test/3503610246.avi -> ../../DAiSEE/features/3/test/3503610246.npy
# ✓ 3/test/1100012037.avi -> ../../DAiSEE/features/3/test/1100012037.npy
# ✓ 3/test/5100451035.avi -> ../../DAiSEE/features/3/test/5100451035.npy
# ✓ 3/test/1100151014.avi -> ../../DAiSEE/features/3/test/1100151014.npy
# ✓ 3/test/2100572002.avi -> ../../DAiSEE/features/3/test/2100572002.npy
# ✓ 3/test/9403280164.avi -> ../../DAiSEE/features/3/test/9403280164.npy
# ✓ 3/test/4000331020.avi -> ../../DAiSEE/features/3/test/4000331020.npy
# ✓ 3/test/3100622042.avi -> ../../DAiSEE/features/3/test/3100622042.npy
# ✓ 3/test/5100452054.avi -> ../../DAiSEE/features/3/test/5100452054.npy
# ✓ 3/test/350361012.avi -> ../../DAiSEE/features/3/test/350361012.npy
# ✓ 3/test/2100531067.avi -> ../../DAiSEE/features/3/test/2100531067.npy
# ✓ 3/test/1100062067.avi -> ../../DAiSEE/features/3/test/1100062067.npy
# ✓ 3/test/4140810224.avi -> ../../DAiSEE/features/3/test/4140810224.npy
# ✓ 3/test/2100521008.avi -> ../../DAiSEE/features/3/test/2100521008.npy
# ✓ 3/test/4100262037.avi -> ../../DAiSEE/features/3/test/4100262037.npy
# ✓ 3/test/1100111001.avi -> ../../DAiSEE/features/3/test/1100111001.npy
# ✓ 3/test/4140810229.avi -> ../../DAiSEE/features/3/test/4140810229.npy
# ✓ 3/test/3100722039.avi -> ../../DAiSEE/features/3/test/3100722039.npy
# ✓ 3/test/2100611056.avi -> ../../DAiSEE/features/3/test/2100611056.npy
# ✓ 3/test/5000952053.avi -> ../../DAiSEE/features/3/test/5000952053.npy
# ✓ 3/test/3100721032.avi -> ../../DAiSEE/features/3/test/3100721032.npy
# ✓ 3/test/928901023.avi -> ../../DAiSEE/features/3/test/928901023.npy
# ✓ 3/test/3100751040.avi -> ../../DAiSEE/features/3/test/3100751040.npy
# ✓ 3/test/4100202008.avi -> ../../DAiSEE/features/3/test/4100202008.npy
# ✓ 3/test/5100471057.avi -> ../../DAiSEE/features/3/test/5100471057.npy
# ✓ 3/test/3100822075.avi -> ../../DAiSEE/features/3/test/3100822075.npy
# ✓ 3/test/2100611055.avi -> ../../DAiSEE/features/3/test/2100611055.npy
# ✓ 3/test/4100321005.avi -> ../../DAiSEE/features/3/test/4100321005.npy
# ✓ 3/test/2100592019.avi -> ../../DAiSEE/features/3/test/2100592019.npy
# ✓ 3/test/1100152013.avi -> ../../DAiSEE/features/3/test/1100152013.npy
# ✓ 3/test/3100831004.avi -> ../../DAiSEE/features/3/test/3100831004.npy
# ✓ 3/test/1100071057.avi -> ../../DAiSEE/features/3/test/1100071057.npy
# ✓ 3/test/5000391032.avi -> ../../DAiSEE/features/3/test/5000391032.npy
# ✓ 3/test/2100561023.avi -> ../../DAiSEE/features/3/test/2100561023.npy
# ✓ 3/test/2000541025.avi -> ../../DAiSEE/features/3/test/2000541025.npy
# ✓ 3/test/1100022027.avi -> ../../DAiSEE/features/3/test/1100022027.npy
# ✓ 3/test/5000441009.avi -> ../../DAiSEE/features/3/test/5000441009.npy
# ✓ 3/test/1100012060.avi -> ../../DAiSEE/features/3/test/1100012060.npy
# ✓ 3/test/3100621033.avi -> ../../DAiSEE/features/3/test/3100621033.npy
# ✓ 3/test/2100581002.avi -> ../../DAiSEE/features/3/test/2100581002.npy
# ✓ 3/test/5100352046.avi -> ../../DAiSEE/features/3/test/5100352046.npy
# ✓ 3/test/3344630130.avi -> ../../DAiSEE/features/3/test/3344630130.npy
# ✓ 3/test/1100042020.avi -> ../../DAiSEE/features/3/test/1100042020.npy
# ✓ 3/test/1100121012.avi -> ../../DAiSEE/features/3/test/1100121012.npy
# ✓ 3/test/1100112039.avi -> ../../DAiSEE/features/3/test/1100112039.npy
# ✓ 3/test/2408460261.avi -> ../../DAiSEE/features/3/test/2408460261.npy
# ✓ 3/test/5100381053.avi -> ../../DAiSEE/features/3/test/5100381053.npy
# ✓ 3/test/5100381003.avi -> ../../DAiSEE/features/3/test/5100381003.npy
# ✓ 3/test/5000391066.avi -> ../../DAiSEE/features/3/test/5000391066.npy
# ✓ 3/test/3100792031.avi -> ../../DAiSEE/features/3/test/3100792031.npy
# ✓ 3/test/3100721070.avi -> ../../DAiSEE/features/3/test/3100721070.npy
# ✓ 3/test/2100562058.avi -> ../../DAiSEE/features/3/test/2100562058.npy
# ✓ 3/test/5100452009.avi -> ../../DAiSEE/features/3/test/5100452009.npy
# ✓ 3/test/1100011053.avi -> ../../DAiSEE/features/3/test/1100011053.npy
# ✓ 3/test/4000331003.avi -> ../../DAiSEE/features/3/test/4000331003.npy
# ✓ 3/test/2408460280.avi -> ../../DAiSEE/features/3/test/2408460280.npy
# ✓ 3/test/3100642011.avi -> ../../DAiSEE/features/3/test/3100642011.npy
# ✓ 3/test/2100612058.avi -> ../../DAiSEE/features/3/test/2100612058.npy
# ✓ 3/test/1100071034.avi -> ../../DAiSEE/features/3/test/1100071034.npy
# ✓ 3/test/1100121005.avi -> ../../DAiSEE/features/3/test/1100121005.npy
# ✓ 3/test/5100352038.avi -> ../../DAiSEE/features/3/test/5100352038.npy
# ✓ 3/test/3503610150.avi -> ../../DAiSEE/features/3/test/3503610150.npy
# ✓ 3/test/9877360159.avi -> ../../DAiSEE/features/3/test/9877360159.npy
# ✓ 3/test/3100631043.avi -> ../../DAiSEE/features/3/test/3100631043.npy
# ✓ 3/test/5221290167.avi -> ../../DAiSEE/features/3/test/5221290167.npy
# ✓ 3/test/4000232007.avi -> ../../DAiSEE/features/3/test/4000232007.npy
# ✓ 3/test/1100122048.avi -> ../../DAiSEE/features/3/test/1100122048.npy
# ✓ 3/test/3422270127.avi -> ../../DAiSEE/features/3/test/3422270127.npy
# ✓ 3/test/9289010270.avi -> ../../DAiSEE/features/3/test/9289010270.npy
# ✓ 3/test/4000221062.avi -> ../../DAiSEE/features/3/test/4000221062.npy
# ✓ 3/test/8264120227.avi -> ../../DAiSEE/features/3/test/8264120227.npy
# ✓ 3/test/5000442027.avi -> ../../DAiSEE/features/3/test/5000442027.npy
# ✓ 3/test/5000952076.avi -> ../../DAiSEE/features/3/test/5000952076.npy
# ✓ 3/test/2100591010.avi -> ../../DAiSEE/features/3/test/2100591010.npy
# ✓ 3/test/2100612007.avi -> ../../DAiSEE/features/3/test/2100612007.npy
# ✓ 3/test/1100011056.avi -> ../../DAiSEE/features/3/test/1100011056.npy
# ✓ 3/test/3100782019.avi -> ../../DAiSEE/features/3/test/3100782019.npy
# ✓ 3/test/2100601045.avi -> ../../DAiSEE/features/3/test/2100601045.npy
# ✓ 3/test/4100281078.avi -> ../../DAiSEE/features/3/test/4100281078.npy
# ✓ 3/test/4000181061.avi -> ../../DAiSEE/features/3/test/4000181061.npy
# ✓ 3/test/1110032006.avi -> ../../DAiSEE/features/3/test/1110032006.npy
# ✓ 3/test/2100611046.avi -> ../../DAiSEE/features/3/test/2100611046.npy
# ✓ 3/test/5000431023.avi -> ../../DAiSEE/features/3/test/5000431023.npy
# ✓ 3/test/2100552059.avi -> ../../DAiSEE/features/3/test/2100552059.npy
# ✓ 3/test/1100012050.avi -> ../../DAiSEE/features/3/test/1100012050.npy
# ✓ 3/test/29042802520.mp4 -> ../../DAiSEE/features/3/test/29042802520.npy
# ✓ 3/test/8826540150.mp4 -> ../../DAiSEE/features/3/test/8826540150.npy
# ✓ 3/test/88265402380.mp4 -> ../../DAiSEE/features/3/test/88265402380.npy
# ✓ 3/test/202614021.mp4 -> ../../DAiSEE/features/3/test/202614021.npy
# ✓ 3/test/29042802670.mp4 -> ../../DAiSEE/features/3/test/29042802670.npy
# ✓ 3/test/303830210.mp4 -> ../../DAiSEE/features/3/test/303830210.npy
# ✓ 3/test/29042801340.mp4 -> ../../DAiSEE/features/3/test/29042801340.npy
# ✓ 3/test/29042801770.mp4 -> ../../DAiSEE/features/3/test/29042801770.npy
# ✓ 3/test/303830122.mp4 -> ../../DAiSEE/features/3/test/303830122.npy
# ✓ 3/test/29042802830.mp4 -> ../../DAiSEE/features/3/test/29042802830.npy
# ✓ 3/test/303830118.mp4 -> ../../DAiSEE/features/3/test/303830118.npy
# ✓ 3/test/303830241.mp4 -> ../../DAiSEE/features/3/test/303830241.npy
# ✓ 3/test/33702102400.mp4 -> ../../DAiSEE/features/3/test/33702102400.npy
# ✓ 3/test/33702101760.mp4 -> ../../DAiSEE/features/3/test/33702101760.npy
# ✓ 3/test/33702102600.mp4 -> ../../DAiSEE/features/3/test/33702102600.npy
# ✓ 3/test/88265402630.mp4 -> ../../DAiSEE/features/3/test/88265402630.npy
# ✓ 3/test/88265402840.mp4 -> ../../DAiSEE/features/3/test/88265402840.npy
# ✓ 3/test/303830234.mp4 -> ../../DAiSEE/features/3/test/303830234.npy
# ✓ 3/test/88265401400.mp4 -> ../../DAiSEE/features/3/test/88265401400.npy
# ✓ 3/test/2026140161.mp4 -> ../../DAiSEE/features/3/test/2026140161.npy
# ✓ 3/test/88265402810.mp4 -> ../../DAiSEE/features/3/test/88265402810.npy
# ✓ 3/test/248510262.mp4 -> ../../DAiSEE/features/3/test/248510262.npy
# ✓ 3/test/79940201490.mp4 -> ../../DAiSEE/features/3/test/79940201490.npy
# ✓ 3/test/303830263.mp4 -> ../../DAiSEE/features/3/test/303830263.npy
# ✓ 3/test/79940202570.mp4 -> ../../DAiSEE/features/3/test/79940202570.npy
# ✓ 3/test/907001490.mp4 -> ../../DAiSEE/features/3/test/907001490.npy
# Batch X: (32, 32, 1280) Batch y: [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2]
# 2025-05-12 19:44:08.502225: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def make_dataset(split, shuffle=True, balance=True):
    datasets = []
    for cls in CLASSES:
        pattern = os.path.join(OUTPUT_FEATURES, cls, split, "*.npy")
        files_ds = tf.data.Dataset.list_files(pattern, shuffle=shuffle)

        def _load(path):
            # (NUM_FRAMES, 1280), label
            x = tf.numpy_function(np.load, [path], tf.float32)
            x.set_shape((NUM_FRAMES, 1280))
            y = tf.strings.split(path, os.sep)[-3]
            y = tf.strings.to_number(y, out_type=tf.int32)
            return x, y

        # Repetimos para no quedarnos sin datos cuando la clase minoritaria se agote
        ds = files_ds.map(_load, num_parallel_calls=tf.data.AUTOTUNE).repeat()
        datasets.append(ds)

    if balance:
        # Muestreo balanceado **por ejemplo** (no por batch)
        mixed = tf.data.Dataset.sample_from_datasets(
            datasets,
            weights=[1/len(CLASSES)]*len(CLASSES),
            stop_on_empty_dataset=False,
        )
    else:
        mixed = datasets[0]
        for extra in datasets[1:]:
            mixed = mixed.concatenate(extra)

    return (
        mixed
        .shuffle(1000)             # mezcla adicional
        .batch(BATCH_SIZE, drop_remainder=True)
        .prefetch(tf.data.AUTOTUNE)
    )

# %%
# Ejemplo de uso en tu ciclo de entrenamiento
train_ds = make_dataset("train", balance=True)
val_ds   = make_dataset("validation", balance=False)

for xb, yb in train_ds.take(5):
    print("Batch X:", xb.shape, "Batch y:", yb.numpy())
# Out:
# Batch X: (32, 32, 1280) Batch y: [0 2 0 2 2 1 0 2 3 1 2 2 0 2 1 2 2 2 0 2 2 0 1 1 0 0 0 0 2 0 3 3]
# Batch X: (32, 32, 1280) Batch y: [0 2 3 2 0 0 1 0 3 0 3 2 3 3 3 1 2 0 1 2 1 2 2 1 2 0 2 3 2 3 2 3]
# Batch X: (32, 32, 1280) Batch y: [0 2 0 2 1 0 2 1 3 1 2 1 3 1 3 3 0 1 3 3 3 3 0 1 0 1 0 1 3 1 0 1]
# Batch X: (32, 32, 1280) Batch y: [0 1 0 2 0 2 1 3 3 2 0 3 1 2 3 1 3 2 1 0 1 0 1 3 0 1 3 0 0 0 3 0]
# Batch X: (32, 32, 1280) Batch y: [3 1 1 1 2 1 1 2 0 2 0 1 1 2 1 3 3 0 3 3 0 3 3 2 1 1 3 3 1 2 1 0]
# 2025-05-12 20:12:49.365229: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
