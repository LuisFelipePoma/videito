# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import os
import pickle
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
from sklearn.metrics import precision_recall_curve, f1_score, classification_report

from tensorflow.keras import layers, models
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Conv1D, GlobalMaxPooling1D, MaxPooling1D, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Precision, Recall
import tensorflow.keras.backend as K
from sklearn.utils import class_weight

# %%
def charge_npy(path):
    X = np.load(path)
    y = np.load(path.replace('X', 'y'))
    return X, y

# %%
# charge y_train.npy in Facenet Embeddings/Train/y_train.npy
path_train = '../../../../Facenet Embeddings/Train/X_train.npy'
path_val = '../../../../Facenet Embeddings/Val/X_val.npy'
path_test = '../../../../Facenet Embeddings/Test/X_test.npy'
X_train, y_train = charge_npy(path_train)
X_val, y_val = charge_npy(path_val)
X_test, y_test = charge_npy(path_test)
n_frames = 5
embedding_dim = 128

X_train = X_train.reshape((-1, n_frames, embedding_dim))
y_train = y_train[:, 4:8]
y_train = np.mean(y_train.reshape(-1, 5, 4), axis=1)
y_train = np.argmax(y_train, axis=1)


X_val = X_val.reshape((-1, n_frames, embedding_dim)) 
y_val = y_val[:, 4:8]
y_val = np.mean(y_val.reshape(-1, 5, 4), axis=1)
y_val = np.argmax(y_val, axis=1)


X_test = X_test.reshape((-1, n_frames, embedding_dim))  
y_test = y_test[:, 4:8]
y_test = np.mean(y_test.reshape(-1, 5, 4), axis=1)
y_test = np.argmax(y_test, axis=1)

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((5481, 5, 128), (5481,), (1720, 5, 128), (1720,), (1723, 5, 128), (1723,))

# %%
# Primero, identificamos los índices de cada clase
indices_class_0 = np.where(y_train == 0)[0]
indices_class_1 = np.where(y_train == 1)[0]
indices_class_2 = np.where(y_train == 2)[0]
indices_class_3 = np.where(y_train == 3)[0]

# Ahora, hacemos downsample (muestreo aleatorio sin reemplazo)
np.random.seed(123)  # para reproducibilidad

selected_class_0 = np.random.choice(indices_class_0, 34, replace=False)
selected_class_1 = np.random.choice(indices_class_1, 80, replace=False)
selected_class_2 = np.random.choice(indices_class_2, 80, replace=False)
selected_class_3 = np.random.choice(indices_class_3, 80, replace=False)

# Unimos todos los índices seleccionados
selected_indices = np.concatenate([selected_class_0, selected_class_1, selected_class_2, selected_class_3])

# Mezclamos los índices para que estén desordenados
np.random.shuffle(selected_indices)

# Creamos los nuevos datasets
X_train_balanced = X_train[selected_indices]
y_train_balanced = y_train[selected_indices]

# Verificamos las nuevas formas
print(X_train_balanced.shape)  # debería ser (301, 5, 128)
print(y_train_balanced.shape)  # debería ser (301,)
# Out:
# (274, 5, 128)
# (274,)

# %%
# Concatenate X_val and X_test, and y_val and y_test
X_val_test = np.concatenate((X_val, X_test), axis=0)
y_val_test = np.concatenate((y_val, y_test), axis=0)

# Train-test split
X_val, X_test, y_val, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=123, stratify=y_val_test)

# %%
# view value count in y_val and y_test
print("y_val value counts:")
print(pd.Series(y_val).value_counts())
print("y_test value counts:")
print(pd.Series(y_test).value_counts())
# Out:
# y_val value counts:
# 2    886
# 3    701
# 1    120
# 0     14
# Name: count, dtype: int64
# y_test value counts:
# 2    887
# 3    701
# 1    121
# 0     13
# Name: count, dtype: int64

# %%
# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_balanced),
    y=y_train_balanced
)
class_weights = dict(enumerate(class_weights))

# %%
# Parámetros
early_stopping = EarlyStopping(monitor='val_loss', patience=250, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=50, verbose=1)

# Definimos el modelo CNN
def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(128, kernel_size=5, activation='relu', padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Conv1D(256, kernel_size=3, activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    model.add(Conv1D(256, kernel_size=3, activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    model.add(GlobalMaxPooling1D())

    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(4, activation='softmax'))  # Cambia 4 por el número de clases que tengas

    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(0.0005), metrics=['accuracy'])
    return model


# Creamos y entrenamos el modelo
model = build_cnn_model((X_train.shape[1], X_train.shape[2]))
    
history = model.fit(
    X_train_balanced,
    y_train_balanced,
    class_weight=class_weights,
    epochs=1000,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.2656 - loss: 3.1346 - val_accuracy: 0.1737 - val_loss: 1.3956 - learning_rate: 5.0000e-04
# Epoch 2/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3789 - loss: 2.1397 - val_accuracy: 0.1917 - val_loss: 1.3978 - learning_rate: 5.0000e-04
# Epoch 3/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3548 - loss: 2.0451 - val_accuracy: 0.2981 - val_loss: 1.3606 - learning_rate: 5.0000e-04
# Epoch 4/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3861 - loss: 1.6692 - val_accuracy: 0.3684 - val_loss: 1.3354 - learning_rate: 5.0000e-04
# Epoch 5/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3770 - loss: 1.6272 - val_accuracy: 0.3899 - val_loss: 1.3342 - learning_rate: 5.0000e-04
# Epoch 6/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4696 - loss: 1.4399 - val_accuracy: 0.3818 - val_loss: 1.3317 - learning_rate: 5.0000e-04
# Epoch 7/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4049 - loss: 1.4291 - val_accuracy: 0.3672 - val_loss: 1.3346 - learning_rate: 5.0000e-04
# Epoch 8/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3933 - loss: 1.4090 - val_accuracy: 0.3219 - val_loss: 1.3405 - learning_rate: 5.0000e-04
# Epoch 9/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4216 - loss: 1.3505 - val_accuracy: 0.3045 - val_loss: 1.3407 - learning_rate: 5.0000e-04
# Epoch 10/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5254 - loss: 1.1493 - val_accuracy: 0.2911 - val_loss: 1.3444 - learning_rate: 5.0000e-04
# Epoch 11/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4979 - loss: 1.1882 - val_accuracy: 0.2795 - val_loss: 1.3576 - learning_rate: 5.0000e-04
# Epoch 12/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4579 - loss: 1.3030 - val_accuracy: 0.2894 - val_loss: 1.3649 - learning_rate: 5.0000e-04
# Epoch 13/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5294 - loss: 0.9466 - val_accuracy: 0.3109 - val_loss: 1.3691 - learning_rate: 5.0000e-04
# Epoch 14/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4972 - loss: 1.0927 - val_accuracy: 0.2812 - val_loss: 1.3864 - learning_rate: 5.0000e-04
# Epoch 15/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5190 - loss: 1.1457 - val_accuracy: 0.2882 - val_loss: 1.3918 - learning_rate: 5.0000e-04
# Epoch 16/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5741 - loss: 1.0459 - val_accuracy: 0.2934 - val_loss: 1.4024 - learning_rate: 5.0000e-04
# Epoch 17/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5126 - loss: 1.0390 - val_accuracy: 0.3451 - val_loss: 1.3823 - learning_rate: 5.0000e-04
# Epoch 18/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5805 - loss: 0.9371 - val_accuracy: 0.3428 - val_loss: 1.3925 - learning_rate: 5.0000e-04
# Epoch 19/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6003 - loss: 0.9194 - val_accuracy: 0.3405 - val_loss: 1.3972 - learning_rate: 5.0000e-04
# Epoch 20/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5657 - loss: 0.9662 - val_accuracy: 0.3492 - val_loss: 1.4062 - learning_rate: 5.0000e-04
# Epoch 21/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5764 - loss: 0.9809 - val_accuracy: 0.3219 - val_loss: 1.4535 - learning_rate: 5.0000e-04
# Epoch 22/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5825 - loss: 1.0151 - val_accuracy: 0.2946 - val_loss: 1.4858 - learning_rate: 5.0000e-04
# Epoch 23/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6187 - loss: 0.9144 - val_accuracy: 0.2557 - val_loss: 1.5981 - learning_rate: 5.0000e-04
# Epoch 24/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5239 - loss: 0.9853 - val_accuracy: 0.2609 - val_loss: 1.5988 - learning_rate: 5.0000e-04
# Epoch 25/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6360 - loss: 0.8034 - val_accuracy: 0.2609 - val_loss: 1.6218 - learning_rate: 5.0000e-04
# Epoch 26/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5961 - loss: 0.8344 - val_accuracy: 0.2748 - val_loss: 1.6274 - learning_rate: 5.0000e-04
# Epoch 27/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6820 - loss: 0.7475 - val_accuracy: 0.2870 - val_loss: 1.6143 - learning_rate: 5.0000e-04
# Epoch 28/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5680 - loss: 0.8743 - val_accuracy: 0.3219 - val_loss: 1.5798 - learning_rate: 5.0000e-04
# Epoch 29/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5994 - loss: 0.8429 - val_accuracy: 0.3219 - val_loss: 1.6309 - learning_rate: 5.0000e-04
# Epoch 30/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6839 - loss: 0.7874 - val_accuracy: 0.3318 - val_loss: 1.6281 - learning_rate: 5.0000e-04
# Epoch 31/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6913 - loss: 0.6997 - val_accuracy: 0.3544 - val_loss: 1.6198 - learning_rate: 5.0000e-04
# Epoch 32/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6340 - loss: 0.7631 - val_accuracy: 0.3533 - val_loss: 1.6294 - learning_rate: 5.0000e-04
# Epoch 33/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6830 - loss: 0.8122 - val_accuracy: 0.3126 - val_loss: 1.7985 - learning_rate: 5.0000e-04
# Epoch 34/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5861 - loss: 0.8611 - val_accuracy: 0.3277 - val_loss: 1.7327 - learning_rate: 5.0000e-04
# Epoch 35/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7481 - loss: 0.5836 - val_accuracy: 0.3411 - val_loss: 1.7566 - learning_rate: 5.0000e-04
# Epoch 36/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7030 - loss: 0.7307 - val_accuracy: 0.3486 - val_loss: 1.7807 - learning_rate: 5.0000e-04
# Epoch 37/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7244 - loss: 0.6477 - val_accuracy: 0.3213 - val_loss: 1.9190 - learning_rate: 5.0000e-04
# Epoch 38/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6669 - loss: 0.7852 - val_accuracy: 0.3411 - val_loss: 1.8980 - learning_rate: 5.0000e-04
# Epoch 39/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6605 - loss: 0.7201 - val_accuracy: 0.3440 - val_loss: 1.8592 - learning_rate: 5.0000e-04
# Epoch 40/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7071 - loss: 0.6746 - val_accuracy: 0.3318 - val_loss: 1.9413 - learning_rate: 5.0000e-04
# Epoch 41/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6962 - loss: 0.6941 - val_accuracy: 0.3422 - val_loss: 1.8811 - learning_rate: 5.0000e-04
# Epoch 42/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6704 - loss: 0.7578 - val_accuracy: 0.3620 - val_loss: 1.8127 - learning_rate: 5.0000e-04
# Epoch 43/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7290 - loss: 0.6366 - val_accuracy: 0.3173 - val_loss: 1.9803 - learning_rate: 5.0000e-04
# Epoch 44/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6799 - loss: 0.6501 - val_accuracy: 0.3097 - val_loss: 2.0089 - learning_rate: 5.0000e-04
# Epoch 45/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7287 - loss: 0.6225 - val_accuracy: 0.3184 - val_loss: 1.9772 - learning_rate: 5.0000e-04
# Epoch 46/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7030 - loss: 0.6582 - val_accuracy: 0.3120 - val_loss: 2.0243 - learning_rate: 5.0000e-04
# Epoch 47/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7166 - loss: 0.5815 - val_accuracy: 0.3271 - val_loss: 1.9524 - learning_rate: 5.0000e-04
# Epoch 48/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7292 - loss: 0.5871 - val_accuracy: 0.2905 - val_loss: 2.2060 - learning_rate: 5.0000e-04
# Epoch 49/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8315 - loss: 0.4822 - val_accuracy: 0.2969 - val_loss: 2.2836 - learning_rate: 5.0000e-04
# Epoch 50/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7851 - loss: 0.5172 - val_accuracy: 0.3260 - val_loss: 2.1577 - learning_rate: 5.0000e-04
# Epoch 51/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7468 - loss: 0.5860 - val_accuracy: 0.3173 - val_loss: 2.1374 - learning_rate: 5.0000e-04
# Epoch 52/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7708 - loss: 0.5194 - val_accuracy: 0.3219 - val_loss: 2.2160 - learning_rate: 5.0000e-04
# Epoch 53/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7489 - loss: 0.5755 - val_accuracy: 0.3178 - val_loss: 2.3797 - learning_rate: 5.0000e-04
# Epoch 54/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7526 - loss: 0.5378 - val_accuracy: 0.3260 - val_loss: 2.3213 - learning_rate: 5.0000e-04
# Epoch 55/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8051 - loss: 0.4575 - val_accuracy: 0.3399 - val_loss: 2.3116 - learning_rate: 5.0000e-04
# Epoch 56/1000
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7500 - loss: 0.5854
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7663 - loss: 0.5301 - val_accuracy: 0.3202 - val_loss: 2.4618 - learning_rate: 5.0000e-04
# Epoch 57/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8213 - loss: 0.4847 - val_accuracy: 0.3033 - val_loss: 2.5394 - learning_rate: 2.5000e-04
# Epoch 58/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7904 - loss: 0.4437 - val_accuracy: 0.3045 - val_loss: 2.5215 - learning_rate: 2.5000e-04
# Epoch 59/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8095 - loss: 0.5847 - val_accuracy: 0.3056 - val_loss: 2.4705 - learning_rate: 2.5000e-04
# Epoch 60/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7952 - loss: 0.4670 - val_accuracy: 0.3219 - val_loss: 2.4227 - learning_rate: 2.5000e-04
# Epoch 61/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8182 - loss: 0.3835 - val_accuracy: 0.3202 - val_loss: 2.4595 - learning_rate: 2.5000e-04
# Epoch 62/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8127 - loss: 0.4240 - val_accuracy: 0.3155 - val_loss: 2.5246 - learning_rate: 2.5000e-04
# Epoch 63/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8048 - loss: 0.5016 - val_accuracy: 0.3173 - val_loss: 2.5244 - learning_rate: 2.5000e-04
# Epoch 64/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - loss: 0.4160 - val_accuracy: 0.3167 - val_loss: 2.5375 - learning_rate: 2.5000e-04
# Epoch 65/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8372 - loss: 0.4040 - val_accuracy: 0.3184 - val_loss: 2.5715 - learning_rate: 2.5000e-04
# Epoch 66/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8190 - loss: 0.4029 - val_accuracy: 0.3236 - val_loss: 2.5984 - learning_rate: 2.5000e-04
# Epoch 67/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8105 - loss: 0.3977 - val_accuracy: 0.3248 - val_loss: 2.6482 - learning_rate: 2.5000e-04
# Epoch 68/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8201 - loss: 0.4000 - val_accuracy: 0.3085 - val_loss: 2.7450 - learning_rate: 2.5000e-04
# Epoch 69/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8397 - loss: 0.3842 - val_accuracy: 0.3045 - val_loss: 2.8187 - learning_rate: 2.5000e-04
# Epoch 70/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8143 - loss: 0.3887 - val_accuracy: 0.3039 - val_loss: 2.7976 - learning_rate: 2.5000e-04
# Epoch 71/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8052 - loss: 0.4257 - val_accuracy: 0.2969 - val_loss: 2.8342 - learning_rate: 2.5000e-04
# Epoch 72/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8299 - loss: 0.3359 - val_accuracy: 0.2859 - val_loss: 2.9232 - learning_rate: 2.5000e-04
# Epoch 73/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8654 - loss: 0.3235 - val_accuracy: 0.2870 - val_loss: 2.9575 - learning_rate: 2.5000e-04
# Epoch 74/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8492 - loss: 0.3280 - val_accuracy: 0.2876 - val_loss: 2.9684 - learning_rate: 2.5000e-04
# Epoch 75/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8894 - loss: 0.3119 - val_accuracy: 0.2929 - val_loss: 2.9266 - learning_rate: 2.5000e-04
# Epoch 76/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8281 - loss: 0.3842 - val_accuracy: 0.2847 - val_loss: 2.9747 - learning_rate: 2.5000e-04
# Epoch 77/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8833 - loss: 0.2858 - val_accuracy: 0.2905 - val_loss: 2.9350 - learning_rate: 2.5000e-04
# Epoch 78/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8711 - loss: 0.3498 - val_accuracy: 0.3068 - val_loss: 2.8193 - learning_rate: 2.5000e-04
# Epoch 79/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8861 - loss: 0.2923 - val_accuracy: 0.3149 - val_loss: 2.8336 - learning_rate: 2.5000e-04
# Epoch 80/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8753 - loss: 0.2990 - val_accuracy: 0.3114 - val_loss: 2.8976 - learning_rate: 2.5000e-04
# Epoch 81/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8458 - loss: 0.3269 - val_accuracy: 0.3039 - val_loss: 2.9437 - learning_rate: 2.5000e-04
# Epoch 82/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8939 - loss: 0.2415 - val_accuracy: 0.3068 - val_loss: 2.9312 - learning_rate: 2.5000e-04
# Epoch 83/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8424 - loss: 0.3184 - val_accuracy: 0.3091 - val_loss: 2.9043 - learning_rate: 2.5000e-04
# Epoch 84/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8825 - loss: 0.2875 - val_accuracy: 0.3010 - val_loss: 3.0086 - learning_rate: 2.5000e-04
# Epoch 85/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9097 - loss: 0.2272 - val_accuracy: 0.2923 - val_loss: 3.0892 - learning_rate: 2.5000e-04
# Epoch 86/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8703 - loss: 0.3242 - val_accuracy: 0.3062 - val_loss: 2.9753 - learning_rate: 2.5000e-04
# Epoch 87/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8705 - loss: 0.3063 - val_accuracy: 0.3213 - val_loss: 2.8864 - learning_rate: 2.5000e-04
# Epoch 88/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8711 - loss: 0.2393 - val_accuracy: 0.3161 - val_loss: 2.9301 - learning_rate: 2.5000e-04
# Epoch 89/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8700 - loss: 0.2699 - val_accuracy: 0.2987 - val_loss: 3.0789 - learning_rate: 2.5000e-04
# Epoch 90/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9149 - loss: 0.2363 - val_accuracy: 0.2836 - val_loss: 3.2957 - learning_rate: 2.5000e-04
# Epoch 91/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9269 - loss: 0.2180 - val_accuracy: 0.2940 - val_loss: 3.3128 - learning_rate: 2.5000e-04
# Epoch 92/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8691 - loss: 0.3048 - val_accuracy: 0.3039 - val_loss: 3.2547 - learning_rate: 2.5000e-04
# Epoch 93/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9100 - loss: 0.2323 - val_accuracy: 0.3010 - val_loss: 3.2143 - learning_rate: 2.5000e-04
# Epoch 94/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8665 - loss: 0.2906 - val_accuracy: 0.2952 - val_loss: 3.2819 - learning_rate: 2.5000e-04
# Epoch 95/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8600 - loss: 0.4034 - val_accuracy: 0.2987 - val_loss: 3.2583 - learning_rate: 2.5000e-04
# Epoch 96/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8840 - loss: 0.2311 - val_accuracy: 0.2899 - val_loss: 3.3420 - learning_rate: 2.5000e-04
# Epoch 97/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8451 - loss: 0.3811 - val_accuracy: 0.2929 - val_loss: 3.3038 - learning_rate: 2.5000e-04
# Epoch 98/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9034 - loss: 0.2542 - val_accuracy: 0.2969 - val_loss: 3.2437 - learning_rate: 2.5000e-04
# Epoch 99/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8960 - loss: 0.2642 - val_accuracy: 0.3091 - val_loss: 3.1800 - learning_rate: 2.5000e-04
# Epoch 100/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8922 - loss: 0.2551 - val_accuracy: 0.3120 - val_loss: 3.2088 - learning_rate: 2.5000e-04
# Epoch 101/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8873 - loss: 0.2470 - val_accuracy: 0.3051 - val_loss: 3.3093 - learning_rate: 2.5000e-04
# Epoch 102/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8894 - loss: 0.2526 - val_accuracy: 0.3161 - val_loss: 3.2234 - learning_rate: 2.5000e-04
# Epoch 103/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8732 - loss: 0.2843 - val_accuracy: 0.3173 - val_loss: 3.1916 - learning_rate: 2.5000e-04
# Epoch 104/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9112 - loss: 0.2191 - val_accuracy: 0.3347 - val_loss: 3.0679 - learning_rate: 2.5000e-04
# Epoch 105/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8896 - loss: 0.2378 - val_accuracy: 0.3306 - val_loss: 3.0014 - learning_rate: 2.5000e-04
# Epoch 106/1000
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9062 - loss: 0.2687
# Epoch 106: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8924 - loss: 0.2463 - val_accuracy: 0.3364 - val_loss: 2.9354 - learning_rate: 2.5000e-04
# Epoch 107/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9180 - loss: 0.2359 - val_accuracy: 0.3329 - val_loss: 2.9793 - learning_rate: 1.2500e-04
# Epoch 108/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8888 - loss: 0.2356 - val_accuracy: 0.3219 - val_loss: 3.0519 - learning_rate: 1.2500e-04
# Epoch 109/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9169 - loss: 0.2220 - val_accuracy: 0.3196 - val_loss: 3.1266 - learning_rate: 1.2500e-04
# Epoch 110/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9022 - loss: 0.2117 - val_accuracy: 0.3155 - val_loss: 3.1746 - learning_rate: 1.2500e-04
# Epoch 111/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8968 - loss: 0.2296 - val_accuracy: 0.3126 - val_loss: 3.2471 - learning_rate: 1.2500e-04
# Epoch 112/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9070 - loss: 0.1998 - val_accuracy: 0.3120 - val_loss: 3.3190 - learning_rate: 1.2500e-04
# Epoch 113/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9538 - loss: 0.1615 - val_accuracy: 0.3207 - val_loss: 3.3241 - learning_rate: 1.2500e-04
# Epoch 114/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9170 - loss: 0.1827 - val_accuracy: 0.3260 - val_loss: 3.3402 - learning_rate: 1.2500e-04
# Epoch 115/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8836 - loss: 0.2288 - val_accuracy: 0.3219 - val_loss: 3.3986 - learning_rate: 1.2500e-04
# Epoch 116/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9129 - loss: 0.1923 - val_accuracy: 0.3161 - val_loss: 3.3944 - learning_rate: 1.2500e-04
# Epoch 117/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9104 - loss: 0.2424 - val_accuracy: 0.3161 - val_loss: 3.4154 - learning_rate: 1.2500e-04
# Epoch 118/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9397 - loss: 0.1637 - val_accuracy: 0.3190 - val_loss: 3.4570 - learning_rate: 1.2500e-04
# Epoch 119/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9217 - loss: 0.1727 - val_accuracy: 0.3155 - val_loss: 3.4825 - learning_rate: 1.2500e-04
# Epoch 120/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9223 - loss: 0.1935 - val_accuracy: 0.3120 - val_loss: 3.5578 - learning_rate: 1.2500e-04
# Epoch 121/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9296 - loss: 0.1997 - val_accuracy: 0.3109 - val_loss: 3.5528 - learning_rate: 1.2500e-04
# Epoch 122/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9249 - loss: 0.2001 - val_accuracy: 0.3190 - val_loss: 3.4762 - learning_rate: 1.2500e-04
# Epoch 123/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9553 - loss: 0.1091 - val_accuracy: 0.3213 - val_loss: 3.4224 - learning_rate: 1.2500e-04
# Epoch 124/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9105 - loss: 0.1947 - val_accuracy: 0.3155 - val_loss: 3.4106 - learning_rate: 1.2500e-04
# Epoch 125/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9458 - loss: 0.1663 - val_accuracy: 0.3103 - val_loss: 3.4611 - learning_rate: 1.2500e-04
# Epoch 126/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9003 - loss: 0.2157 - val_accuracy: 0.3155 - val_loss: 3.4686 - learning_rate: 1.2500e-04
# Epoch 127/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9158 - loss: 0.1860 - val_accuracy: 0.3138 - val_loss: 3.5170 - learning_rate: 1.2500e-04
# Epoch 128/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9354 - loss: 0.1883 - val_accuracy: 0.3144 - val_loss: 3.5822 - learning_rate: 1.2500e-04
# Epoch 129/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9141 - loss: 0.1538 - val_accuracy: 0.3126 - val_loss: 3.6332 - learning_rate: 1.2500e-04
# Epoch 130/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9098 - loss: 0.2181 - val_accuracy: 0.3149 - val_loss: 3.6010 - learning_rate: 1.2500e-04
# Epoch 131/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9103 - loss: 0.2089 - val_accuracy: 0.3178 - val_loss: 3.5765 - learning_rate: 1.2500e-04
# Epoch 132/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9505 - loss: 0.1652 - val_accuracy: 0.3155 - val_loss: 3.5797 - learning_rate: 1.2500e-04
# Epoch 133/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9405 - loss: 0.1324 - val_accuracy: 0.3190 - val_loss: 3.5988 - learning_rate: 1.2500e-04
# Epoch 134/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9489 - loss: 0.1240 - val_accuracy: 0.3225 - val_loss: 3.6123 - learning_rate: 1.2500e-04
# Epoch 135/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9274 - loss: 0.1475 - val_accuracy: 0.3271 - val_loss: 3.5851 - learning_rate: 1.2500e-04
# Epoch 136/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9373 - loss: 0.1417 - val_accuracy: 0.3295 - val_loss: 3.5929 - learning_rate: 1.2500e-04
# Epoch 137/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9441 - loss: 0.1358 - val_accuracy: 0.3236 - val_loss: 3.6266 - learning_rate: 1.2500e-04
# Epoch 138/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9212 - loss: 0.1692 - val_accuracy: 0.3260 - val_loss: 3.6406 - learning_rate: 1.2500e-04
# Epoch 139/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9331 - loss: 0.1841 - val_accuracy: 0.3231 - val_loss: 3.6645 - learning_rate: 1.2500e-04
# Epoch 140/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9070 - loss: 0.1511 - val_accuracy: 0.3231 - val_loss: 3.6467 - learning_rate: 1.2500e-04
# Epoch 141/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9343 - loss: 0.1678 - val_accuracy: 0.3225 - val_loss: 3.6639 - learning_rate: 1.2500e-04
# Epoch 142/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9700 - loss: 0.1035 - val_accuracy: 0.3236 - val_loss: 3.6731 - learning_rate: 1.2500e-04
# Epoch 143/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9310 - loss: 0.1897 - val_accuracy: 0.3114 - val_loss: 3.7509 - learning_rate: 1.2500e-04
# Epoch 144/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9283 - loss: 0.1799 - val_accuracy: 0.3132 - val_loss: 3.7784 - learning_rate: 1.2500e-04
# Epoch 145/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9632 - loss: 0.1059 - val_accuracy: 0.3202 - val_loss: 3.8025 - learning_rate: 1.2500e-04
# Epoch 146/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9555 - loss: 0.1435 - val_accuracy: 0.3213 - val_loss: 3.8397 - learning_rate: 1.2500e-04
# Epoch 147/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9450 - loss: 0.1316 - val_accuracy: 0.3219 - val_loss: 3.8293 - learning_rate: 1.2500e-04
# Epoch 148/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9501 - loss: 0.1479 - val_accuracy: 0.3295 - val_loss: 3.7829 - learning_rate: 1.2500e-04
# Epoch 149/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9573 - loss: 0.1361 - val_accuracy: 0.3347 - val_loss: 3.6791 - learning_rate: 1.2500e-04
# Epoch 150/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9507 - loss: 0.1419 - val_accuracy: 0.3417 - val_loss: 3.6156 - learning_rate: 1.2500e-04
# Epoch 151/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9365 - loss: 0.1471 - val_accuracy: 0.3341 - val_loss: 3.6671 - learning_rate: 1.2500e-04
# Epoch 152/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9266 - loss: 0.1985 - val_accuracy: 0.3295 - val_loss: 3.7787 - learning_rate: 1.2500e-04
# Epoch 153/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9346 - loss: 0.1561 - val_accuracy: 0.3324 - val_loss: 3.7990 - learning_rate: 1.2500e-04
# Epoch 154/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9230 - loss: 0.1632 - val_accuracy: 0.3399 - val_loss: 3.6755 - learning_rate: 1.2500e-04
# Epoch 155/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9526 - loss: 0.1613 - val_accuracy: 0.3405 - val_loss: 3.6231 - learning_rate: 1.2500e-04
# Epoch 156/1000
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9375 - loss: 0.1186
# Epoch 156: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9309 - loss: 0.1347 - val_accuracy: 0.3393 - val_loss: 3.6228 - learning_rate: 1.2500e-04
# Epoch 157/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9753 - loss: 0.0798 - val_accuracy: 0.3388 - val_loss: 3.6354 - learning_rate: 6.2500e-05
# Epoch 158/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9548 - loss: 0.1125 - val_accuracy: 0.3376 - val_loss: 3.6539 - learning_rate: 6.2500e-05
# Epoch 159/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9396 - loss: 0.1613 - val_accuracy: 0.3359 - val_loss: 3.6688 - learning_rate: 6.2500e-05
# Epoch 160/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9916 - loss: 0.0797 - val_accuracy: 0.3347 - val_loss: 3.6970 - learning_rate: 6.2500e-05
# Epoch 161/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9566 - loss: 0.0961 - val_accuracy: 0.3335 - val_loss: 3.7295 - learning_rate: 6.2500e-05
# Epoch 162/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9432 - loss: 0.1383 - val_accuracy: 0.3335 - val_loss: 3.7599 - learning_rate: 6.2500e-05
# Epoch 163/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9462 - loss: 0.1246 - val_accuracy: 0.3329 - val_loss: 3.7832 - learning_rate: 6.2500e-05
# Epoch 164/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9264 - loss: 0.1315 - val_accuracy: 0.3318 - val_loss: 3.7730 - learning_rate: 6.2500e-05
# Epoch 165/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9655 - loss: 0.1195 - val_accuracy: 0.3341 - val_loss: 3.7723 - learning_rate: 6.2500e-05
# Epoch 166/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9528 - loss: 0.0846 - val_accuracy: 0.3312 - val_loss: 3.8727 - learning_rate: 6.2500e-05
# Epoch 167/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9409 - loss: 0.1491 - val_accuracy: 0.3277 - val_loss: 3.8961 - learning_rate: 6.2500e-05
# Epoch 168/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9824 - loss: 0.0744 - val_accuracy: 0.3277 - val_loss: 3.8961 - learning_rate: 6.2500e-05
# Epoch 169/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9482 - loss: 0.1040 - val_accuracy: 0.3260 - val_loss: 3.9127 - learning_rate: 6.2500e-05
# Epoch 170/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9579 - loss: 0.1017 - val_accuracy: 0.3277 - val_loss: 3.9015 - learning_rate: 6.2500e-05
# Epoch 171/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9678 - loss: 0.0754 - val_accuracy: 0.3271 - val_loss: 3.8934 - learning_rate: 6.2500e-05
# Epoch 172/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9621 - loss: 0.1015 - val_accuracy: 0.3289 - val_loss: 3.8901 - learning_rate: 6.2500e-05
# Epoch 173/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9484 - loss: 0.1396 - val_accuracy: 0.3295 - val_loss: 3.9041 - learning_rate: 6.2500e-05
# Epoch 174/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9751 - loss: 0.0710 - val_accuracy: 0.3318 - val_loss: 3.8850 - learning_rate: 6.2500e-05
# Epoch 175/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9701 - loss: 0.1055 - val_accuracy: 0.3295 - val_loss: 3.9296 - learning_rate: 6.2500e-05
# Epoch 176/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9702 - loss: 0.0852 - val_accuracy: 0.3271 - val_loss: 3.9731 - learning_rate: 6.2500e-05
# Epoch 177/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9548 - loss: 0.0878 - val_accuracy: 0.3283 - val_loss: 3.9860 - learning_rate: 6.2500e-05
# Epoch 178/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9466 - loss: 0.0950 - val_accuracy: 0.3312 - val_loss: 3.9833 - learning_rate: 6.2500e-05
# Epoch 179/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9640 - loss: 0.0900 - val_accuracy: 0.3341 - val_loss: 3.9800 - learning_rate: 6.2500e-05
# Epoch 180/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9517 - loss: 0.0947 - val_accuracy: 0.3353 - val_loss: 3.9729 - learning_rate: 6.2500e-05
# Epoch 181/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9517 - loss: 0.1127 - val_accuracy: 0.3318 - val_loss: 3.9777 - learning_rate: 6.2500e-05
# Epoch 182/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9681 - loss: 0.0805 - val_accuracy: 0.3306 - val_loss: 4.0019 - learning_rate: 6.2500e-05
# Epoch 183/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9591 - loss: 0.1101 - val_accuracy: 0.3318 - val_loss: 4.0050 - learning_rate: 6.2500e-05
# Epoch 184/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9701 - loss: 0.1069 - val_accuracy: 0.3300 - val_loss: 4.0155 - learning_rate: 6.2500e-05
# Epoch 185/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9771 - loss: 0.0550 - val_accuracy: 0.3283 - val_loss: 4.0340 - learning_rate: 6.2500e-05
# Epoch 186/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9610 - loss: 0.0800 - val_accuracy: 0.3277 - val_loss: 4.0254 - learning_rate: 6.2500e-05
# Epoch 187/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9865 - loss: 0.0739 - val_accuracy: 0.3289 - val_loss: 4.0180 - learning_rate: 6.2500e-05
# Epoch 188/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9658 - loss: 0.0897 - val_accuracy: 0.3283 - val_loss: 4.0306 - learning_rate: 6.2500e-05
# Epoch 189/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9470 - loss: 0.1418 - val_accuracy: 0.3318 - val_loss: 4.0384 - learning_rate: 6.2500e-05
# Epoch 190/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9712 - loss: 0.0598 - val_accuracy: 0.3329 - val_loss: 4.0134 - learning_rate: 6.2500e-05
# Epoch 191/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9516 - loss: 0.0775 - val_accuracy: 0.3329 - val_loss: 4.0187 - learning_rate: 6.2500e-05
# Epoch 192/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9700 - loss: 0.0760 - val_accuracy: 0.3300 - val_loss: 4.0419 - learning_rate: 6.2500e-05
# Epoch 193/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9592 - loss: 0.0890 - val_accuracy: 0.3295 - val_loss: 4.0734 - learning_rate: 6.2500e-05
# Epoch 194/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9875 - loss: 0.0904 - val_accuracy: 0.3289 - val_loss: 4.0620 - learning_rate: 6.2500e-05
# Epoch 195/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9488 - loss: 0.1288 - val_accuracy: 0.3364 - val_loss: 4.0230 - learning_rate: 6.2500e-05
# Epoch 196/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9722 - loss: 0.0674 - val_accuracy: 0.3399 - val_loss: 4.0186 - learning_rate: 6.2500e-05
# Epoch 197/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9564 - loss: 0.1083 - val_accuracy: 0.3370 - val_loss: 4.0246 - learning_rate: 6.2500e-05
# Epoch 198/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9656 - loss: 0.0855 - val_accuracy: 0.3300 - val_loss: 4.0755 - learning_rate: 6.2500e-05
# Epoch 199/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9745 - loss: 0.0800 - val_accuracy: 0.3254 - val_loss: 4.1104 - learning_rate: 6.2500e-05
# Epoch 200/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9712 - loss: 0.0735 - val_accuracy: 0.3283 - val_loss: 4.1145 - learning_rate: 6.2500e-05
# Epoch 201/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9837 - loss: 0.0659 - val_accuracy: 0.3283 - val_loss: 4.1191 - learning_rate: 6.2500e-05
# Epoch 202/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9628 - loss: 0.0807 - val_accuracy: 0.3254 - val_loss: 4.1121 - learning_rate: 6.2500e-05
# Epoch 203/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9571 - loss: 0.0944 - val_accuracy: 0.3260 - val_loss: 4.0910 - learning_rate: 6.2500e-05
# Epoch 204/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9695 - loss: 0.0947 - val_accuracy: 0.3231 - val_loss: 4.1081 - learning_rate: 6.2500e-05
# Epoch 205/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9644 - loss: 0.0726 - val_accuracy: 0.3236 - val_loss: 4.1113 - learning_rate: 6.2500e-05
# Epoch 206/1000
# 1/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9688 - loss: 0.1042
# Epoch 206: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9772 - loss: 0.0698 - val_accuracy: 0.3236 - val_loss: 4.1229 - learning_rate: 6.2500e-05
# Epoch 207/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9544 - loss: 0.1148 - val_accuracy: 0.3254 - val_loss: 4.0963 - learning_rate: 3.1250e-05
# Epoch 208/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9438 - loss: 0.0954 - val_accuracy: 0.3260 - val_loss: 4.0930 - learning_rate: 3.1250e-05
# Epoch 209/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9680 - loss: 0.0913 - val_accuracy: 0.3266 - val_loss: 4.0899 - learning_rate: 3.1250e-05
# Epoch 210/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9750 - loss: 0.0806 - val_accuracy: 0.3271 - val_loss: 4.0918 - learning_rate: 3.1250e-05
# Epoch 211/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9737 - loss: 0.0757 - val_accuracy: 0.3266 - val_loss: 4.0896 - learning_rate: 3.1250e-05
# Epoch 212/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9926 - loss: 0.0561 - val_accuracy: 0.3283 - val_loss: 4.0978 - learning_rate: 3.1250e-05
# Epoch 213/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9453 - loss: 0.1196 - val_accuracy: 0.3300 - val_loss: 4.1116 - learning_rate: 3.1250e-05
# Epoch 214/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9814 - loss: 0.0579 - val_accuracy: 0.3242 - val_loss: 4.1719 - learning_rate: 3.1250e-05
# Epoch 215/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9805 - loss: 0.0742 - val_accuracy: 0.3196 - val_loss: 4.2199 - learning_rate: 3.1250e-05
# Epoch 216/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9681 - loss: 0.0948 - val_accuracy: 0.3231 - val_loss: 4.1987 - learning_rate: 3.1250e-05
# Epoch 217/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9686 - loss: 0.0923 - val_accuracy: 0.3266 - val_loss: 4.1887 - learning_rate: 3.1250e-05
# Epoch 218/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9916 - loss: 0.0502 - val_accuracy: 0.3283 - val_loss: 4.1910 - learning_rate: 3.1250e-05
# Epoch 219/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9492 - loss: 0.1128 - val_accuracy: 0.3254 - val_loss: 4.1927 - learning_rate: 3.1250e-05
# Epoch 220/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9584 - loss: 0.0754 - val_accuracy: 0.3266 - val_loss: 4.2025 - learning_rate: 3.1250e-05
# Epoch 221/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9848 - loss: 0.0475 - val_accuracy: 0.3248 - val_loss: 4.2192 - learning_rate: 3.1250e-05
# Epoch 222/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9834 - loss: 0.0546 - val_accuracy: 0.3236 - val_loss: 4.2276 - learning_rate: 3.1250e-05
# Epoch 223/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9836 - loss: 0.0562 - val_accuracy: 0.3231 - val_loss: 4.2330 - learning_rate: 3.1250e-05
# Epoch 224/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9674 - loss: 0.0685 - val_accuracy: 0.3236 - val_loss: 4.2220 - learning_rate: 3.1250e-05
# Epoch 225/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9716 - loss: 0.0774 - val_accuracy: 0.3231 - val_loss: 4.2118 - learning_rate: 3.1250e-05
# Epoch 226/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9778 - loss: 0.0630 - val_accuracy: 0.3242 - val_loss: 4.2141 - learning_rate: 3.1250e-05
# Epoch 227/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9627 - loss: 0.0927 - val_accuracy: 0.3266 - val_loss: 4.2251 - learning_rate: 3.1250e-05
# Epoch 228/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9729 - loss: 0.0841 - val_accuracy: 0.3277 - val_loss: 4.2257 - learning_rate: 3.1250e-05
# Epoch 229/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9886 - loss: 0.0563 - val_accuracy: 0.3283 - val_loss: 4.2385 - learning_rate: 3.1250e-05
# Epoch 230/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9527 - loss: 0.1092 - val_accuracy: 0.3242 - val_loss: 4.2626 - learning_rate: 3.1250e-05
# Epoch 231/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9657 - loss: 0.0850 - val_accuracy: 0.3271 - val_loss: 4.2791 - learning_rate: 3.1250e-05
# Epoch 232/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9686 - loss: 0.0931 - val_accuracy: 0.3271 - val_loss: 4.2865 - learning_rate: 3.1250e-05
# Epoch 233/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9722 - loss: 0.0785 - val_accuracy: 0.3300 - val_loss: 4.2787 - learning_rate: 3.1250e-05
# Epoch 234/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9697 - loss: 0.0834 - val_accuracy: 0.3306 - val_loss: 4.2805 - learning_rate: 3.1250e-05
# Epoch 235/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9667 - loss: 0.0638 - val_accuracy: 0.3289 - val_loss: 4.2865 - learning_rate: 3.1250e-05
# Epoch 236/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9566 - loss: 0.0911 - val_accuracy: 0.3277 - val_loss: 4.2851 - learning_rate: 3.1250e-05
# Epoch 237/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9685 - loss: 0.0795 - val_accuracy: 0.3295 - val_loss: 4.2731 - learning_rate: 3.1250e-05
# Epoch 238/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9659 - loss: 0.0674 - val_accuracy: 0.3300 - val_loss: 4.2727 - learning_rate: 3.1250e-05
# Epoch 239/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9789 - loss: 0.0805 - val_accuracy: 0.3312 - val_loss: 4.2704 - learning_rate: 3.1250e-05
# Epoch 240/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9673 - loss: 0.0654 - val_accuracy: 0.3312 - val_loss: 4.2703 - learning_rate: 3.1250e-05
# Epoch 241/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9881 - loss: 0.0503 - val_accuracy: 0.3335 - val_loss: 4.2644 - learning_rate: 3.1250e-05
# Epoch 242/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9691 - loss: 0.0759 - val_accuracy: 0.3335 - val_loss: 4.2711 - learning_rate: 3.1250e-05
# Epoch 243/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9842 - loss: 0.0577 - val_accuracy: 0.3341 - val_loss: 4.2930 - learning_rate: 3.1250e-05
# Epoch 244/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9587 - loss: 0.0795 - val_accuracy: 0.3318 - val_loss: 4.3119 - learning_rate: 3.1250e-05
# Epoch 245/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9741 - loss: 0.0750 - val_accuracy: 0.3335 - val_loss: 4.3292 - learning_rate: 3.1250e-05
# Epoch 246/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9776 - loss: 0.0540 - val_accuracy: 0.3347 - val_loss: 4.3237 - learning_rate: 3.1250e-05
# Epoch 247/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9888 - loss: 0.0556 - val_accuracy: 0.3335 - val_loss: 4.3086 - learning_rate: 3.1250e-05
# Epoch 248/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9855 - loss: 0.0516 - val_accuracy: 0.3289 - val_loss: 4.2995 - learning_rate: 3.1250e-05
# Epoch 249/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9882 - loss: 0.0501 - val_accuracy: 0.3300 - val_loss: 4.2953 - learning_rate: 3.1250e-05
# Epoch 250/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9827 - loss: 0.0615 - val_accuracy: 0.3295 - val_loss: 4.2876 - learning_rate: 3.1250e-05
# Epoch 251/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9803 - loss: 0.0615 - val_accuracy: 0.3306 - val_loss: 4.2926 - learning_rate: 3.1250e-05
# Epoch 252/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9734 - loss: 0.0519 - val_accuracy: 0.3318 - val_loss: 4.2960 - learning_rate: 3.1250e-05
# Epoch 253/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9787 - loss: 0.0518 - val_accuracy: 0.3324 - val_loss: 4.2971 - learning_rate: 3.1250e-05
# Epoch 254/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9779 - loss: 0.0598 - val_accuracy: 0.3312 - val_loss: 4.3233 - learning_rate: 3.1250e-05
# Epoch 255/1000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9761 - loss: 0.0538 - val_accuracy: 0.3295 - val_loss: 4.3394 - learning_rate: 3.1250e-05
# Epoch 256/1000
# 8/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.0385
# Epoch 256: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9897 - loss: 0.0422 - val_accuracy: 0.3306 - val_loss: 4.3419 - learning_rate: 3.1250e-05
# Epoch 256: early stopping
# Restoring model weights from the end of the best epoch: 6.

# %%
# Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title(f'Modelo {1} - Accuracy vs Val_Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title(f'Modelo {1} - Loss vs Val_Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predicciones individuales de cada modelo
preds = model.predict(X_test)
final_preds = np.argmax(preds, axis=1)
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, final_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.arange(cm.shape[1]), yticklabels=np.arange(cm.shape[0]))
plt.title("Matriz de Confusión")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")
plt.show()

# %%
# Confusion Matrix with new split
cm = confusion_matrix(y_test, final_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.arange(cm.shape[1]), yticklabels=np.arange(cm.shape[0]))
plt.title("Matriz de Confusión")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")
plt.show()

# %%
# Classification report
print(classification_report(y_test, final_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.000     0.000     0.000         4
#            1      0.029     0.012     0.017        81
#            2      0.512     0.568     0.539       861
#            3      0.453     0.423     0.438       777
#
#     accuracy                          0.475      1723
#    macro avg      0.248     0.251     0.248      1723
# weighted avg      0.461     0.475     0.467      1723

# %%
# Classification report with New split
print(classification_report(y_test, final_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.020     0.077     0.031        13
#            1      0.059     0.149     0.085       121
#            2      0.521     0.468     0.493       887
#            3      0.386     0.315     0.347       701
#
#     accuracy                          0.380      1722
#    macro avg      0.247     0.252     0.239      1722
# weighted avg      0.430     0.380     0.402      1722

# %%
# Print UAR metric
def uar(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    uar = np.mean(np.diag(cm) / np.sum(cm, axis=1))
    return uar

uar_score = uar(y_test, final_preds)
print(f'UAR: {uar_score:.4f}')
# Out:
# UAR: 0.2522
