# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LSTM, Bidirectional, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
# Out:
# 2025-05-11 13:21:17.015381: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-11 13:21:17.026499: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-11 13:21:17.029819: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-11 13:21:17.038215: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Charge npy files
def charge_npy(path):
    X = np.load(path)
    y = np.load(path.replace('X', 'y'))
    return X, y

# %%
# Charge embeddings of Facenet for Train, Val and Test
path_train = '../../../../Facenet Embeddings/Train/X_train.npy'
path_val   = '../../../../Facenet Embeddings/Val/X_val.npy'
path_test  = '../../../../Facenet Embeddings/Test/X_test.npy'
X_train, y_train = charge_npy(path_train)
X_val, y_val = charge_npy(path_val)
X_test, y_test = charge_npy(path_test)

n_frames = 5
embedding_dim = 128

X_train = X_train.reshape((-1, n_frames, embedding_dim))
y_train = y_train[:, 4:8]
y_train = np.mean(y_train.reshape(-1, 5, 4), axis=1)
y_train = np.argmax(y_train, axis=1)

X_val = X_val.reshape((-1, n_frames, embedding_dim)) 
y_val = y_val[:, 4:8]
y_val = np.mean(y_val.reshape(-1, 5, 4), axis=1)
y_val = np.argmax(y_val, axis=1)

X_test = X_test.reshape((-1, n_frames, embedding_dim))  
y_test = y_test[:, 4:8]
y_test = np.mean(y_test.reshape(-1, 5, 4), axis=1)
y_test = np.argmax(y_test, axis=1)

X = np.concatenate((X_val, X_test), axis=0)
y = np.concatenate((y_val, y_test), axis=0)

# %%
# Divide data in Val and test
X_val, X_test, y_val, y_test = train_test_split(X, y, test_size=0.5, random_state=123, stratify=y)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((5481, 5, 128), (1721, 5, 128), (1722, 5, 128), (5481,), (1721,), (1722,))

# %%
# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 40.3014705882353,
#  1: 6.40303738317757,
#  2: 0.5172706681766704,
#  3: 0.5302825077399381}

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=250, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=100, verbose=1)

# BILSTM model
def build_bilstm_model(input_shape):
    inputs = Input(shape=input_shape)
    
    # 1st BiLSTM
    x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(inputs)
    
    # 2nd BiLSTM
    x = Bidirectional(LSTM(64, return_sequences=True, dropout=0.3, recurrent_dropout=0.3))(x)
    
    # Global Pooling 
    x = GlobalAveragePooling1D()(x)
    
    # Dense + Dropout
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    outputs = Dense(4, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(1e-4), metrics=["accuracy"])
    
    return model

# Create and train the BILSTM model
model = build_bilstm_model((X_train.shape[1], X_train.shape[2]))

history = model.fit(
    X_train,
    y_train,
    class_weight=class_weights,
    epochs=1000,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746987739.963748   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987739.991813   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987739.991884   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987739.995558   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987739.995680   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987739.995725   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987740.147277   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1746987740.147398   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-11 13:22:20.147409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1746987740.147475   35248 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-11 13:22:20.147500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2246 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 39s 172ms/step - accuracy: 0.3132 - loss: 1.2946 - val_accuracy: 0.3928 - val_loss: 1.3340 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.3330 - loss: 1.3946 - val_accuracy: 0.3393 - val_loss: 1.3366 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.3459 - loss: 1.3351 - val_accuracy: 0.3359 - val_loss: 1.3326 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.3124 - loss: 1.4235 - val_accuracy: 0.3219 - val_loss: 1.3367 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.3523 - loss: 1.3061 - val_accuracy: 0.3033 - val_loss: 1.3369 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 165ms/step - accuracy: 0.3774 - loss: 1.2862 - val_accuracy: 0.2998 - val_loss: 1.3460 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.3560 - loss: 1.3434 - val_accuracy: 0.3114 - val_loss: 1.3108 - learning_rate: 1.0000e-04
# Epoch 8/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3738 - loss: 1.2354 - val_accuracy: 0.3021 - val_loss: 1.3399 - learning_rate: 1.0000e-04
# Epoch 9/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.3645 - loss: 1.2393 - val_accuracy: 0.2888 - val_loss: 1.3683 - learning_rate: 1.0000e-04
# Epoch 10/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.3538 - loss: 1.1850 - val_accuracy: 0.2934 - val_loss: 1.3511 - learning_rate: 1.0000e-04
# Epoch 11/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3476 - loss: 1.2827 - val_accuracy: 0.3353 - val_loss: 1.2616 - learning_rate: 1.0000e-04
# Epoch 12/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3819 - loss: 1.2068 - val_accuracy: 0.3016 - val_loss: 1.3083 - learning_rate: 1.0000e-04
# Epoch 13/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3706 - loss: 1.1250 - val_accuracy: 0.2865 - val_loss: 1.3661 - learning_rate: 1.0000e-04
# Epoch 14/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.3862 - loss: 1.1092 - val_accuracy: 0.3190 - val_loss: 1.2752 - learning_rate: 1.0000e-04
# Epoch 15/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.3564 - loss: 1.2358 - val_accuracy: 0.3132 - val_loss: 1.2413 - learning_rate: 1.0000e-04
# Epoch 16/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4034 - loss: 1.0495 - val_accuracy: 0.3126 - val_loss: 1.2885 - learning_rate: 1.0000e-04
# Epoch 17/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.3623 - loss: 1.1095 - val_accuracy: 0.3161 - val_loss: 1.2781 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4144 - loss: 1.0203 - val_accuracy: 0.3051 - val_loss: 1.3157 - learning_rate: 1.0000e-04
# Epoch 19/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.3908 - loss: 1.1080 - val_accuracy: 0.3248 - val_loss: 1.2241 - learning_rate: 1.0000e-04
# Epoch 20/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4123 - loss: 1.0398 - val_accuracy: 0.3207 - val_loss: 1.2424 - learning_rate: 1.0000e-04
# Epoch 21/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.3673 - loss: 1.1658 - val_accuracy: 0.3736 - val_loss: 1.1821 - learning_rate: 1.0000e-04
# Epoch 22/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4057 - loss: 1.1259 - val_accuracy: 0.3568 - val_loss: 1.1965 - learning_rate: 1.0000e-04
# Epoch 23/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4297 - loss: 1.0838 - val_accuracy: 0.3759 - val_loss: 1.1453 - learning_rate: 1.0000e-04
# Epoch 24/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4295 - loss: 1.0429 - val_accuracy: 0.3574 - val_loss: 1.1802 - learning_rate: 1.0000e-04
# Epoch 25/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4131 - loss: 1.0523 - val_accuracy: 0.3359 - val_loss: 1.2174 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4006 - loss: 1.0125 - val_accuracy: 0.3388 - val_loss: 1.2370 - learning_rate: 1.0000e-04
# Epoch 27/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4228 - loss: 1.0423 - val_accuracy: 0.3870 - val_loss: 1.1658 - learning_rate: 1.0000e-04
# Epoch 28/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4313 - loss: 1.0061 - val_accuracy: 0.3132 - val_loss: 1.2544 - learning_rate: 1.0000e-04
# Epoch 29/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4208 - loss: 0.9868 - val_accuracy: 0.3475 - val_loss: 1.2195 - learning_rate: 1.0000e-04
# Epoch 30/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4339 - loss: 0.9605 - val_accuracy: 0.3858 - val_loss: 1.1546 - learning_rate: 1.0000e-04
# Epoch 31/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4421 - loss: 1.0605 - val_accuracy: 0.3457 - val_loss: 1.1935 - learning_rate: 1.0000e-04
# Epoch 32/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4224 - loss: 0.9560 - val_accuracy: 0.3730 - val_loss: 1.1908 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4386 - loss: 1.0056 - val_accuracy: 0.3202 - val_loss: 1.2474 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4319 - loss: 1.0358 - val_accuracy: 0.3788 - val_loss: 1.1615 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4422 - loss: 1.0215 - val_accuracy: 0.3614 - val_loss: 1.1992 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4355 - loss: 0.9332 - val_accuracy: 0.3637 - val_loss: 1.2017 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4187 - loss: 0.9220 - val_accuracy: 0.3626 - val_loss: 1.1933 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4422 - loss: 0.9277 - val_accuracy: 0.3515 - val_loss: 1.2418 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4449 - loss: 0.8966 - val_accuracy: 0.3359 - val_loss: 1.2552 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4390 - loss: 0.9692 - val_accuracy: 0.3655 - val_loss: 1.1721 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4479 - loss: 0.9060 - val_accuracy: 0.3138 - val_loss: 1.2507 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4165 - loss: 0.8989 - val_accuracy: 0.3579 - val_loss: 1.1855 - learning_rate: 1.0000e-04
# Epoch 43/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.4366 - loss: 0.9634 - val_accuracy: 0.3736 - val_loss: 1.1941 - learning_rate: 1.0000e-04
# Epoch 44/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4662 - loss: 0.9426 - val_accuracy: 0.3725 - val_loss: 1.1798 - learning_rate: 1.0000e-04
# Epoch 45/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4500 - loss: 0.9159 - val_accuracy: 0.3661 - val_loss: 1.2151 - learning_rate: 1.0000e-04
# Epoch 46/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4531 - loss: 0.9280 - val_accuracy: 0.3422 - val_loss: 1.2440 - learning_rate: 1.0000e-04
# Epoch 47/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4548 - loss: 0.9078 - val_accuracy: 0.3376 - val_loss: 1.2320 - learning_rate: 1.0000e-04
# Epoch 48/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4243 - loss: 0.9481 - val_accuracy: 0.3242 - val_loss: 1.2699 - learning_rate: 1.0000e-04
# Epoch 49/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4580 - loss: 0.9223 - val_accuracy: 0.3359 - val_loss: 1.2616 - learning_rate: 1.0000e-04
# Epoch 50/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 41s 160ms/step - accuracy: 0.4308 - loss: 0.9422 - val_accuracy: 0.3574 - val_loss: 1.1979 - learning_rate: 1.0000e-04
# Epoch 51/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4739 - loss: 0.8395 - val_accuracy: 0.3504 - val_loss: 1.1923 - learning_rate: 1.0000e-04
# Epoch 52/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4560 - loss: 0.8540 - val_accuracy: 0.3010 - val_loss: 1.3263 - learning_rate: 1.0000e-04
# Epoch 53/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4493 - loss: 0.8778 - val_accuracy: 0.3544 - val_loss: 1.1978 - learning_rate: 1.0000e-04
# Epoch 54/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4645 - loss: 0.9651 - val_accuracy: 0.3585 - val_loss: 1.2036 - learning_rate: 1.0000e-04
# Epoch 55/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4703 - loss: 0.8967 - val_accuracy: 0.3504 - val_loss: 1.2219 - learning_rate: 1.0000e-04
# Epoch 56/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4552 - loss: 0.9107 - val_accuracy: 0.3399 - val_loss: 1.2779 - learning_rate: 1.0000e-04
# Epoch 57/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4586 - loss: 0.9125 - val_accuracy: 0.3300 - val_loss: 1.2457 - learning_rate: 1.0000e-04
# Epoch 58/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4617 - loss: 0.8442 - val_accuracy: 0.3492 - val_loss: 1.2173 - learning_rate: 1.0000e-04
# Epoch 59/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4572 - loss: 0.8336 - val_accuracy: 0.3225 - val_loss: 1.3160 - learning_rate: 1.0000e-04
# Epoch 60/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4451 - loss: 0.8703 - val_accuracy: 0.3574 - val_loss: 1.2408 - learning_rate: 1.0000e-04
# Epoch 61/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4766 - loss: 0.8801 - val_accuracy: 0.3574 - val_loss: 1.1951 - learning_rate: 1.0000e-04
# Epoch 62/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4733 - loss: 0.8241 - val_accuracy: 0.3603 - val_loss: 1.1793 - learning_rate: 1.0000e-04
# Epoch 63/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4757 - loss: 1.0068 - val_accuracy: 0.3422 - val_loss: 1.2647 - learning_rate: 1.0000e-04
# Epoch 64/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4700 - loss: 0.8710 - val_accuracy: 0.3626 - val_loss: 1.2058 - learning_rate: 1.0000e-04
# Epoch 65/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4892 - loss: 0.8232 - val_accuracy: 0.3417 - val_loss: 1.2536 - learning_rate: 1.0000e-04
# Epoch 66/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4746 - loss: 0.8619 - val_accuracy: 0.3283 - val_loss: 1.2852 - learning_rate: 1.0000e-04
# Epoch 67/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4585 - loss: 0.8421 - val_accuracy: 0.3254 - val_loss: 1.2758 - learning_rate: 1.0000e-04
# Epoch 68/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4430 - loss: 0.8460 - val_accuracy: 0.3858 - val_loss: 1.1427 - learning_rate: 1.0000e-04
# Epoch 69/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4689 - loss: 0.8390 - val_accuracy: 0.3486 - val_loss: 1.2670 - learning_rate: 1.0000e-04
# Epoch 70/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4738 - loss: 0.8726 - val_accuracy: 0.3655 - val_loss: 1.2180 - learning_rate: 1.0000e-04
# Epoch 71/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4789 - loss: 0.8418 - val_accuracy: 0.3074 - val_loss: 1.3120 - learning_rate: 1.0000e-04
# Epoch 72/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4475 - loss: 0.8379 - val_accuracy: 0.3173 - val_loss: 1.3247 - learning_rate: 1.0000e-04
# Epoch 73/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4470 - loss: 0.8571 - val_accuracy: 0.3411 - val_loss: 1.2363 - learning_rate: 1.0000e-04
# Epoch 74/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4746 - loss: 0.8616 - val_accuracy: 0.3690 - val_loss: 1.1790 - learning_rate: 1.0000e-04
# Epoch 75/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4830 - loss: 0.8226 - val_accuracy: 0.3289 - val_loss: 1.2865 - learning_rate: 1.0000e-04
# Epoch 76/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4874 - loss: 0.8702 - val_accuracy: 0.3562 - val_loss: 1.2101 - learning_rate: 1.0000e-04
# Epoch 77/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5063 - loss: 0.8006 - val_accuracy: 0.3202 - val_loss: 1.2614 - learning_rate: 1.0000e-04
# Epoch 78/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4794 - loss: 0.8436 - val_accuracy: 0.3184 - val_loss: 1.2753 - learning_rate: 1.0000e-04
# Epoch 79/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.4846 - loss: 0.8142 - val_accuracy: 0.3329 - val_loss: 1.2379 - learning_rate: 1.0000e-04
# Epoch 80/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4767 - loss: 0.8144 - val_accuracy: 0.3056 - val_loss: 1.3136 - learning_rate: 1.0000e-04
# Epoch 81/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4688 - loss: 0.8115 - val_accuracy: 0.3364 - val_loss: 1.2323 - learning_rate: 1.0000e-04
# Epoch 82/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4699 - loss: 0.8172 - val_accuracy: 0.3300 - val_loss: 1.2753 - learning_rate: 1.0000e-04
# Epoch 83/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4860 - loss: 0.8066 - val_accuracy: 0.3399 - val_loss: 1.2347 - learning_rate: 1.0000e-04
# Epoch 84/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.4917 - loss: 0.7781 - val_accuracy: 0.3260 - val_loss: 1.3125 - learning_rate: 1.0000e-04
# Epoch 85/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4840 - loss: 0.8329 - val_accuracy: 0.3341 - val_loss: 1.2385 - learning_rate: 1.0000e-04
# Epoch 86/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4771 - loss: 0.7881 - val_accuracy: 0.3585 - val_loss: 1.2151 - learning_rate: 1.0000e-04
# Epoch 87/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4808 - loss: 0.8204 - val_accuracy: 0.3562 - val_loss: 1.2146 - learning_rate: 1.0000e-04
# Epoch 88/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4768 - loss: 0.7928 - val_accuracy: 0.3202 - val_loss: 1.2915 - learning_rate: 1.0000e-04
# Epoch 89/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4916 - loss: 0.7711 - val_accuracy: 0.3324 - val_loss: 1.2674 - learning_rate: 1.0000e-04
# Epoch 90/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4774 - loss: 0.7778 - val_accuracy: 0.3289 - val_loss: 1.2726 - learning_rate: 1.0000e-04
# Epoch 91/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4745 - loss: 0.7824 - val_accuracy: 0.3155 - val_loss: 1.3063 - learning_rate: 1.0000e-04
# Epoch 92/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4815 - loss: 0.8154 - val_accuracy: 0.3469 - val_loss: 1.2698 - learning_rate: 1.0000e-04
# Epoch 93/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4988 - loss: 0.7995 - val_accuracy: 0.3510 - val_loss: 1.2467 - learning_rate: 1.0000e-04
# Epoch 94/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4818 - loss: 0.8101 - val_accuracy: 0.3207 - val_loss: 1.3074 - learning_rate: 1.0000e-04
# Epoch 95/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4883 - loss: 0.7931 - val_accuracy: 0.3277 - val_loss: 1.2671 - learning_rate: 1.0000e-04
# Epoch 96/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4844 - loss: 0.7700 - val_accuracy: 0.3364 - val_loss: 1.2507 - learning_rate: 1.0000e-04
# Epoch 97/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4837 - loss: 0.8040 - val_accuracy: 0.3236 - val_loss: 1.3402 - learning_rate: 1.0000e-04
# Epoch 98/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4924 - loss: 0.7450 - val_accuracy: 0.3236 - val_loss: 1.2778 - learning_rate: 1.0000e-04
# Epoch 99/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4927 - loss: 0.7808 - val_accuracy: 0.3329 - val_loss: 1.2947 - learning_rate: 1.0000e-04
# Epoch 100/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4716 - loss: 0.8040 - val_accuracy: 0.3103 - val_loss: 1.4355 - learning_rate: 1.0000e-04
# Epoch 101/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4811 - loss: 0.8685 - val_accuracy: 0.3359 - val_loss: 1.2449 - learning_rate: 1.0000e-04
# Epoch 102/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4935 - loss: 0.7682 - val_accuracy: 0.3440 - val_loss: 1.2469 - learning_rate: 1.0000e-04
# Epoch 103/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5136 - loss: 0.7199 - val_accuracy: 0.3318 - val_loss: 1.2850 - learning_rate: 1.0000e-04
# Epoch 104/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4727 - loss: 0.8362 - val_accuracy: 0.3446 - val_loss: 1.2583 - learning_rate: 1.0000e-04
# Epoch 105/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4860 - loss: 0.8282 - val_accuracy: 0.3434 - val_loss: 1.2789 - learning_rate: 1.0000e-04
# Epoch 106/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4976 - loss: 0.7591 - val_accuracy: 0.3428 - val_loss: 1.2598 - learning_rate: 1.0000e-04
# Epoch 107/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4855 - loss: 0.8139 - val_accuracy: 0.3457 - val_loss: 1.2630 - learning_rate: 1.0000e-04
# Epoch 108/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4848 - loss: 0.7981 - val_accuracy: 0.3736 - val_loss: 1.1812 - learning_rate: 1.0000e-04
# Epoch 109/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5152 - loss: 0.7667 - val_accuracy: 0.3370 - val_loss: 1.2580 - learning_rate: 1.0000e-04
# Epoch 110/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5131 - loss: 0.7414 - val_accuracy: 0.3568 - val_loss: 1.2370 - learning_rate: 1.0000e-04
# Epoch 111/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4921 - loss: 0.7798 - val_accuracy: 0.3364 - val_loss: 1.2914 - learning_rate: 1.0000e-04
# Epoch 112/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4866 - loss: 0.7794 - val_accuracy: 0.3440 - val_loss: 1.2751 - learning_rate: 1.0000e-04
# Epoch 113/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4831 - loss: 0.7897 - val_accuracy: 0.3341 - val_loss: 1.2913 - learning_rate: 1.0000e-04
# Epoch 114/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5102 - loss: 0.7641 - val_accuracy: 0.3388 - val_loss: 1.2959 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5020 - loss: 0.8942 - val_accuracy: 0.3626 - val_loss: 1.2217 - learning_rate: 1.0000e-04
# Epoch 116/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4913 - loss: 0.7619 - val_accuracy: 0.3248 - val_loss: 1.3215 - learning_rate: 1.0000e-04
# Epoch 117/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4927 - loss: 0.7247 - val_accuracy: 0.3434 - val_loss: 1.2659 - learning_rate: 1.0000e-04
# Epoch 118/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4755 - loss: 0.7362
# Epoch 118: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4755 - loss: 0.7362 - val_accuracy: 0.3492 - val_loss: 1.2434 - learning_rate: 1.0000e-04
# Epoch 119/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5064 - loss: 0.7300 - val_accuracy: 0.3451 - val_loss: 1.2725 - learning_rate: 5.0000e-05
# Epoch 120/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4960 - loss: 0.7049 - val_accuracy: 0.3341 - val_loss: 1.3002 - learning_rate: 5.0000e-05
# Epoch 121/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4769 - loss: 0.7294 - val_accuracy: 0.3469 - val_loss: 1.2783 - learning_rate: 5.0000e-05
# Epoch 122/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.4915 - loss: 0.7321 - val_accuracy: 0.3510 - val_loss: 1.2470 - learning_rate: 5.0000e-05
# Epoch 123/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5100 - loss: 0.7200 - val_accuracy: 0.3475 - val_loss: 1.3135 - learning_rate: 5.0000e-05
# Epoch 124/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.4758 - loss: 0.7465 - val_accuracy: 0.3411 - val_loss: 1.3161 - learning_rate: 5.0000e-05
# Epoch 125/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5108 - loss: 0.7172 - val_accuracy: 0.3597 - val_loss: 1.2585 - learning_rate: 5.0000e-05
# Epoch 126/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5119 - loss: 0.6983 - val_accuracy: 0.3411 - val_loss: 1.3029 - learning_rate: 5.0000e-05
# Epoch 127/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5049 - loss: 0.7226 - val_accuracy: 0.3492 - val_loss: 1.2802 - learning_rate: 5.0000e-05
# Epoch 128/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5036 - loss: 0.6973 - val_accuracy: 0.3422 - val_loss: 1.3041 - learning_rate: 5.0000e-05
# Epoch 129/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4950 - loss: 0.7308 - val_accuracy: 0.3417 - val_loss: 1.3456 - learning_rate: 5.0000e-05
# Epoch 130/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4958 - loss: 0.7123 - val_accuracy: 0.3759 - val_loss: 1.2276 - learning_rate: 5.0000e-05
# Epoch 131/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5192 - loss: 0.7145 - val_accuracy: 0.3504 - val_loss: 1.3071 - learning_rate: 5.0000e-05
# Epoch 132/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.4876 - loss: 0.7780 - val_accuracy: 0.3492 - val_loss: 1.3015 - learning_rate: 5.0000e-05
# Epoch 133/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4854 - loss: 0.7277 - val_accuracy: 0.3719 - val_loss: 1.2578 - learning_rate: 5.0000e-05
# Epoch 134/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5159 - loss: 0.6873 - val_accuracy: 0.3440 - val_loss: 1.3342 - learning_rate: 5.0000e-05
# Epoch 135/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4987 - loss: 0.7224 - val_accuracy: 0.3626 - val_loss: 1.2625 - learning_rate: 5.0000e-05
# Epoch 136/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5175 - loss: 0.7122 - val_accuracy: 0.3521 - val_loss: 1.2961 - learning_rate: 5.0000e-05
# Epoch 137/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5103 - loss: 0.6538 - val_accuracy: 0.3626 - val_loss: 1.2698 - learning_rate: 5.0000e-05
# Epoch 138/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5036 - loss: 0.6912 - val_accuracy: 0.3527 - val_loss: 1.2908 - learning_rate: 5.0000e-05
# Epoch 139/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5101 - loss: 0.7721 - val_accuracy: 0.3469 - val_loss: 1.3238 - learning_rate: 5.0000e-05
# Epoch 140/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5085 - loss: 0.7105 - val_accuracy: 0.3544 - val_loss: 1.2995 - learning_rate: 5.0000e-05
# Epoch 141/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5117 - loss: 0.7312 - val_accuracy: 0.3492 - val_loss: 1.3239 - learning_rate: 5.0000e-05
# Epoch 142/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5138 - loss: 0.6765 - val_accuracy: 0.3574 - val_loss: 1.2939 - learning_rate: 5.0000e-05
# Epoch 143/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.4953 - loss: 0.7629 - val_accuracy: 0.3620 - val_loss: 1.2860 - learning_rate: 5.0000e-05
# Epoch 144/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5184 - loss: 0.7117 - val_accuracy: 0.3550 - val_loss: 1.3154 - learning_rate: 5.0000e-05
# Epoch 145/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5135 - loss: 0.6830 - val_accuracy: 0.3556 - val_loss: 1.3259 - learning_rate: 5.0000e-05
# Epoch 146/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5151 - loss: 0.7188 - val_accuracy: 0.3684 - val_loss: 1.2850 - learning_rate: 5.0000e-05
# Epoch 147/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5105 - loss: 0.6918 - val_accuracy: 0.3539 - val_loss: 1.3294 - learning_rate: 5.0000e-05
# Epoch 148/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5074 - loss: 0.8130 - val_accuracy: 0.3597 - val_loss: 1.3108 - learning_rate: 5.0000e-05
# Epoch 149/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5065 - loss: 0.7050 - val_accuracy: 0.3469 - val_loss: 1.3268 - learning_rate: 5.0000e-05
# Epoch 150/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 165ms/step - accuracy: 0.5027 - loss: 0.7028 - val_accuracy: 0.3614 - val_loss: 1.2976 - learning_rate: 5.0000e-05
# Epoch 151/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 165ms/step - accuracy: 0.5206 - loss: 0.6952 - val_accuracy: 0.3603 - val_loss: 1.3028 - learning_rate: 5.0000e-05
# Epoch 152/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5308 - loss: 0.6991 - val_accuracy: 0.3486 - val_loss: 1.3183 - learning_rate: 5.0000e-05
# Epoch 153/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5086 - loss: 0.6872 - val_accuracy: 0.3498 - val_loss: 1.3289 - learning_rate: 5.0000e-05
# Epoch 154/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4946 - loss: 0.7324 - val_accuracy: 0.3521 - val_loss: 1.3155 - learning_rate: 5.0000e-05
# Epoch 155/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5127 - loss: 0.6948 - val_accuracy: 0.3626 - val_loss: 1.2893 - learning_rate: 5.0000e-05
# Epoch 156/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5157 - loss: 0.7144 - val_accuracy: 0.3597 - val_loss: 1.2968 - learning_rate: 5.0000e-05
# Epoch 157/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.5224 - loss: 0.6721 - val_accuracy: 0.3591 - val_loss: 1.3219 - learning_rate: 5.0000e-05
# Epoch 158/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.5021 - loss: 0.7500 - val_accuracy: 0.3818 - val_loss: 1.2613 - learning_rate: 5.0000e-05
# Epoch 159/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5281 - loss: 0.6664 - val_accuracy: 0.3562 - val_loss: 1.3303 - learning_rate: 5.0000e-05
# Epoch 160/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 165ms/step - accuracy: 0.5146 - loss: 0.6798 - val_accuracy: 0.3574 - val_loss: 1.3286 - learning_rate: 5.0000e-05
# Epoch 161/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 164ms/step - accuracy: 0.5250 - loss: 0.7997 - val_accuracy: 0.3666 - val_loss: 1.2969 - learning_rate: 5.0000e-05
# Epoch 162/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5054 - loss: 0.6811 - val_accuracy: 0.3579 - val_loss: 1.3120 - learning_rate: 5.0000e-05
# Epoch 163/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5360 - loss: 0.7009 - val_accuracy: 0.3690 - val_loss: 1.2921 - learning_rate: 5.0000e-05
# Epoch 164/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5098 - loss: 0.7142 - val_accuracy: 0.3754 - val_loss: 1.2730 - learning_rate: 5.0000e-05
# Epoch 165/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5281 - loss: 0.6815 - val_accuracy: 0.3393 - val_loss: 1.3848 - learning_rate: 5.0000e-05
# Epoch 166/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5050 - loss: 0.6938 - val_accuracy: 0.3707 - val_loss: 1.2971 - learning_rate: 5.0000e-05
# Epoch 167/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5287 - loss: 0.6967 - val_accuracy: 0.3696 - val_loss: 1.3027 - learning_rate: 5.0000e-05
# Epoch 168/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5138 - loss: 0.7024
# Epoch 168: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5138 - loss: 0.7025 - val_accuracy: 0.3620 - val_loss: 1.3479 - learning_rate: 5.0000e-05
# Epoch 169/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5198 - loss: 0.6898 - val_accuracy: 0.3614 - val_loss: 1.3356 - learning_rate: 2.5000e-05
# Epoch 170/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5173 - loss: 0.7020 - val_accuracy: 0.3678 - val_loss: 1.3216 - learning_rate: 2.5000e-05
# Epoch 171/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5223 - loss: 0.7201 - val_accuracy: 0.3666 - val_loss: 1.3273 - learning_rate: 2.5000e-05
# Epoch 172/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.5258 - loss: 0.6679 - val_accuracy: 0.3614 - val_loss: 1.3391 - learning_rate: 2.5000e-05
# Epoch 173/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5261 - loss: 0.6997 - val_accuracy: 0.3672 - val_loss: 1.3122 - learning_rate: 2.5000e-05
# Epoch 174/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5215 - loss: 0.7247 - val_accuracy: 0.3736 - val_loss: 1.3114 - learning_rate: 2.5000e-05
# Epoch 175/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5130 - loss: 0.6542 - val_accuracy: 0.3643 - val_loss: 1.3327 - learning_rate: 2.5000e-05
# Epoch 176/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.5163 - loss: 0.6761 - val_accuracy: 0.3626 - val_loss: 1.3357 - learning_rate: 2.5000e-05
# Epoch 177/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5290 - loss: 0.6789 - val_accuracy: 0.3730 - val_loss: 1.3116 - learning_rate: 2.5000e-05
# Epoch 178/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5284 - loss: 0.7308 - val_accuracy: 0.3678 - val_loss: 1.3136 - learning_rate: 2.5000e-05
# Epoch 179/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5407 - loss: 0.6352 - val_accuracy: 0.3672 - val_loss: 1.3261 - learning_rate: 2.5000e-05
# Epoch 180/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 157ms/step - accuracy: 0.5324 - loss: 0.7068 - val_accuracy: 0.3614 - val_loss: 1.3314 - learning_rate: 2.5000e-05
# Epoch 181/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 157ms/step - accuracy: 0.5366 - loss: 0.6366 - val_accuracy: 0.3603 - val_loss: 1.3371 - learning_rate: 2.5000e-05
# Epoch 182/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5232 - loss: 0.6827 - val_accuracy: 0.3678 - val_loss: 1.3133 - learning_rate: 2.5000e-05
# Epoch 183/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5171 - loss: 0.6553 - val_accuracy: 0.3626 - val_loss: 1.3323 - learning_rate: 2.5000e-05
# Epoch 184/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5323 - loss: 0.6817 - val_accuracy: 0.3637 - val_loss: 1.3300 - learning_rate: 2.5000e-05
# Epoch 185/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5470 - loss: 0.6512 - val_accuracy: 0.3556 - val_loss: 1.3585 - learning_rate: 2.5000e-05
# Epoch 186/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5181 - loss: 0.6412 - val_accuracy: 0.3632 - val_loss: 1.3462 - learning_rate: 2.5000e-05
# Epoch 187/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5276 - loss: 0.6787 - val_accuracy: 0.3643 - val_loss: 1.3312 - learning_rate: 2.5000e-05
# Epoch 188/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5100 - loss: 0.6789 - val_accuracy: 0.3637 - val_loss: 1.3203 - learning_rate: 2.5000e-05
# Epoch 189/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5296 - loss: 0.6892 - val_accuracy: 0.3597 - val_loss: 1.3452 - learning_rate: 2.5000e-05
# Epoch 190/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5309 - loss: 0.6503 - val_accuracy: 0.3608 - val_loss: 1.3423 - learning_rate: 2.5000e-05
# Epoch 191/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5207 - loss: 0.7193 - val_accuracy: 0.3655 - val_loss: 1.3339 - learning_rate: 2.5000e-05
# Epoch 192/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5150 - loss: 0.6717 - val_accuracy: 0.3649 - val_loss: 1.3471 - learning_rate: 2.5000e-05
# Epoch 193/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5232 - loss: 0.6758 - val_accuracy: 0.3678 - val_loss: 1.3386 - learning_rate: 2.5000e-05
# Epoch 194/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5131 - loss: 0.6945 - val_accuracy: 0.3591 - val_loss: 1.3642 - learning_rate: 2.5000e-05
# Epoch 195/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5207 - loss: 0.6408 - val_accuracy: 0.3684 - val_loss: 1.3294 - learning_rate: 2.5000e-05
# Epoch 196/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5263 - loss: 0.6817 - val_accuracy: 0.3655 - val_loss: 1.3366 - learning_rate: 2.5000e-05
# Epoch 197/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5105 - loss: 0.6841 - val_accuracy: 0.3614 - val_loss: 1.3549 - learning_rate: 2.5000e-05
# Epoch 198/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5191 - loss: 0.6422 - val_accuracy: 0.3649 - val_loss: 1.3431 - learning_rate: 2.5000e-05
# Epoch 199/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5158 - loss: 0.6981 - val_accuracy: 0.3672 - val_loss: 1.3341 - learning_rate: 2.5000e-05
# Epoch 200/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5273 - loss: 0.6657 - val_accuracy: 0.3614 - val_loss: 1.3504 - learning_rate: 2.5000e-05
# Epoch 201/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5191 - loss: 0.6456 - val_accuracy: 0.3632 - val_loss: 1.3476 - learning_rate: 2.5000e-05
# Epoch 202/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5398 - loss: 0.6517 - val_accuracy: 0.3591 - val_loss: 1.3604 - learning_rate: 2.5000e-05
# Epoch 203/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5266 - loss: 0.6528 - val_accuracy: 0.3527 - val_loss: 1.3830 - learning_rate: 2.5000e-05
# Epoch 204/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5179 - loss: 0.6447 - val_accuracy: 0.3620 - val_loss: 1.3517 - learning_rate: 2.5000e-05
# Epoch 205/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5135 - loss: 0.6650 - val_accuracy: 0.3614 - val_loss: 1.3545 - learning_rate: 2.5000e-05
# Epoch 206/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5193 - loss: 0.7328 - val_accuracy: 0.3603 - val_loss: 1.3672 - learning_rate: 2.5000e-05
# Epoch 207/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5234 - loss: 0.7163 - val_accuracy: 0.3591 - val_loss: 1.3530 - learning_rate: 2.5000e-05
# Epoch 208/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5100 - loss: 0.6666 - val_accuracy: 0.3632 - val_loss: 1.3489 - learning_rate: 2.5000e-05
# Epoch 209/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5289 - loss: 0.6609 - val_accuracy: 0.3696 - val_loss: 1.3291 - learning_rate: 2.5000e-05
# Epoch 210/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5303 - loss: 0.6843 - val_accuracy: 0.3568 - val_loss: 1.3579 - learning_rate: 2.5000e-05
# Epoch 211/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5183 - loss: 0.6406 - val_accuracy: 0.3690 - val_loss: 1.3370 - learning_rate: 2.5000e-05
# Epoch 212/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5255 - loss: 0.6715 - val_accuracy: 0.3719 - val_loss: 1.3271 - learning_rate: 2.5000e-05
# Epoch 213/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5254 - loss: 0.7288 - val_accuracy: 0.3742 - val_loss: 1.3361 - learning_rate: 2.5000e-05
# Epoch 214/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5156 - loss: 0.6634 - val_accuracy: 0.3608 - val_loss: 1.3628 - learning_rate: 2.5000e-05
# Epoch 215/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5420 - loss: 0.6207 - val_accuracy: 0.3696 - val_loss: 1.3508 - learning_rate: 2.5000e-05
# Epoch 216/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5308 - loss: 0.6758 - val_accuracy: 0.3701 - val_loss: 1.3520 - learning_rate: 2.5000e-05
# Epoch 217/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5247 - loss: 0.6371 - val_accuracy: 0.3765 - val_loss: 1.3354 - learning_rate: 2.5000e-05
# Epoch 218/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5295 - loss: 0.6245
# Epoch 218: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5295 - loss: 0.6246 - val_accuracy: 0.3696 - val_loss: 1.3587 - learning_rate: 2.5000e-05
# Epoch 219/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5217 - loss: 0.6617 - val_accuracy: 0.3754 - val_loss: 1.3419 - learning_rate: 1.2500e-05
# Epoch 220/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5339 - loss: 0.6464 - val_accuracy: 0.3678 - val_loss: 1.3600 - learning_rate: 1.2500e-05
# Epoch 221/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5296 - loss: 0.7075 - val_accuracy: 0.3672 - val_loss: 1.3654 - learning_rate: 1.2500e-05
# Epoch 222/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5387 - loss: 0.6616 - val_accuracy: 0.3719 - val_loss: 1.3455 - learning_rate: 1.2500e-05
# Epoch 223/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5455 - loss: 0.6328 - val_accuracy: 0.3649 - val_loss: 1.3630 - learning_rate: 1.2500e-05
# Epoch 224/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5274 - loss: 0.6683 - val_accuracy: 0.3684 - val_loss: 1.3495 - learning_rate: 1.2500e-05
# Epoch 225/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5346 - loss: 0.6331 - val_accuracy: 0.3719 - val_loss: 1.3499 - learning_rate: 1.2500e-05
# Epoch 226/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5328 - loss: 0.6568 - val_accuracy: 0.3725 - val_loss: 1.3481 - learning_rate: 1.2500e-05
# Epoch 227/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5340 - loss: 0.6496 - val_accuracy: 0.3672 - val_loss: 1.3566 - learning_rate: 1.2500e-05
# Epoch 228/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5200 - loss: 0.6558 - val_accuracy: 0.3574 - val_loss: 1.3932 - learning_rate: 1.2500e-05
# Epoch 229/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5201 - loss: 0.6510 - val_accuracy: 0.3649 - val_loss: 1.3745 - learning_rate: 1.2500e-05
# Epoch 230/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5360 - loss: 0.6630 - val_accuracy: 0.3637 - val_loss: 1.3752 - learning_rate: 1.2500e-05
# Epoch 231/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5284 - loss: 0.6514 - val_accuracy: 0.3655 - val_loss: 1.3725 - learning_rate: 1.2500e-05
# Epoch 232/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5370 - loss: 0.6428 - val_accuracy: 0.3678 - val_loss: 1.3659 - learning_rate: 1.2500e-05
# Epoch 233/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5304 - loss: 0.6575 - val_accuracy: 0.3736 - val_loss: 1.3602 - learning_rate: 1.2500e-05
# Epoch 234/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5258 - loss: 0.6531 - val_accuracy: 0.3736 - val_loss: 1.3534 - learning_rate: 1.2500e-05
# Epoch 235/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5272 - loss: 0.6868 - val_accuracy: 0.3713 - val_loss: 1.3601 - learning_rate: 1.2500e-05
# Epoch 236/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5416 - loss: 0.6861 - val_accuracy: 0.3696 - val_loss: 1.3735 - learning_rate: 1.2500e-05
# Epoch 237/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5379 - loss: 0.6485 - val_accuracy: 0.3696 - val_loss: 1.3685 - learning_rate: 1.2500e-05
# Epoch 238/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5312 - loss: 0.6769 - val_accuracy: 0.3713 - val_loss: 1.3603 - learning_rate: 1.2500e-05
# Epoch 239/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5178 - loss: 0.6563 - val_accuracy: 0.3690 - val_loss: 1.3607 - learning_rate: 1.2500e-05
# Epoch 240/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5396 - loss: 0.6667 - val_accuracy: 0.3661 - val_loss: 1.3686 - learning_rate: 1.2500e-05
# Epoch 241/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5298 - loss: 0.6885 - val_accuracy: 0.3661 - val_loss: 1.3697 - learning_rate: 1.2500e-05
# Epoch 242/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5306 - loss: 0.6519 - val_accuracy: 0.3661 - val_loss: 1.3760 - learning_rate: 1.2500e-05
# Epoch 243/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5199 - loss: 0.6910 - val_accuracy: 0.3655 - val_loss: 1.3727 - learning_rate: 1.2500e-05
# Epoch 244/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5242 - loss: 0.6763 - val_accuracy: 0.3666 - val_loss: 1.3706 - learning_rate: 1.2500e-05
# Epoch 245/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5211 - loss: 0.7167 - val_accuracy: 0.3719 - val_loss: 1.3597 - learning_rate: 1.2500e-05
# Epoch 246/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5353 - loss: 0.6457 - val_accuracy: 0.3765 - val_loss: 1.3530 - learning_rate: 1.2500e-05
# Epoch 247/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5390 - loss: 0.6741 - val_accuracy: 0.3655 - val_loss: 1.3711 - learning_rate: 1.2500e-05
# Epoch 248/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5399 - loss: 0.6081 - val_accuracy: 0.3684 - val_loss: 1.3714 - learning_rate: 1.2500e-05
# Epoch 249/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5300 - loss: 0.6425 - val_accuracy: 0.3620 - val_loss: 1.3756 - learning_rate: 1.2500e-05
# Epoch 250/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5244 - loss: 0.6537 - val_accuracy: 0.3632 - val_loss: 1.3783 - learning_rate: 1.2500e-05
# Epoch 251/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5248 - loss: 0.6373 - val_accuracy: 0.3701 - val_loss: 1.3631 - learning_rate: 1.2500e-05
# Epoch 252/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5432 - loss: 0.6590 - val_accuracy: 0.3707 - val_loss: 1.3609 - learning_rate: 1.2500e-05
# Epoch 253/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5282 - loss: 0.6499 - val_accuracy: 0.3713 - val_loss: 1.3687 - learning_rate: 1.2500e-05
# Epoch 254/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5334 - loss: 0.6655 - val_accuracy: 0.3632 - val_loss: 1.3864 - learning_rate: 1.2500e-05
# Epoch 255/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5378 - loss: 0.6333 - val_accuracy: 0.3678 - val_loss: 1.3766 - learning_rate: 1.2500e-05
# Epoch 256/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5338 - loss: 0.6834 - val_accuracy: 0.3719 - val_loss: 1.3599 - learning_rate: 1.2500e-05
# Epoch 257/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5257 - loss: 0.6617 - val_accuracy: 0.3742 - val_loss: 1.3541 - learning_rate: 1.2500e-05
# Epoch 258/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5319 - loss: 0.6822 - val_accuracy: 0.3736 - val_loss: 1.3582 - learning_rate: 1.2500e-05
# Epoch 259/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5299 - loss: 0.6480 - val_accuracy: 0.3690 - val_loss: 1.3687 - learning_rate: 1.2500e-05
# Epoch 260/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5418 - loss: 0.7469 - val_accuracy: 0.3690 - val_loss: 1.3700 - learning_rate: 1.2500e-05
# Epoch 261/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5314 - loss: 0.6761 - val_accuracy: 0.3730 - val_loss: 1.3627 - learning_rate: 1.2500e-05
# Epoch 262/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5450 - loss: 0.6143 - val_accuracy: 0.3748 - val_loss: 1.3577 - learning_rate: 1.2500e-05
# Epoch 263/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5266 - loss: 0.6322 - val_accuracy: 0.3719 - val_loss: 1.3609 - learning_rate: 1.2500e-05
# Epoch 264/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5488 - loss: 0.6241 - val_accuracy: 0.3754 - val_loss: 1.3497 - learning_rate: 1.2500e-05
# Epoch 265/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5293 - loss: 0.6644 - val_accuracy: 0.3777 - val_loss: 1.3468 - learning_rate: 1.2500e-05
# Epoch 266/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5434 - loss: 0.6135 - val_accuracy: 0.3736 - val_loss: 1.3549 - learning_rate: 1.2500e-05
# Epoch 267/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5274 - loss: 0.6998 - val_accuracy: 0.3725 - val_loss: 1.3571 - learning_rate: 1.2500e-05
# Epoch 268/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5254 - loss: 0.6593
# Epoch 268: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5254 - loss: 0.6593 - val_accuracy: 0.3736 - val_loss: 1.3570 - learning_rate: 1.2500e-05
# Epoch 269/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5137 - loss: 0.6497 - val_accuracy: 0.3730 - val_loss: 1.3565 - learning_rate: 6.2500e-06
# Epoch 270/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5352 - loss: 0.6370 - val_accuracy: 0.3742 - val_loss: 1.3539 - learning_rate: 6.2500e-06
# Epoch 271/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5402 - loss: 0.6375 - val_accuracy: 0.3719 - val_loss: 1.3587 - learning_rate: 6.2500e-06
# Epoch 272/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 157ms/step - accuracy: 0.5461 - loss: 0.6502 - val_accuracy: 0.3725 - val_loss: 1.3591 - learning_rate: 6.2500e-06
# Epoch 273/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5366 - loss: 0.6722 - val_accuracy: 0.3696 - val_loss: 1.3684 - learning_rate: 6.2500e-06
# Epoch 274/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5292 - loss: 0.6389 - val_accuracy: 0.3725 - val_loss: 1.3612 - learning_rate: 6.2500e-06
# Epoch 275/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5382 - loss: 0.6132 - val_accuracy: 0.3742 - val_loss: 1.3527 - learning_rate: 6.2500e-06
# Epoch 276/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5408 - loss: 0.6417 - val_accuracy: 0.3730 - val_loss: 1.3568 - learning_rate: 6.2500e-06
# Epoch 277/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5351 - loss: 0.6187 - val_accuracy: 0.3725 - val_loss: 1.3601 - learning_rate: 6.2500e-06
# Epoch 278/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5328 - loss: 0.6291 - val_accuracy: 0.3754 - val_loss: 1.3565 - learning_rate: 6.2500e-06
# Epoch 279/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5329 - loss: 0.6702 - val_accuracy: 0.3748 - val_loss: 1.3561 - learning_rate: 6.2500e-06
# Epoch 280/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5185 - loss: 0.6666 - val_accuracy: 0.3707 - val_loss: 1.3632 - learning_rate: 6.2500e-06
# Epoch 281/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5395 - loss: 0.6313 - val_accuracy: 0.3719 - val_loss: 1.3635 - learning_rate: 6.2500e-06
# Epoch 282/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5201 - loss: 0.6395 - val_accuracy: 0.3707 - val_loss: 1.3663 - learning_rate: 6.2500e-06
# Epoch 283/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5228 - loss: 0.6395 - val_accuracy: 0.3696 - val_loss: 1.3701 - learning_rate: 6.2500e-06
# Epoch 284/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5182 - loss: 0.6401 - val_accuracy: 0.3736 - val_loss: 1.3630 - learning_rate: 6.2500e-06
# Epoch 285/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5285 - loss: 0.6473 - val_accuracy: 0.3736 - val_loss: 1.3626 - learning_rate: 6.2500e-06
# Epoch 286/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5271 - loss: 0.6490 - val_accuracy: 0.3765 - val_loss: 1.3621 - learning_rate: 6.2500e-06
# Epoch 287/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5177 - loss: 0.6415 - val_accuracy: 0.3736 - val_loss: 1.3632 - learning_rate: 6.2500e-06
# Epoch 288/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5383 - loss: 0.6621 - val_accuracy: 0.3742 - val_loss: 1.3645 - learning_rate: 6.2500e-06
# Epoch 289/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5299 - loss: 0.6569 - val_accuracy: 0.3748 - val_loss: 1.3603 - learning_rate: 6.2500e-06
# Epoch 290/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5262 - loss: 0.6526 - val_accuracy: 0.3742 - val_loss: 1.3634 - learning_rate: 6.2500e-06
# Epoch 291/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5308 - loss: 0.6708 - val_accuracy: 0.3742 - val_loss: 1.3703 - learning_rate: 6.2500e-06
# Epoch 292/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5231 - loss: 0.6579 - val_accuracy: 0.3736 - val_loss: 1.3660 - learning_rate: 6.2500e-06
# Epoch 293/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5288 - loss: 0.6320 - val_accuracy: 0.3736 - val_loss: 1.3649 - learning_rate: 6.2500e-06
# Epoch 294/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5450 - loss: 0.6195 - val_accuracy: 0.3719 - val_loss: 1.3705 - learning_rate: 6.2500e-06
# Epoch 295/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5368 - loss: 0.6522 - val_accuracy: 0.3730 - val_loss: 1.3664 - learning_rate: 6.2500e-06
# Epoch 296/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5482 - loss: 0.6322 - val_accuracy: 0.3759 - val_loss: 1.3614 - learning_rate: 6.2500e-06
# Epoch 297/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5364 - loss: 0.6754 - val_accuracy: 0.3759 - val_loss: 1.3646 - learning_rate: 6.2500e-06
# Epoch 298/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5331 - loss: 0.6210 - val_accuracy: 0.3754 - val_loss: 1.3662 - learning_rate: 6.2500e-06
# Epoch 299/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5284 - loss: 0.6757 - val_accuracy: 0.3754 - val_loss: 1.3678 - learning_rate: 6.2500e-06
# Epoch 300/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5362 - loss: 0.6414 - val_accuracy: 0.3754 - val_loss: 1.3667 - learning_rate: 6.2500e-06
# Epoch 301/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5416 - loss: 0.6719 - val_accuracy: 0.3754 - val_loss: 1.3660 - learning_rate: 6.2500e-06
# Epoch 302/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5297 - loss: 0.6879 - val_accuracy: 0.3730 - val_loss: 1.3628 - learning_rate: 6.2500e-06
# Epoch 303/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5346 - loss: 0.6369 - val_accuracy: 0.3719 - val_loss: 1.3666 - learning_rate: 6.2500e-06
# Epoch 304/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5221 - loss: 0.6644 - val_accuracy: 0.3754 - val_loss: 1.3591 - learning_rate: 6.2500e-06
# Epoch 305/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5280 - loss: 0.6448 - val_accuracy: 0.3725 - val_loss: 1.3660 - learning_rate: 6.2500e-06
# Epoch 306/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5169 - loss: 0.6311 - val_accuracy: 0.3730 - val_loss: 1.3638 - learning_rate: 6.2500e-06
# Epoch 307/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5347 - loss: 0.6609 - val_accuracy: 0.3748 - val_loss: 1.3606 - learning_rate: 6.2500e-06
# Epoch 308/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5414 - loss: 0.6321 - val_accuracy: 0.3754 - val_loss: 1.3606 - learning_rate: 6.2500e-06
# Epoch 309/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.5344 - loss: 0.6352 - val_accuracy: 0.3742 - val_loss: 1.3622 - learning_rate: 6.2500e-06
# Epoch 310/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5394 - loss: 0.6176 - val_accuracy: 0.3765 - val_loss: 1.3581 - learning_rate: 6.2500e-06
# Epoch 311/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5299 - loss: 0.6652 - val_accuracy: 0.3777 - val_loss: 1.3556 - learning_rate: 6.2500e-06
# Epoch 312/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5342 - loss: 0.6519 - val_accuracy: 0.3754 - val_loss: 1.3630 - learning_rate: 6.2500e-06
# Epoch 313/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5265 - loss: 0.6432 - val_accuracy: 0.3771 - val_loss: 1.3589 - learning_rate: 6.2500e-06
# Epoch 314/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5356 - loss: 0.6504 - val_accuracy: 0.3771 - val_loss: 1.3597 - learning_rate: 6.2500e-06
# Epoch 315/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 28s 160ms/step - accuracy: 0.5285 - loss: 0.6460 - val_accuracy: 0.3765 - val_loss: 1.3657 - learning_rate: 6.2500e-06
# Epoch 316/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5317 - loss: 0.6292 - val_accuracy: 0.3788 - val_loss: 1.3585 - learning_rate: 6.2500e-06
# Epoch 317/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5314 - loss: 0.6318 - val_accuracy: 0.3806 - val_loss: 1.3544 - learning_rate: 6.2500e-06
# Epoch 318/1000
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5498 - loss: 0.6340
# Epoch 318: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 27s 159ms/step - accuracy: 0.5498 - loss: 0.6339 - val_accuracy: 0.3806 - val_loss: 1.3505 - learning_rate: 6.2500e-06
# Epoch 318: early stopping
# Restoring model weights from the end of the best epoch: 68.

# %%
# Train Accuracy vs Val Accuracy 
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title(f'Accuracy vs Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Train Loss vs Validation Loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title(f'Train Loss vs Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predictions
preds = model.predict(X_test)
final_preds = np.argmax(preds, axis=1)
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_test, final_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.arange(cm.shape[1]), yticklabels=np.arange(cm.shape[0]))
plt.title("Matriz de Confusión")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")
plt.show()

# %%
# Classification report
print(classification_report(y_test, final_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.031     0.077     0.044        13
#            1      0.079     0.339     0.128       121
#            2      0.550     0.364     0.438       887
#            3      0.478     0.398     0.434       701
#
#     accuracy                          0.374      1722
#    macro avg      0.285     0.294     0.261      1722
# weighted avg      0.484     0.374     0.412      1722

# %%
# UAR metric
def uar(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    uar = np.mean(np.diag(cm) / np.sum(cm, axis=1))
    return uar

uar_score = uar(y_test, final_preds)
print(f'UAR: {uar_score:.4f}')
# Out:
# UAR: 0.2945
