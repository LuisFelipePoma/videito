# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import os
import pickle
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils import class_weight
from sklearn.metrics import precision_recall_curve, f1_score, classification_report

from tensorflow.keras import layers, models
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Conv1D, GlobalMaxPooling1D, MaxPooling1D, LSTM, MultiHeadAttention, Add, GlobalAveragePooling1D, LayerNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC, Precision, Recall
import tensorflow.keras.backend as K

# %%
def charge_npy(path):
    X = np.load(path)
    y = np.load(path.replace('X', 'y'))
    return X, y

# %%
# charge y_train.npy in Facenet Embeddings/Train/y_train.npy
path_train = '../../../Facenet Embeddings/Train/X_train.npy'
path_val = '../../../Facenet Embeddings/Val/X_val.npy'
path_test = '../../../Facenet Embeddings/Test/X_test.npy'
X_train, y_train = charge_npy(path_train)
X_val, y_val = charge_npy(path_val)
X_test, y_test = charge_npy(path_test)

n_frames = 5
embedding_dim = 128

X_train = X_train.reshape((-1, n_frames, embedding_dim))
y_train = y_train[:, 4:8]
y_train = np.mean(y_train.reshape(-1, 5, 4), axis=1)
y_train = np.argmax(y_train, axis=1)
## if in the first or second position exists a 1, then y is 0 and only has a shape of 1, else 1
##y_train = np.where((y_train[:, 3] == 1), 1, 0).reshape(-1, 1)

X_val = X_val.reshape((-1, n_frames, embedding_dim)) 
y_val = y_val[:, 4:8]
y_val = np.mean(y_val.reshape(-1, 5, 4), axis=1)
y_val = np.argmax(y_val, axis=1)
##y_val = np.where((y_val[:, 3] == 1), 1, 0).reshape(-1, 1)

X_test = X_test.reshape((-1, n_frames, embedding_dim))  
y_test = y_test[:, 4:8]
y_test = np.mean(y_test.reshape(-1, 5, 4), axis=1)
y_test = np.argmax(y_test, axis=1)

#y_test = np.mean(y_test.reshape(-1, 5, 4), axis=1)
##y_test = np.where((y_test[:, 3] == 1), 1, 0).reshape(-1, 1)

# %%
# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# %%
# Parámetros
n_models = 1
models = []
histories = []

# Callback EarlyStopping y ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_loss', patience=250, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=50, verbose=1)

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    # Multi-Head Attention
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Add()([x, inputs])  # Skip connection
    x = LayerNormalization(epsilon=1e-6)(x)

    # Feed-Forward Network
    ff = Dense(ff_dim, activation="relu")(x)
    ff = Dropout(dropout)(ff)
    ff = Dense(inputs.shape[-1])(ff)
    x = Add()([x, ff])  # Skip connection
    x = LayerNormalization(epsilon=1e-6)(x)

    return x

def build_transformer_model(input_shape):
    inputs = Input(shape=input_shape)

    # Transformer Encoder
    x = transformer_encoder(inputs, head_size=64, num_heads=4, ff_dim=128, dropout=0.2)

    # Pooling + Dense
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.5)(x)
    outputs = Dense(4, activation="softmax")(x)

    model = Model(inputs, outputs)
    model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(1e-4), metrics=["accuracy"])
    return model

# Creamos y entrenamos el modelo
model = build_transformer_model((X_train.shape[1], X_train.shape[2]))

history = model.fit(
    X_train,
    y_train,
    class_weight=class_weights,
    epochs=500,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3299 - loss: 1.6222 - val_accuracy: 0.2233 - val_loss: 1.5247 - learning_rate: 1.0000e-04
# Epoch 2/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3115 - loss: 1.4868 - val_accuracy: 0.2698 - val_loss: 1.3780 - learning_rate: 1.0000e-04
# Epoch 3/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3476 - loss: 1.2887 - val_accuracy: 0.2366 - val_loss: 1.3998 - learning_rate: 1.0000e-04
# Epoch 4/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3419 - loss: 1.2637 - val_accuracy: 0.2855 - val_loss: 1.3153 - learning_rate: 1.0000e-04
# Epoch 5/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3536 - loss: 1.2809 - val_accuracy: 0.2855 - val_loss: 1.3131 - learning_rate: 1.0000e-04
# Epoch 6/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3606 - loss: 1.2448 - val_accuracy: 0.3064 - val_loss: 1.3037 - learning_rate: 1.0000e-04
# Epoch 7/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3955 - loss: 1.1709 - val_accuracy: 0.2930 - val_loss: 1.2939 - learning_rate: 1.0000e-04
# Epoch 8/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3833 - loss: 1.2361 - val_accuracy: 0.2715 - val_loss: 1.3090 - learning_rate: 1.0000e-04
# Epoch 9/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3808 - loss: 1.1610 - val_accuracy: 0.2936 - val_loss: 1.2912 - learning_rate: 1.0000e-04
# Epoch 10/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4054 - loss: 1.1552 - val_accuracy: 0.3227 - val_loss: 1.2713 - learning_rate: 1.0000e-04
# Epoch 11/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4001 - loss: 1.1640 - val_accuracy: 0.2901 - val_loss: 1.3061 - learning_rate: 1.0000e-04
# Epoch 12/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3970 - loss: 1.1155 - val_accuracy: 0.3186 - val_loss: 1.2658 - learning_rate: 1.0000e-04
# Epoch 13/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4109 - loss: 1.1553 - val_accuracy: 0.2959 - val_loss: 1.3010 - learning_rate: 1.0000e-04
# Epoch 14/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4104 - loss: 1.1323 - val_accuracy: 0.3727 - val_loss: 1.2129 - learning_rate: 1.0000e-04
# Epoch 15/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4368 - loss: 1.2192 - val_accuracy: 0.3453 - val_loss: 1.2308 - learning_rate: 1.0000e-04
# Epoch 16/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4330 - loss: 1.0786 - val_accuracy: 0.3477 - val_loss: 1.2269 - learning_rate: 1.0000e-04
# Epoch 17/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4331 - loss: 1.0780 - val_accuracy: 0.3209 - val_loss: 1.2370 - learning_rate: 1.0000e-04
# Epoch 18/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4383 - loss: 1.0033 - val_accuracy: 0.3680 - val_loss: 1.1921 - learning_rate: 1.0000e-04
# Epoch 19/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4205 - loss: 1.0658 - val_accuracy: 0.3733 - val_loss: 1.1827 - learning_rate: 1.0000e-04
# Epoch 20/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4520 - loss: 1.0545 - val_accuracy: 0.3081 - val_loss: 1.3116 - learning_rate: 1.0000e-04
# Epoch 21/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4148 - loss: 1.0781 - val_accuracy: 0.3715 - val_loss: 1.1863 - learning_rate: 1.0000e-04
# Epoch 22/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4552 - loss: 1.0544 - val_accuracy: 0.3953 - val_loss: 1.1955 - learning_rate: 1.0000e-04
# Epoch 23/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4496 - loss: 1.0099 - val_accuracy: 0.3506 - val_loss: 1.2368 - learning_rate: 1.0000e-04
# Epoch 24/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4493 - loss: 0.9935 - val_accuracy: 0.3605 - val_loss: 1.2101 - learning_rate: 1.0000e-04
# Epoch 25/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4441 - loss: 0.9823 - val_accuracy: 0.3808 - val_loss: 1.1568 - learning_rate: 1.0000e-04
# Epoch 26/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4716 - loss: 0.9299 - val_accuracy: 0.3802 - val_loss: 1.1989 - learning_rate: 1.0000e-04
# Epoch 27/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4301 - loss: 1.0755 - val_accuracy: 0.4140 - val_loss: 1.1508 - learning_rate: 1.0000e-04
# Epoch 28/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4728 - loss: 0.9349 - val_accuracy: 0.3291 - val_loss: 1.3011 - learning_rate: 1.0000e-04
# Epoch 29/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4463 - loss: 0.9096 - val_accuracy: 0.3605 - val_loss: 1.1847 - learning_rate: 1.0000e-04
# Epoch 30/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4688 - loss: 0.9782 - val_accuracy: 0.3651 - val_loss: 1.2111 - learning_rate: 1.0000e-04
# Epoch 31/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4634 - loss: 0.9463 - val_accuracy: 0.3337 - val_loss: 1.2273 - learning_rate: 1.0000e-04
# Epoch 32/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4596 - loss: 0.9176 - val_accuracy: 0.3186 - val_loss: 1.2262 - learning_rate: 1.0000e-04
# Epoch 33/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4691 - loss: 0.9107 - val_accuracy: 0.3541 - val_loss: 1.2282 - learning_rate: 1.0000e-04
# Epoch 34/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4668 - loss: 0.9105 - val_accuracy: 0.3029 - val_loss: 1.3122 - learning_rate: 1.0000e-04
# Epoch 35/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4652 - loss: 0.8864 - val_accuracy: 0.3733 - val_loss: 1.1833 - learning_rate: 1.0000e-04
# Epoch 36/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4675 - loss: 0.9066 - val_accuracy: 0.3634 - val_loss: 1.2084 - learning_rate: 1.0000e-04
# Epoch 37/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4663 - loss: 0.9240 - val_accuracy: 0.3907 - val_loss: 1.1595 - learning_rate: 1.0000e-04
# Epoch 38/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4756 - loss: 0.9161 - val_accuracy: 0.3215 - val_loss: 1.2318 - learning_rate: 1.0000e-04
# Epoch 39/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4399 - loss: 0.8963 - val_accuracy: 0.3692 - val_loss: 1.1592 - learning_rate: 1.0000e-04
# Epoch 40/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4621 - loss: 0.8847 - val_accuracy: 0.3680 - val_loss: 1.1938 - learning_rate: 1.0000e-04
# Epoch 41/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4811 - loss: 0.9002 - val_accuracy: 0.3674 - val_loss: 1.1899 - learning_rate: 1.0000e-04
# Epoch 42/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4585 - loss: 0.8613 - val_accuracy: 0.3610 - val_loss: 1.1836 - learning_rate: 1.0000e-04
# Epoch 43/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4720 - loss: 0.8382 - val_accuracy: 0.3814 - val_loss: 1.1904 - learning_rate: 1.0000e-04
# Epoch 44/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4833 - loss: 0.8793 - val_accuracy: 0.4070 - val_loss: 1.1348 - learning_rate: 1.0000e-04
# Epoch 45/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4805 - loss: 0.8161 - val_accuracy: 0.3919 - val_loss: 1.1682 - learning_rate: 1.0000e-04
# Epoch 46/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4685 - loss: 0.8519 - val_accuracy: 0.3808 - val_loss: 1.1911 - learning_rate: 1.0000e-04
# Epoch 47/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4864 - loss: 0.8320 - val_accuracy: 0.4140 - val_loss: 1.1288 - learning_rate: 1.0000e-04
# Epoch 48/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4885 - loss: 0.7986 - val_accuracy: 0.3849 - val_loss: 1.1743 - learning_rate: 1.0000e-04
# Epoch 49/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4715 - loss: 0.8264 - val_accuracy: 0.3965 - val_loss: 1.1918 - learning_rate: 1.0000e-04
# Epoch 50/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4792 - loss: 0.8645 - val_accuracy: 0.4256 - val_loss: 1.1487 - learning_rate: 1.0000e-04
# Epoch 51/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5055 - loss: 0.7978 - val_accuracy: 0.4116 - val_loss: 1.1638 - learning_rate: 1.0000e-04
# Epoch 52/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4903 - loss: 0.8254 - val_accuracy: 0.4064 - val_loss: 1.1693 - learning_rate: 1.0000e-04
# Epoch 53/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4876 - loss: 0.8385 - val_accuracy: 0.4076 - val_loss: 1.1554 - learning_rate: 1.0000e-04
# Epoch 54/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4826 - loss: 0.7756 - val_accuracy: 0.4029 - val_loss: 1.1716 - learning_rate: 1.0000e-04
# Epoch 55/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4696 - loss: 0.7807 - val_accuracy: 0.4674 - val_loss: 1.1012 - learning_rate: 1.0000e-04
# Epoch 56/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4936 - loss: 0.7328 - val_accuracy: 0.3698 - val_loss: 1.2005 - learning_rate: 1.0000e-04
# Epoch 57/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4962 - loss: 0.7387 - val_accuracy: 0.3860 - val_loss: 1.1608 - learning_rate: 1.0000e-04
# Epoch 58/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4914 - loss: 0.7397 - val_accuracy: 0.3523 - val_loss: 1.2464 - learning_rate: 1.0000e-04
# Epoch 59/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4877 - loss: 0.7205 - val_accuracy: 0.3581 - val_loss: 1.2358 - learning_rate: 1.0000e-04
# Epoch 60/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4948 - loss: 0.7258 - val_accuracy: 0.4203 - val_loss: 1.1498 - learning_rate: 1.0000e-04
# Epoch 61/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.5063 - loss: 0.7466 - val_accuracy: 0.4372 - val_loss: 1.1340 - learning_rate: 1.0000e-04
# Epoch 62/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5083 - loss: 0.7104 - val_accuracy: 0.4047 - val_loss: 1.1630 - learning_rate: 1.0000e-04
# Epoch 63/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5112 - loss: 0.6962 - val_accuracy: 0.4058 - val_loss: 1.1703 - learning_rate: 1.0000e-04
# Epoch 64/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4940 - loss: 0.7046 - val_accuracy: 0.3733 - val_loss: 1.2061 - learning_rate: 1.0000e-04
# Epoch 65/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5091 - loss: 0.7035 - val_accuracy: 0.3953 - val_loss: 1.1842 - learning_rate: 1.0000e-04
# Epoch 66/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5229 - loss: 0.6756 - val_accuracy: 0.4076 - val_loss: 1.1683 - learning_rate: 1.0000e-04
# Epoch 67/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5084 - loss: 0.7166 - val_accuracy: 0.3977 - val_loss: 1.1846 - learning_rate: 1.0000e-04
# Epoch 68/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5213 - loss: 0.7193 - val_accuracy: 0.3727 - val_loss: 1.2144 - learning_rate: 1.0000e-04
# Epoch 69/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4974 - loss: 0.7221 - val_accuracy: 0.4076 - val_loss: 1.1568 - learning_rate: 1.0000e-04
# Epoch 70/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5323 - loss: 0.7037 - val_accuracy: 0.3640 - val_loss: 1.2583 - learning_rate: 1.0000e-04
# Epoch 71/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5074 - loss: 0.6951 - val_accuracy: 0.3570 - val_loss: 1.2334 - learning_rate: 1.0000e-04
# Epoch 72/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4973 - loss: 0.7143 - val_accuracy: 0.4366 - val_loss: 1.1451 - learning_rate: 1.0000e-04
# Epoch 73/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5182 - loss: 0.6737 - val_accuracy: 0.4465 - val_loss: 1.1246 - learning_rate: 1.0000e-04
# Epoch 74/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5277 - loss: 0.6738 - val_accuracy: 0.4215 - val_loss: 1.1556 - learning_rate: 1.0000e-04
# Epoch 75/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5272 - loss: 0.7243 - val_accuracy: 0.4023 - val_loss: 1.1790 - learning_rate: 1.0000e-04
# Epoch 76/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5018 - loss: 0.6615 - val_accuracy: 0.4140 - val_loss: 1.1988 - learning_rate: 1.0000e-04
# Epoch 77/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5181 - loss: 0.7072 - val_accuracy: 0.4198 - val_loss: 1.1748 - learning_rate: 1.0000e-04
# Epoch 78/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5197 - loss: 0.6972 - val_accuracy: 0.4186 - val_loss: 1.1636 - learning_rate: 1.0000e-04
# Epoch 79/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5377 - loss: 0.6627 - val_accuracy: 0.4390 - val_loss: 1.1542 - learning_rate: 1.0000e-04
# Epoch 80/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5088 - loss: 0.6549 - val_accuracy: 0.4430 - val_loss: 1.1446 - learning_rate: 1.0000e-04
# Epoch 81/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5212 - loss: 0.6806 - val_accuracy: 0.4424 - val_loss: 1.1415 - learning_rate: 1.0000e-04
# Epoch 82/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5299 - loss: 0.6544 - val_accuracy: 0.4110 - val_loss: 1.1830 - learning_rate: 1.0000e-04
# Epoch 83/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5242 - loss: 0.6978 - val_accuracy: 0.4244 - val_loss: 1.1869 - learning_rate: 1.0000e-04
# Epoch 84/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5339 - loss: 0.6509 - val_accuracy: 0.4256 - val_loss: 1.1978 - learning_rate: 1.0000e-04
# Epoch 85/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5280 - loss: 0.6673 - val_accuracy: 0.4174 - val_loss: 1.2019 - learning_rate: 1.0000e-04
# Epoch 86/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5292 - loss: 0.6523 - val_accuracy: 0.4203 - val_loss: 1.1965 - learning_rate: 1.0000e-04
# Epoch 87/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5201 - loss: 0.6580 - val_accuracy: 0.4442 - val_loss: 1.1597 - learning_rate: 1.0000e-04
# Epoch 88/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5507 - loss: 0.6357 - val_accuracy: 0.3988 - val_loss: 1.2043 - learning_rate: 1.0000e-04
# Epoch 89/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5247 - loss: 0.6978 - val_accuracy: 0.4360 - val_loss: 1.1726 - learning_rate: 1.0000e-04
# Epoch 90/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5288 - loss: 0.6586 - val_accuracy: 0.4128 - val_loss: 1.1974 - learning_rate: 1.0000e-04
# Epoch 91/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5187 - loss: 0.6861 - val_accuracy: 0.4512 - val_loss: 1.1551 - learning_rate: 1.0000e-04
# Epoch 92/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5324 - loss: 0.6941 - val_accuracy: 0.4163 - val_loss: 1.1854 - learning_rate: 1.0000e-04
# Epoch 93/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5260 - loss: 0.6396 - val_accuracy: 0.4355 - val_loss: 1.1603 - learning_rate: 1.0000e-04
# Epoch 94/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5359 - loss: 0.6640 - val_accuracy: 0.4198 - val_loss: 1.1754 - learning_rate: 1.0000e-04
# Epoch 95/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5310 - loss: 0.6272 - val_accuracy: 0.4529 - val_loss: 1.1485 - learning_rate: 1.0000e-04
# Epoch 96/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5386 - loss: 0.6585 - val_accuracy: 0.4233 - val_loss: 1.1884 - learning_rate: 1.0000e-04
# Epoch 97/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5308 - loss: 0.6320 - val_accuracy: 0.4442 - val_loss: 1.1690 - learning_rate: 1.0000e-04
# Epoch 98/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5359 - loss: 0.6633 - val_accuracy: 0.4157 - val_loss: 1.1986 - learning_rate: 1.0000e-04
# Epoch 99/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5463 - loss: 0.6390 - val_accuracy: 0.4390 - val_loss: 1.1716 - learning_rate: 1.0000e-04
# Epoch 100/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5256 - loss: 0.6648 - val_accuracy: 0.4709 - val_loss: 1.1442 - learning_rate: 1.0000e-04
# Epoch 101/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5532 - loss: 0.6022 - val_accuracy: 0.4215 - val_loss: 1.2031 - learning_rate: 1.0000e-04
# Epoch 102/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5494 - loss: 0.5871 - val_accuracy: 0.4343 - val_loss: 1.1978 - learning_rate: 1.0000e-04
# Epoch 103/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5474 - loss: 0.6382 - val_accuracy: 0.4343 - val_loss: 1.1743 - learning_rate: 1.0000e-04
# Epoch 104/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5449 - loss: 0.6336 - val_accuracy: 0.4326 - val_loss: 1.1946 - learning_rate: 1.0000e-04
# Epoch 105/500
# 169/172 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5440 - loss: 0.5942
# Epoch 105: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5440 - loss: 0.5944 - val_accuracy: 0.4320 - val_loss: 1.1903 - learning_rate: 1.0000e-04
# Epoch 106/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5440 - loss: 0.6245 - val_accuracy: 0.4215 - val_loss: 1.2052 - learning_rate: 5.0000e-05
# Epoch 107/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5435 - loss: 0.5944 - val_accuracy: 0.4459 - val_loss: 1.1812 - learning_rate: 5.0000e-05
# Epoch 108/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5599 - loss: 0.5794 - val_accuracy: 0.4244 - val_loss: 1.2082 - learning_rate: 5.0000e-05
# Epoch 109/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5490 - loss: 0.5699 - val_accuracy: 0.4180 - val_loss: 1.2235 - learning_rate: 5.0000e-05
# Epoch 110/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5508 - loss: 0.5905 - val_accuracy: 0.4221 - val_loss: 1.2181 - learning_rate: 5.0000e-05
# Epoch 111/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5453 - loss: 0.5785 - val_accuracy: 0.4442 - val_loss: 1.1978 - learning_rate: 5.0000e-05
# Epoch 112/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5470 - loss: 0.5904 - val_accuracy: 0.4442 - val_loss: 1.1942 - learning_rate: 5.0000e-05
# Epoch 113/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5479 - loss: 0.5790 - val_accuracy: 0.4401 - val_loss: 1.2009 - learning_rate: 5.0000e-05
# Epoch 114/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5642 - loss: 0.5690 - val_accuracy: 0.4407 - val_loss: 1.1960 - learning_rate: 5.0000e-05
# Epoch 115/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5561 - loss: 0.6009 - val_accuracy: 0.4221 - val_loss: 1.2309 - learning_rate: 5.0000e-05
# Epoch 116/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5560 - loss: 0.5596 - val_accuracy: 0.4331 - val_loss: 1.2081 - learning_rate: 5.0000e-05
# Epoch 117/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5455 - loss: 0.5638 - val_accuracy: 0.4279 - val_loss: 1.2196 - learning_rate: 5.0000e-05
# Epoch 118/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5464 - loss: 0.5760 - val_accuracy: 0.4314 - val_loss: 1.2232 - learning_rate: 5.0000e-05
# Epoch 119/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5619 - loss: 0.5488 - val_accuracy: 0.4297 - val_loss: 1.2317 - learning_rate: 5.0000e-05
# Epoch 120/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5657 - loss: 0.5724 - val_accuracy: 0.4256 - val_loss: 1.2307 - learning_rate: 5.0000e-05
# Epoch 121/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5689 - loss: 0.5663 - val_accuracy: 0.4471 - val_loss: 1.1978 - learning_rate: 5.0000e-05
# Epoch 122/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5756 - loss: 0.5889 - val_accuracy: 0.4401 - val_loss: 1.2047 - learning_rate: 5.0000e-05
# Epoch 123/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5585 - loss: 0.5770 - val_accuracy: 0.4692 - val_loss: 1.1815 - learning_rate: 5.0000e-05
# Epoch 124/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5652 - loss: 0.5753 - val_accuracy: 0.4570 - val_loss: 1.2064 - learning_rate: 5.0000e-05
# Epoch 125/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5481 - loss: 0.5670 - val_accuracy: 0.4390 - val_loss: 1.2134 - learning_rate: 5.0000e-05
# Epoch 126/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5672 - loss: 0.5513 - val_accuracy: 0.4395 - val_loss: 1.2180 - learning_rate: 5.0000e-05
# Epoch 127/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5443 - loss: 0.5661 - val_accuracy: 0.4651 - val_loss: 1.2038 - learning_rate: 5.0000e-05
# Epoch 128/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5659 - loss: 0.5875 - val_accuracy: 0.4715 - val_loss: 1.1976 - learning_rate: 5.0000e-05
# Epoch 129/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5790 - loss: 0.5503 - val_accuracy: 0.4709 - val_loss: 1.2002 - learning_rate: 5.0000e-05
# Epoch 130/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5729 - loss: 0.5759 - val_accuracy: 0.4576 - val_loss: 1.2246 - learning_rate: 5.0000e-05
# Epoch 131/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5590 - loss: 0.5346 - val_accuracy: 0.4192 - val_loss: 1.2528 - learning_rate: 5.0000e-05
# Epoch 132/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5691 - loss: 0.5471 - val_accuracy: 0.4471 - val_loss: 1.2301 - learning_rate: 5.0000e-05
# Epoch 133/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5586 - loss: 0.5489 - val_accuracy: 0.4459 - val_loss: 1.2243 - learning_rate: 5.0000e-05
# Epoch 134/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5780 - loss: 0.5420 - val_accuracy: 0.4500 - val_loss: 1.2258 - learning_rate: 5.0000e-05
# Epoch 135/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5781 - loss: 0.5143 - val_accuracy: 0.4297 - val_loss: 1.2480 - learning_rate: 5.0000e-05
# Epoch 136/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5632 - loss: 0.5518 - val_accuracy: 0.4419 - val_loss: 1.2254 - learning_rate: 5.0000e-05
# Epoch 137/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5712 - loss: 0.5452 - val_accuracy: 0.4535 - val_loss: 1.2243 - learning_rate: 5.0000e-05
# Epoch 138/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5623 - loss: 0.5432 - val_accuracy: 0.4494 - val_loss: 1.2238 - learning_rate: 5.0000e-05
# Epoch 139/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5697 - loss: 0.5253 - val_accuracy: 0.4395 - val_loss: 1.2510 - learning_rate: 5.0000e-05
# Epoch 140/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5774 - loss: 0.5465 - val_accuracy: 0.4756 - val_loss: 1.2037 - learning_rate: 5.0000e-05
# Epoch 141/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5690 - loss: 0.5446 - val_accuracy: 0.4709 - val_loss: 1.2172 - learning_rate: 5.0000e-05
# Epoch 142/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5706 - loss: 0.5541 - val_accuracy: 0.4366 - val_loss: 1.2505 - learning_rate: 5.0000e-05
# Epoch 143/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5712 - loss: 0.5637 - val_accuracy: 0.4407 - val_loss: 1.2345 - learning_rate: 5.0000e-05
# Epoch 144/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5734 - loss: 0.5618 - val_accuracy: 0.4576 - val_loss: 1.2331 - learning_rate: 5.0000e-05
# Epoch 145/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5617 - loss: 0.5337 - val_accuracy: 0.4581 - val_loss: 1.2377 - learning_rate: 5.0000e-05
# Epoch 146/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5893 - loss: 0.5160 - val_accuracy: 0.4471 - val_loss: 1.2566 - learning_rate: 5.0000e-05
# Epoch 147/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5646 - loss: 0.5511 - val_accuracy: 0.4645 - val_loss: 1.2344 - learning_rate: 5.0000e-05
# Epoch 148/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5884 - loss: 0.5300 - val_accuracy: 0.4733 - val_loss: 1.2204 - learning_rate: 5.0000e-05
# Epoch 149/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5801 - loss: 0.5199 - val_accuracy: 0.4442 - val_loss: 1.2620 - learning_rate: 5.0000e-05
# Epoch 150/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5807 - loss: 0.5247 - val_accuracy: 0.4558 - val_loss: 1.2538 - learning_rate: 5.0000e-05
# Epoch 151/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5598 - loss: 0.5340 - val_accuracy: 0.4808 - val_loss: 1.2302 - learning_rate: 5.0000e-05
# Epoch 152/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5898 - loss: 0.5194 - val_accuracy: 0.4622 - val_loss: 1.2451 - learning_rate: 5.0000e-05
# Epoch 153/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5874 - loss: 0.5399 - val_accuracy: 0.4785 - val_loss: 1.2300 - learning_rate: 5.0000e-05
# Epoch 154/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5787 - loss: 0.5129 - val_accuracy: 0.4773 - val_loss: 1.2357 - learning_rate: 5.0000e-05
# Epoch 155/500
# 169/172 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5624 - loss: 0.5536
# Epoch 155: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5627 - loss: 0.5531 - val_accuracy: 0.4634 - val_loss: 1.2601 - learning_rate: 5.0000e-05
# Epoch 156/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5739 - loss: 0.5239 - val_accuracy: 0.4465 - val_loss: 1.2767 - learning_rate: 2.5000e-05
# Epoch 157/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5811 - loss: 0.5057 - val_accuracy: 0.4570 - val_loss: 1.2615 - learning_rate: 2.5000e-05
# Epoch 158/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5876 - loss: 0.5541 - val_accuracy: 0.4564 - val_loss: 1.2582 - learning_rate: 2.5000e-05
# Epoch 159/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5860 - loss: 0.5200 - val_accuracy: 0.4593 - val_loss: 1.2585 - learning_rate: 2.5000e-05
# Epoch 160/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5871 - loss: 0.5176 - val_accuracy: 0.4512 - val_loss: 1.2712 - learning_rate: 2.5000e-05
# Epoch 161/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5817 - loss: 0.5083 - val_accuracy: 0.4581 - val_loss: 1.2607 - learning_rate: 2.5000e-05
# Epoch 162/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5810 - loss: 0.4998 - val_accuracy: 0.4442 - val_loss: 1.2760 - learning_rate: 2.5000e-05
# Epoch 163/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5844 - loss: 0.5045 - val_accuracy: 0.4663 - val_loss: 1.2549 - learning_rate: 2.5000e-05
# Epoch 164/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5890 - loss: 0.5037 - val_accuracy: 0.4593 - val_loss: 1.2619 - learning_rate: 2.5000e-05
# Epoch 165/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5810 - loss: 0.5115 - val_accuracy: 0.4686 - val_loss: 1.2575 - learning_rate: 2.5000e-05
# Epoch 166/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5837 - loss: 0.5094 - val_accuracy: 0.4628 - val_loss: 1.2592 - learning_rate: 2.5000e-05
# Epoch 167/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5968 - loss: 0.4904 - val_accuracy: 0.4517 - val_loss: 1.2848 - learning_rate: 2.5000e-05
# Epoch 168/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5820 - loss: 0.5111 - val_accuracy: 0.4663 - val_loss: 1.2604 - learning_rate: 2.5000e-05
# Epoch 169/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6012 - loss: 0.4983 - val_accuracy: 0.4628 - val_loss: 1.2685 - learning_rate: 2.5000e-05
# Epoch 170/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6028 - loss: 0.5197 - val_accuracy: 0.4576 - val_loss: 1.2789 - learning_rate: 2.5000e-05
# Epoch 171/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5820 - loss: 0.5134 - val_accuracy: 0.4640 - val_loss: 1.2682 - learning_rate: 2.5000e-05
# Epoch 172/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5921 - loss: 0.5110 - val_accuracy: 0.4698 - val_loss: 1.2724 - learning_rate: 2.5000e-05
# Epoch 173/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5795 - loss: 0.5069 - val_accuracy: 0.4593 - val_loss: 1.2821 - learning_rate: 2.5000e-05
# Epoch 174/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5830 - loss: 0.5074 - val_accuracy: 0.4610 - val_loss: 1.2726 - learning_rate: 2.5000e-05
# Epoch 175/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5833 - loss: 0.5135 - val_accuracy: 0.4640 - val_loss: 1.2590 - learning_rate: 2.5000e-05
# Epoch 176/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5821 - loss: 0.4973 - val_accuracy: 0.4593 - val_loss: 1.2777 - learning_rate: 2.5000e-05
# Epoch 177/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5875 - loss: 0.4991 - val_accuracy: 0.4640 - val_loss: 1.2841 - learning_rate: 2.5000e-05
# Epoch 178/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5907 - loss: 0.5248 - val_accuracy: 0.4669 - val_loss: 1.2714 - learning_rate: 2.5000e-05
# Epoch 179/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6075 - loss: 0.4908 - val_accuracy: 0.4663 - val_loss: 1.2741 - learning_rate: 2.5000e-05
# Epoch 180/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5946 - loss: 0.4841 - val_accuracy: 0.4576 - val_loss: 1.2859 - learning_rate: 2.5000e-05
# Epoch 181/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5893 - loss: 0.4835 - val_accuracy: 0.4529 - val_loss: 1.3100 - learning_rate: 2.5000e-05
# Epoch 182/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5934 - loss: 0.4887 - val_accuracy: 0.4576 - val_loss: 1.2944 - learning_rate: 2.5000e-05
# Epoch 183/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5989 - loss: 0.4911 - val_accuracy: 0.4663 - val_loss: 1.2873 - learning_rate: 2.5000e-05
# Epoch 184/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5920 - loss: 0.5083 - val_accuracy: 0.4762 - val_loss: 1.2840 - learning_rate: 2.5000e-05
# Epoch 185/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5967 - loss: 0.4947 - val_accuracy: 0.4686 - val_loss: 1.2933 - learning_rate: 2.5000e-05
# Epoch 186/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5862 - loss: 0.4827 - val_accuracy: 0.4674 - val_loss: 1.3020 - learning_rate: 2.5000e-05
# Epoch 187/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5962 - loss: 0.5026 - val_accuracy: 0.4808 - val_loss: 1.2877 - learning_rate: 2.5000e-05
# Epoch 188/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5926 - loss: 0.4998 - val_accuracy: 0.4872 - val_loss: 1.2851 - learning_rate: 2.5000e-05
# Epoch 189/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5995 - loss: 0.4706 - val_accuracy: 0.4820 - val_loss: 1.2900 - learning_rate: 2.5000e-05
# Epoch 190/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5855 - loss: 0.4864 - val_accuracy: 0.4727 - val_loss: 1.3013 - learning_rate: 2.5000e-05
# Epoch 191/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5847 - loss: 0.5065 - val_accuracy: 0.4773 - val_loss: 1.2890 - learning_rate: 2.5000e-05
# Epoch 192/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5996 - loss: 0.4950 - val_accuracy: 0.4657 - val_loss: 1.2988 - learning_rate: 2.5000e-05
# Epoch 193/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5995 - loss: 0.4663 - val_accuracy: 0.4802 - val_loss: 1.2909 - learning_rate: 2.5000e-05
# Epoch 194/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5959 - loss: 0.4946 - val_accuracy: 0.4738 - val_loss: 1.2934 - learning_rate: 2.5000e-05
# Epoch 195/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5841 - loss: 0.4927 - val_accuracy: 0.4791 - val_loss: 1.2933 - learning_rate: 2.5000e-05
# Epoch 196/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5875 - loss: 0.4846 - val_accuracy: 0.4797 - val_loss: 1.2982 - learning_rate: 2.5000e-05
# Epoch 197/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6041 - loss: 0.4983 - val_accuracy: 0.4657 - val_loss: 1.3098 - learning_rate: 2.5000e-05
# Epoch 198/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5950 - loss: 0.4878 - val_accuracy: 0.4756 - val_loss: 1.2952 - learning_rate: 2.5000e-05
# Epoch 199/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5885 - loss: 0.4894 - val_accuracy: 0.4657 - val_loss: 1.3031 - learning_rate: 2.5000e-05
# Epoch 200/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5941 - loss: 0.4848 - val_accuracy: 0.4703 - val_loss: 1.3023 - learning_rate: 2.5000e-05
# Epoch 201/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6026 - loss: 0.4838 - val_accuracy: 0.4634 - val_loss: 1.3050 - learning_rate: 2.5000e-05
# Epoch 202/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6033 - loss: 0.4886 - val_accuracy: 0.4698 - val_loss: 1.3035 - learning_rate: 2.5000e-05
# Epoch 203/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5952 - loss: 0.4806 - val_accuracy: 0.4645 - val_loss: 1.3179 - learning_rate: 2.5000e-05
# Epoch 204/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6046 - loss: 0.4780 - val_accuracy: 0.4576 - val_loss: 1.3220 - learning_rate: 2.5000e-05
# Epoch 205/500
# 165/172 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5838 - loss: 0.4935
# Epoch 205: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5839 - loss: 0.4935 - val_accuracy: 0.4593 - val_loss: 1.3249 - learning_rate: 2.5000e-05
# Epoch 206/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5933 - loss: 0.4848 - val_accuracy: 0.4674 - val_loss: 1.3119 - learning_rate: 1.2500e-05
# Epoch 207/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6045 - loss: 0.4852 - val_accuracy: 0.4762 - val_loss: 1.3077 - learning_rate: 1.2500e-05
# Epoch 208/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6062 - loss: 0.4796 - val_accuracy: 0.4576 - val_loss: 1.3263 - learning_rate: 1.2500e-05
# Epoch 209/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6067 - loss: 0.4751 - val_accuracy: 0.4715 - val_loss: 1.3107 - learning_rate: 1.2500e-05
# Epoch 210/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5973 - loss: 0.4875 - val_accuracy: 0.4616 - val_loss: 1.3182 - learning_rate: 1.2500e-05
# Epoch 211/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6027 - loss: 0.4651 - val_accuracy: 0.4709 - val_loss: 1.3185 - learning_rate: 1.2500e-05
# Epoch 212/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6112 - loss: 0.4633 - val_accuracy: 0.4703 - val_loss: 1.3226 - learning_rate: 1.2500e-05
# Epoch 213/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6002 - loss: 0.5156 - val_accuracy: 0.4605 - val_loss: 1.3322 - learning_rate: 1.2500e-05
# Epoch 214/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5984 - loss: 0.4597 - val_accuracy: 0.4680 - val_loss: 1.3255 - learning_rate: 1.2500e-05
# Epoch 215/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6036 - loss: 0.4772 - val_accuracy: 0.4756 - val_loss: 1.3163 - learning_rate: 1.2500e-05
# Epoch 216/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5993 - loss: 0.4834 - val_accuracy: 0.4791 - val_loss: 1.3191 - learning_rate: 1.2500e-05
# Epoch 217/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6148 - loss: 0.4682 - val_accuracy: 0.4779 - val_loss: 1.3178 - learning_rate: 1.2500e-05
# Epoch 218/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5929 - loss: 0.4823 - val_accuracy: 0.4727 - val_loss: 1.3215 - learning_rate: 1.2500e-05
# Epoch 219/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5984 - loss: 0.4450 - val_accuracy: 0.4767 - val_loss: 1.3151 - learning_rate: 1.2500e-05
# Epoch 220/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6121 - loss: 0.4670 - val_accuracy: 0.4727 - val_loss: 1.3231 - learning_rate: 1.2500e-05
# Epoch 221/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6252 - loss: 0.4581 - val_accuracy: 0.4721 - val_loss: 1.3247 - learning_rate: 1.2500e-05
# Epoch 222/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6008 - loss: 0.4699 - val_accuracy: 0.4750 - val_loss: 1.3224 - learning_rate: 1.2500e-05
# Epoch 223/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6061 - loss: 0.4988 - val_accuracy: 0.4808 - val_loss: 1.3159 - learning_rate: 1.2500e-05
# Epoch 224/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6209 - loss: 0.4712 - val_accuracy: 0.4779 - val_loss: 1.3179 - learning_rate: 1.2500e-05
# Epoch 225/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5924 - loss: 0.4770 - val_accuracy: 0.4779 - val_loss: 1.3236 - learning_rate: 1.2500e-05
# Epoch 226/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6165 - loss: 0.4681 - val_accuracy: 0.4785 - val_loss: 1.3245 - learning_rate: 1.2500e-05
# Epoch 227/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6024 - loss: 0.4705 - val_accuracy: 0.4860 - val_loss: 1.3221 - learning_rate: 1.2500e-05
# Epoch 228/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6208 - loss: 0.4546 - val_accuracy: 0.4762 - val_loss: 1.3330 - learning_rate: 1.2500e-05
# Epoch 229/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5962 - loss: 0.4934 - val_accuracy: 0.4703 - val_loss: 1.3391 - learning_rate: 1.2500e-05
# Epoch 230/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5843 - loss: 0.4816 - val_accuracy: 0.4767 - val_loss: 1.3278 - learning_rate: 1.2500e-05
# Epoch 231/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6010 - loss: 0.4725 - val_accuracy: 0.4820 - val_loss: 1.3308 - learning_rate: 1.2500e-05
# Epoch 232/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6154 - loss: 0.4608 - val_accuracy: 0.4738 - val_loss: 1.3430 - learning_rate: 1.2500e-05
# Epoch 233/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6068 - loss: 0.4788 - val_accuracy: 0.4674 - val_loss: 1.3549 - learning_rate: 1.2500e-05
# Epoch 234/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6016 - loss: 0.4728 - val_accuracy: 0.4779 - val_loss: 1.3294 - learning_rate: 1.2500e-05
# Epoch 235/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6090 - loss: 0.4792 - val_accuracy: 0.4721 - val_loss: 1.3365 - learning_rate: 1.2500e-05
# Epoch 236/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5970 - loss: 0.4532 - val_accuracy: 0.4767 - val_loss: 1.3399 - learning_rate: 1.2500e-05
# Epoch 237/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6150 - loss: 0.4559 - val_accuracy: 0.4860 - val_loss: 1.3284 - learning_rate: 1.2500e-05
# Epoch 238/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6170 - loss: 0.4638 - val_accuracy: 0.4773 - val_loss: 1.3409 - learning_rate: 1.2500e-05
# Epoch 239/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5913 - loss: 0.4675 - val_accuracy: 0.4762 - val_loss: 1.3404 - learning_rate: 1.2500e-05
# Epoch 240/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6128 - loss: 0.4628 - val_accuracy: 0.4750 - val_loss: 1.3538 - learning_rate: 1.2500e-05
# Epoch 241/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5958 - loss: 0.4737 - val_accuracy: 0.4855 - val_loss: 1.3306 - learning_rate: 1.2500e-05
# Epoch 242/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6113 - loss: 0.4588 - val_accuracy: 0.4872 - val_loss: 1.3411 - learning_rate: 1.2500e-05
# Epoch 243/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6090 - loss: 0.4682 - val_accuracy: 0.4843 - val_loss: 1.3410 - learning_rate: 1.2500e-05
# Epoch 244/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6145 - loss: 0.4615 - val_accuracy: 0.4849 - val_loss: 1.3400 - learning_rate: 1.2500e-05
# Epoch 245/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5998 - loss: 0.4733 - val_accuracy: 0.4808 - val_loss: 1.3420 - learning_rate: 1.2500e-05
# Epoch 246/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6000 - loss: 0.4757 - val_accuracy: 0.4884 - val_loss: 1.3324 - learning_rate: 1.2500e-05
# Epoch 247/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6260 - loss: 0.4662 - val_accuracy: 0.4837 - val_loss: 1.3418 - learning_rate: 1.2500e-05
# Epoch 248/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6091 - loss: 0.4553 - val_accuracy: 0.4750 - val_loss: 1.3562 - learning_rate: 1.2500e-05
# Epoch 249/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6035 - loss: 0.4598 - val_accuracy: 0.4831 - val_loss: 1.3473 - learning_rate: 1.2500e-05
# Epoch 250/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6162 - loss: 0.4562 - val_accuracy: 0.4831 - val_loss: 1.3452 - learning_rate: 1.2500e-05
# Epoch 251/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5972 - loss: 0.4620 - val_accuracy: 0.4855 - val_loss: 1.3402 - learning_rate: 1.2500e-05
# Epoch 252/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6071 - loss: 0.4575 - val_accuracy: 0.4680 - val_loss: 1.3596 - learning_rate: 1.2500e-05
# Epoch 253/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6130 - loss: 0.4629 - val_accuracy: 0.4895 - val_loss: 1.3421 - learning_rate: 1.2500e-05
# Epoch 254/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6107 - loss: 0.4681 - val_accuracy: 0.4738 - val_loss: 1.3553 - learning_rate: 1.2500e-05
# Epoch 255/500
# 165/172 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6200 - loss: 0.4549
# Epoch 255: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6198 - loss: 0.4547 - val_accuracy: 0.4913 - val_loss: 1.3415 - learning_rate: 1.2500e-05
# Epoch 256/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6070 - loss: 0.4656 - val_accuracy: 0.4837 - val_loss: 1.3467 - learning_rate: 6.2500e-06
# Epoch 257/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6005 - loss: 0.4556 - val_accuracy: 0.4820 - val_loss: 1.3529 - learning_rate: 6.2500e-06
# Epoch 258/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5989 - loss: 0.4717 - val_accuracy: 0.4808 - val_loss: 1.3496 - learning_rate: 6.2500e-06
# Epoch 259/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6026 - loss: 0.4666 - val_accuracy: 0.4814 - val_loss: 1.3510 - learning_rate: 6.2500e-06
# Epoch 260/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6139 - loss: 0.4542 - val_accuracy: 0.4849 - val_loss: 1.3465 - learning_rate: 6.2500e-06
# Epoch 261/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6077 - loss: 0.4656 - val_accuracy: 0.4890 - val_loss: 1.3448 - learning_rate: 6.2500e-06
# Epoch 262/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6141 - loss: 0.4575 - val_accuracy: 0.4849 - val_loss: 1.3470 - learning_rate: 6.2500e-06
# Epoch 263/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6146 - loss: 0.4602 - val_accuracy: 0.4860 - val_loss: 1.3462 - learning_rate: 6.2500e-06
# Epoch 264/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6185 - loss: 0.4648 - val_accuracy: 0.4895 - val_loss: 1.3514 - learning_rate: 6.2500e-06
# Epoch 265/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6304 - loss: 0.4430 - val_accuracy: 0.4895 - val_loss: 1.3529 - learning_rate: 6.2500e-06
# Epoch 266/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5952 - loss: 0.4661 - val_accuracy: 0.4878 - val_loss: 1.3501 - learning_rate: 6.2500e-06
# Epoch 267/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5971 - loss: 0.4616 - val_accuracy: 0.4831 - val_loss: 1.3567 - learning_rate: 6.2500e-06
# Epoch 268/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6042 - loss: 0.4565 - val_accuracy: 0.4860 - val_loss: 1.3533 - learning_rate: 6.2500e-06
# Epoch 269/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6080 - loss: 0.4506 - val_accuracy: 0.4878 - val_loss: 1.3496 - learning_rate: 6.2500e-06
# Epoch 270/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6038 - loss: 0.4602 - val_accuracy: 0.4849 - val_loss: 1.3526 - learning_rate: 6.2500e-06
# Epoch 271/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5994 - loss: 0.4676 - val_accuracy: 0.4831 - val_loss: 1.3509 - learning_rate: 6.2500e-06
# Epoch 272/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6178 - loss: 0.4390 - val_accuracy: 0.4866 - val_loss: 1.3528 - learning_rate: 6.2500e-06
# Epoch 273/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6212 - loss: 0.4456 - val_accuracy: 0.4826 - val_loss: 1.3538 - learning_rate: 6.2500e-06
# Epoch 274/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6060 - loss: 0.4756 - val_accuracy: 0.4820 - val_loss: 1.3566 - learning_rate: 6.2500e-06
# Epoch 275/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6102 - loss: 0.4498 - val_accuracy: 0.4855 - val_loss: 1.3532 - learning_rate: 6.2500e-06
# Epoch 276/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6062 - loss: 0.4707 - val_accuracy: 0.4814 - val_loss: 1.3552 - learning_rate: 6.2500e-06
# Epoch 277/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6102 - loss: 0.4518 - val_accuracy: 0.4860 - val_loss: 1.3537 - learning_rate: 6.2500e-06
# Epoch 278/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6124 - loss: 0.4664 - val_accuracy: 0.4872 - val_loss: 1.3505 - learning_rate: 6.2500e-06
# Epoch 279/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6033 - loss: 0.4553 - val_accuracy: 0.4826 - val_loss: 1.3582 - learning_rate: 6.2500e-06
# Epoch 280/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6165 - loss: 0.4655 - val_accuracy: 0.4773 - val_loss: 1.3649 - learning_rate: 6.2500e-06
# Epoch 281/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6043 - loss: 0.4465 - val_accuracy: 0.4895 - val_loss: 1.3566 - learning_rate: 6.2500e-06
# Epoch 282/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6133 - loss: 0.4679 - val_accuracy: 0.4849 - val_loss: 1.3582 - learning_rate: 6.2500e-06
# Epoch 283/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6174 - loss: 0.4528 - val_accuracy: 0.4826 - val_loss: 1.3603 - learning_rate: 6.2500e-06
# Epoch 284/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6153 - loss: 0.4593 - val_accuracy: 0.4826 - val_loss: 1.3606 - learning_rate: 6.2500e-06
# Epoch 285/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6144 - loss: 0.4620 - val_accuracy: 0.4820 - val_loss: 1.3641 - learning_rate: 6.2500e-06
# Epoch 286/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6093 - loss: 0.4452 - val_accuracy: 0.4791 - val_loss: 1.3658 - learning_rate: 6.2500e-06
# Epoch 287/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6104 - loss: 0.4597 - val_accuracy: 0.4785 - val_loss: 1.3687 - learning_rate: 6.2500e-06
# Epoch 288/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6177 - loss: 0.4354 - val_accuracy: 0.4802 - val_loss: 1.3668 - learning_rate: 6.2500e-06
# Epoch 289/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6173 - loss: 0.4537 - val_accuracy: 0.4820 - val_loss: 1.3659 - learning_rate: 6.2500e-06
# Epoch 290/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6200 - loss: 0.4444 - val_accuracy: 0.4849 - val_loss: 1.3661 - learning_rate: 6.2500e-06
# Epoch 291/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6079 - loss: 0.4682 - val_accuracy: 0.4855 - val_loss: 1.3661 - learning_rate: 6.2500e-06
# Epoch 292/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6064 - loss: 0.4432 - val_accuracy: 0.4802 - val_loss: 1.3690 - learning_rate: 6.2500e-06
# Epoch 293/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6069 - loss: 0.4657 - val_accuracy: 0.4820 - val_loss: 1.3662 - learning_rate: 6.2500e-06
# Epoch 294/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6298 - loss: 0.4573 - val_accuracy: 0.4849 - val_loss: 1.3638 - learning_rate: 6.2500e-06
# Epoch 295/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6180 - loss: 0.4431 - val_accuracy: 0.4837 - val_loss: 1.3654 - learning_rate: 6.2500e-06
# Epoch 296/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6111 - loss: 0.4668 - val_accuracy: 0.4831 - val_loss: 1.3683 - learning_rate: 6.2500e-06
# Epoch 297/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6100 - loss: 0.4460 - val_accuracy: 0.4831 - val_loss: 1.3687 - learning_rate: 6.2500e-06
# Epoch 298/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6108 - loss: 0.4595 - val_accuracy: 0.4820 - val_loss: 1.3735 - learning_rate: 6.2500e-06
# Epoch 299/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6284 - loss: 0.4362 - val_accuracy: 0.4802 - val_loss: 1.3758 - learning_rate: 6.2500e-06
# Epoch 300/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6227 - loss: 0.4460 - val_accuracy: 0.4814 - val_loss: 1.3720 - learning_rate: 6.2500e-06
# Epoch 301/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6213 - loss: 0.4585 - val_accuracy: 0.4837 - val_loss: 1.3732 - learning_rate: 6.2500e-06
# Epoch 302/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6141 - loss: 0.4419 - val_accuracy: 0.4831 - val_loss: 1.3739 - learning_rate: 6.2500e-06
# Epoch 303/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6102 - loss: 0.4588 - val_accuracy: 0.4797 - val_loss: 1.3758 - learning_rate: 6.2500e-06
# Epoch 304/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6150 - loss: 0.4491 - val_accuracy: 0.4797 - val_loss: 1.3746 - learning_rate: 6.2500e-06
# Epoch 305/500
# 164/172 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6103 - loss: 0.4535
# Epoch 305: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6103 - loss: 0.4532 - val_accuracy: 0.4855 - val_loss: 1.3715 - learning_rate: 6.2500e-06
# Epoch 305: early stopping
# Restoring model weights from the end of the best epoch: 55.

# %%
# Accuracy for 5 patience LR
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title(f'Accuracy vs Val_Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Accuracy for 50 lr
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Accuracy')
plt.plot(history.history['val_loss'], label='Validation Accuracy')
plt.title(f'Modelo {1} - Loss vs Val_Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predicciones individuales de cada modelo
preds = model.predict(X_test)
final_preds = np.argmax(preds, axis=1)
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 5 LR
cm = confusion_matrix(y_test, final_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.arange(cm.shape[1]), yticklabels=np.arange(cm.shape[0]))
plt.title("Matriz de Confusión")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")
plt.show()

# %%
# Classification report 5 LR
print(classification_report(y_test, final_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.000     0.000     0.000         4
#            1      0.055     0.148     0.081        81
#            2      0.534     0.647     0.585       861
#            3      0.455     0.242     0.316       777
#
#     accuracy                          0.439      1723
#    macro avg      0.261     0.259     0.245      1723
# weighted avg      0.474     0.439     0.438      1723

# %%
# View metric UAR
def uar(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    uar = np.mean(np.diag(cm) / np.sum(cm, axis=1))
    return uar

uar_score = uar(y_test, final_preds)
print(f"UAR: {uar_score:.4f}")
# Out:
# UAR: 0.2593
