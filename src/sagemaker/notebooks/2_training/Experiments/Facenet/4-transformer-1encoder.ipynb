# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight

from tensorflow.keras.layers import Input, Dense, Dropout, MultiHeadAttention, Add, GlobalAveragePooling1D, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# Charge npy files
def charge_npy(path):
    X = np.load(path)
    y = np.load(path.replace('X', 'y'))
    return X, y

# %%
# Charge embeddings of Facenet for Train, Val and Test
path_train = '../../../../Facenet Embeddings/Train/X_train.npy'
path_val   = '../../../../Facenet Embeddings/Val/X_val.npy'
path_test  = '../../../../Facenet Embeddings/Test/X_test.npy'
X_train, y_train = charge_npy(path_train)
X_val, y_val = charge_npy(path_val)
X_test, y_test = charge_npy(path_test)

n_frames = 5
embedding_dim = 128

X_train = X_train.reshape((-1, n_frames, embedding_dim))
y_train = y_train[:, 4:8]
y_train = np.mean(y_train.reshape(-1, 5, 4), axis=1)
y_train = np.argmax(y_train, axis=1)

X_val = X_val.reshape((-1, n_frames, embedding_dim)) 
y_val = y_val[:, 4:8]
y_val = np.mean(y_val.reshape(-1, 5, 4), axis=1)
y_val = np.argmax(y_val, axis=1)

X_test = X_test.reshape((-1, n_frames, embedding_dim))  
y_test = y_test[:, 4:8]
y_test = np.mean(y_test.reshape(-1, 5, 4), axis=1)
y_test = np.argmax(y_test, axis=1)

X = np.concatenate((X_val, X_test), axis=0)
y = np.concatenate((y_val, y_test), axis=0)

# %%
# Divide data in Val and test
X_val, X_test, y_val, y_test = train_test_split(X, y, test_size=0.5, random_state=123, stratify=y)
X_train.shape, X_val.shape, X_test.shape, y_train.shape, y_val.shape, y_test.shape
# Out:
# ((5481, 5, 128), (1721, 5, 128), (1722, 5, 128), (5481,), (1721,), (1722,))

# %%
# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# {0: 40.3014705882353,
#  1: 6.40303738317757,
#  2: 0.5172706681766704,
#  3: 0.5302825077399381}

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=250, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=100, verbose=1)

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    # Multi-Head Attention
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Add()([x, inputs])
    x = LayerNormalization(epsilon=1e-6)(x)

    # Feed-Forward Network
    ff = Dense(ff_dim, activation="relu")(x)
    ff = Dropout(dropout)(ff)
    ff = Dense(inputs.shape[-1])(ff)
    x = Add()([x, ff])
    x = LayerNormalization(epsilon=1e-6)(x)

    return x

def build_transformer_model(input_shape):
    inputs = Input(shape=input_shape)

    # Transformer Encoder
    x = transformer_encoder(inputs, head_size=64, num_heads=4, ff_dim=128, dropout=0.2)

    # Pooling + Dense
    x = GlobalAveragePooling1D()(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.5)(x)
    outputs = Dense(4, activation="softmax")(x)

    model = Model(inputs, outputs)
    model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(1e-4), metrics=["accuracy"])
    return model

# Create and Train Transformer model
model = build_transformer_model((X_train.shape[1], X_train.shape[2]))

history = model.fit(
    X_train,
    y_train,
    class_weight=class_weights,
    epochs=1000,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/500
# I0000 00:00:1747000887.383389   80923 service.cc:146] XLA service 0x7fc734003ec0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747000887.383439   80923 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2025-05-11 17:01:27.833375: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-05-11 17:01:28.594102: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90101
#  38/172 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2733 - loss: 1.6528
# I0000 00:00:1747000893.012921   80923 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.3038 - loss: 1.7223 - val_accuracy: 0.3539 - val_loss: 1.2865 - learning_rate: 1.0000e-04
# Epoch 2/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3281 - loss: 1.4401 - val_accuracy: 0.3463 - val_loss: 1.3373 - learning_rate: 1.0000e-04
# Epoch 3/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3346 - loss: 1.3665 - val_accuracy: 0.3463 - val_loss: 1.3130 - learning_rate: 1.0000e-04
# Epoch 4/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3382 - loss: 1.5811 - val_accuracy: 0.3062 - val_loss: 1.3201 - learning_rate: 1.0000e-04
# Epoch 5/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3648 - loss: 1.2562 - val_accuracy: 0.2911 - val_loss: 1.3371 - learning_rate: 1.0000e-04
# Epoch 6/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3681 - loss: 1.2126 - val_accuracy: 0.3045 - val_loss: 1.3248 - learning_rate: 1.0000e-04
# Epoch 7/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3691 - loss: 1.1437 - val_accuracy: 0.3027 - val_loss: 1.3553 - learning_rate: 1.0000e-04
# Epoch 8/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3582 - loss: 1.2461 - val_accuracy: 0.3521 - val_loss: 1.2715 - learning_rate: 1.0000e-04
# Epoch 9/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3949 - loss: 1.1610 - val_accuracy: 0.3219 - val_loss: 1.2964 - learning_rate: 1.0000e-04
# Epoch 10/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4004 - loss: 1.1715 - val_accuracy: 0.3684 - val_loss: 1.2385 - learning_rate: 1.0000e-04
# Epoch 11/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3955 - loss: 1.3015 - val_accuracy: 0.3974 - val_loss: 1.2306 - learning_rate: 1.0000e-04
# Epoch 12/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4349 - loss: 1.0981 - val_accuracy: 0.3364 - val_loss: 1.3113 - learning_rate: 1.0000e-04
# Epoch 13/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3810 - loss: 1.2101 - val_accuracy: 0.3992 - val_loss: 1.1962 - learning_rate: 1.0000e-04
# Epoch 14/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4272 - loss: 1.0510 - val_accuracy: 0.3335 - val_loss: 1.2912 - learning_rate: 1.0000e-04
# Epoch 15/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4024 - loss: 1.2128 - val_accuracy: 0.3498 - val_loss: 1.2516 - learning_rate: 1.0000e-04
# Epoch 16/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4068 - loss: 1.1218 - val_accuracy: 0.3504 - val_loss: 1.2384 - learning_rate: 1.0000e-04
# Epoch 17/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4253 - loss: 1.0347 - val_accuracy: 0.3388 - val_loss: 1.2256 - learning_rate: 1.0000e-04
# Epoch 18/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4298 - loss: 1.0681 - val_accuracy: 0.3916 - val_loss: 1.1641 - learning_rate: 1.0000e-04
# Epoch 19/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4526 - loss: 1.0038 - val_accuracy: 0.3399 - val_loss: 1.2471 - learning_rate: 1.0000e-04
# Epoch 20/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4259 - loss: 1.0489 - val_accuracy: 0.3719 - val_loss: 1.2058 - learning_rate: 1.0000e-04
# Epoch 21/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4373 - loss: 1.1027 - val_accuracy: 0.3463 - val_loss: 1.2103 - learning_rate: 1.0000e-04
# Epoch 22/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4272 - loss: 1.0753 - val_accuracy: 0.3928 - val_loss: 1.2052 - learning_rate: 1.0000e-04
# Epoch 23/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4300 - loss: 1.0491 - val_accuracy: 0.3539 - val_loss: 1.2298 - learning_rate: 1.0000e-04
# Epoch 24/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4446 - loss: 1.0343 - val_accuracy: 0.3684 - val_loss: 1.1974 - learning_rate: 1.0000e-04
# Epoch 25/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4486 - loss: 0.9517 - val_accuracy: 0.3463 - val_loss: 1.2377 - learning_rate: 1.0000e-04
# Epoch 26/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4434 - loss: 0.9924 - val_accuracy: 0.3271 - val_loss: 1.3044 - learning_rate: 1.0000e-04
# Epoch 27/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4286 - loss: 1.0507 - val_accuracy: 0.4056 - val_loss: 1.1877 - learning_rate: 1.0000e-04
# Epoch 28/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4306 - loss: 0.9963 - val_accuracy: 0.4184 - val_loss: 1.1507 - learning_rate: 1.0000e-04
# Epoch 29/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4584 - loss: 0.9472 - val_accuracy: 0.3446 - val_loss: 1.2557 - learning_rate: 1.0000e-04
# Epoch 30/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4622 - loss: 0.9061 - val_accuracy: 0.3794 - val_loss: 1.1979 - learning_rate: 1.0000e-04
# Epoch 31/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4620 - loss: 0.9769 - val_accuracy: 0.3957 - val_loss: 1.1785 - learning_rate: 1.0000e-04
# Epoch 32/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4574 - loss: 0.9259 - val_accuracy: 0.3637 - val_loss: 1.2131 - learning_rate: 1.0000e-04
# Epoch 33/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4515 - loss: 0.9959 - val_accuracy: 0.3754 - val_loss: 1.1857 - learning_rate: 1.0000e-04
# Epoch 34/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4845 - loss: 0.9553 - val_accuracy: 0.3765 - val_loss: 1.1885 - learning_rate: 1.0000e-04
# Epoch 35/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4574 - loss: 0.9520 - val_accuracy: 0.3347 - val_loss: 1.2728 - learning_rate: 1.0000e-04
# Epoch 36/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4657 - loss: 0.9298 - val_accuracy: 0.3451 - val_loss: 1.2315 - learning_rate: 1.0000e-04
# Epoch 37/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4718 - loss: 0.8928 - val_accuracy: 0.3655 - val_loss: 1.2132 - learning_rate: 1.0000e-04
# Epoch 38/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4553 - loss: 0.9608 - val_accuracy: 0.3928 - val_loss: 1.1710 - learning_rate: 1.0000e-04
# Epoch 39/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4872 - loss: 0.8698 - val_accuracy: 0.3382 - val_loss: 1.2261 - learning_rate: 1.0000e-04
# Epoch 40/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4601 - loss: 0.8510 - val_accuracy: 0.3759 - val_loss: 1.1962 - learning_rate: 1.0000e-04
# Epoch 41/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4863 - loss: 0.8465 - val_accuracy: 0.3969 - val_loss: 1.1649 - learning_rate: 1.0000e-04
# Epoch 42/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4795 - loss: 0.8592 - val_accuracy: 0.3986 - val_loss: 1.1694 - learning_rate: 1.0000e-04
# Epoch 43/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4718 - loss: 0.8766 - val_accuracy: 0.3597 - val_loss: 1.2001 - learning_rate: 1.0000e-04
# Epoch 44/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4685 - loss: 0.8827 - val_accuracy: 0.3504 - val_loss: 1.2181 - learning_rate: 1.0000e-04
# Epoch 45/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4583 - loss: 0.8808 - val_accuracy: 0.3928 - val_loss: 1.1645 - learning_rate: 1.0000e-04
# Epoch 46/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4784 - loss: 0.8656 - val_accuracy: 0.3539 - val_loss: 1.2191 - learning_rate: 1.0000e-04
# Epoch 47/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4567 - loss: 0.8847 - val_accuracy: 0.3649 - val_loss: 1.2212 - learning_rate: 1.0000e-04
# Epoch 48/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4873 - loss: 0.8337 - val_accuracy: 0.3626 - val_loss: 1.2214 - learning_rate: 1.0000e-04
# Epoch 49/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4713 - loss: 0.8433 - val_accuracy: 0.3655 - val_loss: 1.2085 - learning_rate: 1.0000e-04
# Epoch 50/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4998 - loss: 0.7879 - val_accuracy: 0.3701 - val_loss: 1.2020 - learning_rate: 1.0000e-04
# Epoch 51/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4814 - loss: 0.8162 - val_accuracy: 0.3603 - val_loss: 1.2049 - learning_rate: 1.0000e-04
# Epoch 52/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4826 - loss: 0.7983 - val_accuracy: 0.4166 - val_loss: 1.1481 - learning_rate: 1.0000e-04
# Epoch 53/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4898 - loss: 0.8385 - val_accuracy: 0.3771 - val_loss: 1.1933 - learning_rate: 1.0000e-04
# Epoch 54/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4898 - loss: 0.8220 - val_accuracy: 0.3725 - val_loss: 1.2092 - learning_rate: 1.0000e-04
# Epoch 55/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4845 - loss: 0.8164 - val_accuracy: 0.3754 - val_loss: 1.1823 - learning_rate: 1.0000e-04
# Epoch 56/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4966 - loss: 0.8076 - val_accuracy: 0.3812 - val_loss: 1.2015 - learning_rate: 1.0000e-04
# Epoch 57/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4854 - loss: 0.7977 - val_accuracy: 0.3847 - val_loss: 1.1773 - learning_rate: 1.0000e-04
# Epoch 58/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4604 - loss: 0.8824 - val_accuracy: 0.3550 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 59/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4814 - loss: 0.8043 - val_accuracy: 0.3521 - val_loss: 1.2320 - learning_rate: 1.0000e-04
# Epoch 60/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4734 - loss: 0.8283 - val_accuracy: 0.3829 - val_loss: 1.2019 - learning_rate: 1.0000e-04
# Epoch 61/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4987 - loss: 0.7918 - val_accuracy: 0.3986 - val_loss: 1.1617 - learning_rate: 1.0000e-04
# Epoch 62/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5167 - loss: 0.7641 - val_accuracy: 0.3771 - val_loss: 1.2173 - learning_rate: 1.0000e-04
# Epoch 63/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5002 - loss: 0.7516 - val_accuracy: 0.3806 - val_loss: 1.2113 - learning_rate: 1.0000e-04
# Epoch 64/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5107 - loss: 0.7471 - val_accuracy: 0.3800 - val_loss: 1.1925 - learning_rate: 1.0000e-04
# Epoch 65/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5216 - loss: 0.7293 - val_accuracy: 0.3591 - val_loss: 1.2198 - learning_rate: 1.0000e-04
# Epoch 66/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4989 - loss: 0.7135 - val_accuracy: 0.3666 - val_loss: 1.2220 - learning_rate: 1.0000e-04
# Epoch 67/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5171 - loss: 0.7154 - val_accuracy: 0.3765 - val_loss: 1.2425 - learning_rate: 1.0000e-04
# Epoch 68/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4723 - loss: 0.7831 - val_accuracy: 0.3870 - val_loss: 1.2209 - learning_rate: 1.0000e-04
# Epoch 69/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4981 - loss: 0.7452 - val_accuracy: 0.3719 - val_loss: 1.2087 - learning_rate: 1.0000e-04
# Epoch 70/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5123 - loss: 0.7237 - val_accuracy: 0.3730 - val_loss: 1.2082 - learning_rate: 1.0000e-04
# Epoch 71/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5111 - loss: 0.7246 - val_accuracy: 0.3771 - val_loss: 1.2173 - learning_rate: 1.0000e-04
# Epoch 72/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4986 - loss: 0.7276 - val_accuracy: 0.3771 - val_loss: 1.2150 - learning_rate: 1.0000e-04
# Epoch 73/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5071 - loss: 0.7015 - val_accuracy: 0.3696 - val_loss: 1.2396 - learning_rate: 1.0000e-04
# Epoch 74/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4996 - loss: 0.7603 - val_accuracy: 0.3905 - val_loss: 1.1967 - learning_rate: 1.0000e-04
# Epoch 75/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5283 - loss: 0.7244 - val_accuracy: 0.3754 - val_loss: 1.2330 - learning_rate: 1.0000e-04
# Epoch 76/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5123 - loss: 0.7372 - val_accuracy: 0.3870 - val_loss: 1.2171 - learning_rate: 1.0000e-04
# Epoch 77/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5114 - loss: 0.7727 - val_accuracy: 0.3690 - val_loss: 1.2362 - learning_rate: 1.0000e-04
# Epoch 78/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5266 - loss: 0.6978 - val_accuracy: 0.3823 - val_loss: 1.2204 - learning_rate: 1.0000e-04
# Epoch 79/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5207 - loss: 0.7100 - val_accuracy: 0.4003 - val_loss: 1.1747 - learning_rate: 1.0000e-04
# Epoch 80/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5212 - loss: 0.7342 - val_accuracy: 0.3713 - val_loss: 1.2481 - learning_rate: 1.0000e-04
# Epoch 81/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5265 - loss: 0.6913 - val_accuracy: 0.3847 - val_loss: 1.2331 - learning_rate: 1.0000e-04
# Epoch 82/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5104 - loss: 0.6989 - val_accuracy: 0.4091 - val_loss: 1.2020 - learning_rate: 1.0000e-04
# Epoch 83/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4932 - loss: 0.7259 - val_accuracy: 0.4096 - val_loss: 1.1886 - learning_rate: 1.0000e-04
# Epoch 84/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5167 - loss: 0.6751 - val_accuracy: 0.3876 - val_loss: 1.2322 - learning_rate: 1.0000e-04
# Epoch 85/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5138 - loss: 0.6759 - val_accuracy: 0.4096 - val_loss: 1.2058 - learning_rate: 1.0000e-04
# Epoch 86/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5267 - loss: 0.7009 - val_accuracy: 0.3730 - val_loss: 1.2880 - learning_rate: 1.0000e-04
# Epoch 87/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5099 - loss: 0.6878 - val_accuracy: 0.3963 - val_loss: 1.2096 - learning_rate: 1.0000e-04
# Epoch 88/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5023 - loss: 0.6736 - val_accuracy: 0.3800 - val_loss: 1.2526 - learning_rate: 1.0000e-04
# Epoch 89/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5320 - loss: 0.6358 - val_accuracy: 0.4056 - val_loss: 1.2251 - learning_rate: 1.0000e-04
# Epoch 90/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5233 - loss: 0.6704 - val_accuracy: 0.3998 - val_loss: 1.2216 - learning_rate: 1.0000e-04
# Epoch 91/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5227 - loss: 0.6867 - val_accuracy: 0.3974 - val_loss: 1.2261 - learning_rate: 1.0000e-04
# Epoch 92/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5106 - loss: 0.6647 - val_accuracy: 0.3684 - val_loss: 1.2994 - learning_rate: 1.0000e-04
# Epoch 93/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5026 - loss: 0.6924 - val_accuracy: 0.3858 - val_loss: 1.2637 - learning_rate: 1.0000e-04
# Epoch 94/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5228 - loss: 0.7125 - val_accuracy: 0.3858 - val_loss: 1.2586 - learning_rate: 1.0000e-04
# Epoch 95/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5163 - loss: 0.6676 - val_accuracy: 0.4102 - val_loss: 1.2182 - learning_rate: 1.0000e-04
# Epoch 96/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5365 - loss: 0.6583 - val_accuracy: 0.4184 - val_loss: 1.1889 - learning_rate: 1.0000e-04
# Epoch 97/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5343 - loss: 0.6548 - val_accuracy: 0.3858 - val_loss: 1.2688 - learning_rate: 1.0000e-04
# Epoch 98/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5302 - loss: 0.6350 - val_accuracy: 0.3719 - val_loss: 1.2901 - learning_rate: 1.0000e-04
# Epoch 99/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5459 - loss: 0.6394 - val_accuracy: 0.3951 - val_loss: 1.2466 - learning_rate: 1.0000e-04
# Epoch 100/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5202 - loss: 0.6542 - val_accuracy: 0.3940 - val_loss: 1.2554 - learning_rate: 1.0000e-04
# Epoch 101/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5290 - loss: 0.6763 - val_accuracy: 0.3788 - val_loss: 1.2438 - learning_rate: 1.0000e-04
# Epoch 102/500
# 162/172 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5413 - loss: 0.6448
# Epoch 102: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5413 - loss: 0.6448 - val_accuracy: 0.4160 - val_loss: 1.2147 - learning_rate: 1.0000e-04
# Epoch 103/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5356 - loss: 0.6576 - val_accuracy: 0.4021 - val_loss: 1.2289 - learning_rate: 5.0000e-05
# Epoch 104/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5556 - loss: 0.5713 - val_accuracy: 0.3922 - val_loss: 1.2690 - learning_rate: 5.0000e-05
# Epoch 105/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5450 - loss: 0.6415 - val_accuracy: 0.3765 - val_loss: 1.2922 - learning_rate: 5.0000e-05
# Epoch 106/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5402 - loss: 0.5886 - val_accuracy: 0.3963 - val_loss: 1.2601 - learning_rate: 5.0000e-05
# Epoch 107/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5351 - loss: 0.6236 - val_accuracy: 0.3992 - val_loss: 1.2585 - learning_rate: 5.0000e-05
# Epoch 108/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5295 - loss: 0.6202 - val_accuracy: 0.3928 - val_loss: 1.2491 - learning_rate: 5.0000e-05
# Epoch 109/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5423 - loss: 0.5895 - val_accuracy: 0.3771 - val_loss: 1.3065 - learning_rate: 5.0000e-05
# Epoch 110/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5365 - loss: 0.6207 - val_accuracy: 0.3963 - val_loss: 1.2592 - learning_rate: 5.0000e-05
# Epoch 111/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5571 - loss: 0.5765 - val_accuracy: 0.3945 - val_loss: 1.2583 - learning_rate: 5.0000e-05
# Epoch 112/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5546 - loss: 0.5833 - val_accuracy: 0.3928 - val_loss: 1.2812 - learning_rate: 5.0000e-05
# Epoch 113/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5489 - loss: 0.5949 - val_accuracy: 0.4021 - val_loss: 1.2603 - learning_rate: 5.0000e-05
# Epoch 114/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5516 - loss: 0.5959 - val_accuracy: 0.4027 - val_loss: 1.2547 - learning_rate: 5.0000e-05
# Epoch 115/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5606 - loss: 0.5755 - val_accuracy: 0.3928 - val_loss: 1.2820 - learning_rate: 5.0000e-05
# Epoch 116/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5541 - loss: 0.5879 - val_accuracy: 0.4003 - val_loss: 1.2565 - learning_rate: 5.0000e-05
# Epoch 117/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5315 - loss: 0.5918 - val_accuracy: 0.4003 - val_loss: 1.2651 - learning_rate: 5.0000e-05
# Epoch 118/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5513 - loss: 0.5909 - val_accuracy: 0.3998 - val_loss: 1.2757 - learning_rate: 5.0000e-05
# Epoch 119/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5452 - loss: 0.6082 - val_accuracy: 0.4189 - val_loss: 1.2361 - learning_rate: 5.0000e-05
# Epoch 120/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5495 - loss: 0.6043 - val_accuracy: 0.4056 - val_loss: 1.2561 - learning_rate: 5.0000e-05
# Epoch 121/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5491 - loss: 0.5813 - val_accuracy: 0.4038 - val_loss: 1.2576 - learning_rate: 5.0000e-05
# Epoch 122/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5502 - loss: 0.5738 - val_accuracy: 0.4114 - val_loss: 1.2329 - learning_rate: 5.0000e-05
# Epoch 123/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5603 - loss: 0.5867 - val_accuracy: 0.4143 - val_loss: 1.2309 - learning_rate: 5.0000e-05
# Epoch 124/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5825 - loss: 0.5802 - val_accuracy: 0.3998 - val_loss: 1.2916 - learning_rate: 5.0000e-05
# Epoch 125/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5434 - loss: 0.5761 - val_accuracy: 0.4195 - val_loss: 1.2466 - learning_rate: 5.0000e-05
# Epoch 126/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5589 - loss: 0.5511 - val_accuracy: 0.4033 - val_loss: 1.2699 - learning_rate: 5.0000e-05
# Epoch 127/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5533 - loss: 0.5973 - val_accuracy: 0.4184 - val_loss: 1.2715 - learning_rate: 5.0000e-05
# Epoch 128/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5648 - loss: 0.5539 - val_accuracy: 0.4149 - val_loss: 1.2642 - learning_rate: 5.0000e-05
# Epoch 129/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5608 - loss: 0.5538 - val_accuracy: 0.4149 - val_loss: 1.2515 - learning_rate: 5.0000e-05
# Epoch 130/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5373 - loss: 0.5846 - val_accuracy: 0.4114 - val_loss: 1.2686 - learning_rate: 5.0000e-05
# Epoch 131/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5584 - loss: 0.5719 - val_accuracy: 0.3945 - val_loss: 1.2933 - learning_rate: 5.0000e-05
# Epoch 132/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5518 - loss: 0.5807 - val_accuracy: 0.4126 - val_loss: 1.2690 - learning_rate: 5.0000e-05
# Epoch 133/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5626 - loss: 0.5797 - val_accuracy: 0.4201 - val_loss: 1.2669 - learning_rate: 5.0000e-05
# Epoch 134/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5597 - loss: 0.5616 - val_accuracy: 0.4044 - val_loss: 1.2981 - learning_rate: 5.0000e-05
# Epoch 135/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5402 - loss: 0.5960 - val_accuracy: 0.4155 - val_loss: 1.2703 - learning_rate: 5.0000e-05
# Epoch 136/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5456 - loss: 0.5615 - val_accuracy: 0.4021 - val_loss: 1.2884 - learning_rate: 5.0000e-05
# Epoch 137/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5567 - loss: 0.5520 - val_accuracy: 0.4079 - val_loss: 1.2767 - learning_rate: 5.0000e-05
# Epoch 138/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5323 - loss: 0.5736 - val_accuracy: 0.4184 - val_loss: 1.2613 - learning_rate: 5.0000e-05
# Epoch 139/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5566 - loss: 0.5692 - val_accuracy: 0.4073 - val_loss: 1.2900 - learning_rate: 5.0000e-05
# Epoch 140/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5661 - loss: 0.5448 - val_accuracy: 0.4213 - val_loss: 1.2681 - learning_rate: 5.0000e-05
# Epoch 141/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5572 - loss: 0.5349 - val_accuracy: 0.3916 - val_loss: 1.3309 - learning_rate: 5.0000e-05
# Epoch 142/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5320 - loss: 0.5969 - val_accuracy: 0.4067 - val_loss: 1.3070 - learning_rate: 5.0000e-05
# Epoch 143/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5539 - loss: 0.5574 - val_accuracy: 0.4021 - val_loss: 1.2829 - learning_rate: 5.0000e-05
# Epoch 144/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5610 - loss: 0.5419 - val_accuracy: 0.4079 - val_loss: 1.2819 - learning_rate: 5.0000e-05
# Epoch 145/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5563 - loss: 0.5539 - val_accuracy: 0.4056 - val_loss: 1.2837 - learning_rate: 5.0000e-05
# Epoch 146/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5777 - loss: 0.5382 - val_accuracy: 0.4073 - val_loss: 1.2972 - learning_rate: 5.0000e-05
# Epoch 147/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5450 - loss: 0.5413 - val_accuracy: 0.4056 - val_loss: 1.3050 - learning_rate: 5.0000e-05
# Epoch 148/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5615 - loss: 0.5480 - val_accuracy: 0.4131 - val_loss: 1.2784 - learning_rate: 5.0000e-05
# Epoch 149/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5687 - loss: 0.5506 - val_accuracy: 0.4062 - val_loss: 1.2852 - learning_rate: 5.0000e-05
# Epoch 150/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5610 - loss: 0.5561 - val_accuracy: 0.4079 - val_loss: 1.2903 - learning_rate: 5.0000e-05
# Epoch 151/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5752 - loss: 0.5313 - val_accuracy: 0.4021 - val_loss: 1.3141 - learning_rate: 5.0000e-05
# Epoch 152/500
# 162/172 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5398 - loss: 0.5559
# Epoch 152: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5406 - loss: 0.5559 - val_accuracy: 0.4050 - val_loss: 1.2933 - learning_rate: 5.0000e-05
# Epoch 153/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5594 - loss: 0.5450 - val_accuracy: 0.4021 - val_loss: 1.2976 - learning_rate: 2.5000e-05
# Epoch 154/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5587 - loss: 0.5515 - val_accuracy: 0.3992 - val_loss: 1.3042 - learning_rate: 2.5000e-05
# Epoch 155/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5768 - loss: 0.5252 - val_accuracy: 0.4120 - val_loss: 1.2904 - learning_rate: 2.5000e-05
# Epoch 156/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5747 - loss: 0.5471 - val_accuracy: 0.4091 - val_loss: 1.2976 - learning_rate: 2.5000e-05
# Epoch 157/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5856 - loss: 0.5074 - val_accuracy: 0.4062 - val_loss: 1.3094 - learning_rate: 2.5000e-05
# Epoch 158/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5659 - loss: 0.5251 - val_accuracy: 0.4108 - val_loss: 1.2931 - learning_rate: 2.5000e-05
# Epoch 159/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5706 - loss: 0.5591 - val_accuracy: 0.4143 - val_loss: 1.3131 - learning_rate: 2.5000e-05
# Epoch 160/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5703 - loss: 0.5248 - val_accuracy: 0.4160 - val_loss: 1.3046 - learning_rate: 2.5000e-05
# Epoch 161/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5764 - loss: 0.5235 - val_accuracy: 0.4073 - val_loss: 1.3060 - learning_rate: 2.5000e-05
# Epoch 162/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5735 - loss: 0.5273 - val_accuracy: 0.4096 - val_loss: 1.3073 - learning_rate: 2.5000e-05
# Epoch 163/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5708 - loss: 0.5245 - val_accuracy: 0.4155 - val_loss: 1.3020 - learning_rate: 2.5000e-05
# Epoch 164/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5851 - loss: 0.5296 - val_accuracy: 0.4149 - val_loss: 1.3167 - learning_rate: 2.5000e-05
# Epoch 165/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5701 - loss: 0.5348 - val_accuracy: 0.4108 - val_loss: 1.3062 - learning_rate: 2.5000e-05
# Epoch 166/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5733 - loss: 0.5344 - val_accuracy: 0.4166 - val_loss: 1.2973 - learning_rate: 2.5000e-05
# Epoch 167/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5738 - loss: 0.5136 - val_accuracy: 0.4108 - val_loss: 1.3145 - learning_rate: 2.5000e-05
# Epoch 168/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5751 - loss: 0.5459 - val_accuracy: 0.4213 - val_loss: 1.2997 - learning_rate: 2.5000e-05
# Epoch 169/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5825 - loss: 0.5003 - val_accuracy: 0.4155 - val_loss: 1.3103 - learning_rate: 2.5000e-05
# Epoch 170/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5672 - loss: 0.5249 - val_accuracy: 0.4096 - val_loss: 1.3192 - learning_rate: 2.5000e-05
# Epoch 171/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5853 - loss: 0.5096 - val_accuracy: 0.4149 - val_loss: 1.3090 - learning_rate: 2.5000e-05
# Epoch 172/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5842 - loss: 0.4937 - val_accuracy: 0.4131 - val_loss: 1.3291 - learning_rate: 2.5000e-05
# Epoch 173/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5824 - loss: 0.5031 - val_accuracy: 0.4120 - val_loss: 1.3327 - learning_rate: 2.5000e-05
# Epoch 174/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5721 - loss: 0.5164 - val_accuracy: 0.4178 - val_loss: 1.3207 - learning_rate: 2.5000e-05
# Epoch 175/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5744 - loss: 0.5285 - val_accuracy: 0.4143 - val_loss: 1.3228 - learning_rate: 2.5000e-05
# Epoch 176/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5755 - loss: 0.5230 - val_accuracy: 0.4137 - val_loss: 1.3257 - learning_rate: 2.5000e-05
# Epoch 177/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5870 - loss: 0.5136 - val_accuracy: 0.4131 - val_loss: 1.3336 - learning_rate: 2.5000e-05
# Epoch 178/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5647 - loss: 0.5146 - val_accuracy: 0.4120 - val_loss: 1.3328 - learning_rate: 2.5000e-05
# Epoch 179/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5733 - loss: 0.5112 - val_accuracy: 0.4021 - val_loss: 1.3444 - learning_rate: 2.5000e-05
# Epoch 180/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5702 - loss: 0.5099 - val_accuracy: 0.4126 - val_loss: 1.3156 - learning_rate: 2.5000e-05
# Epoch 181/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5658 - loss: 0.5077 - val_accuracy: 0.4131 - val_loss: 1.3259 - learning_rate: 2.5000e-05
# Epoch 182/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5796 - loss: 0.4958 - val_accuracy: 0.4201 - val_loss: 1.3293 - learning_rate: 2.5000e-05
# Epoch 183/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5908 - loss: 0.5043 - val_accuracy: 0.4137 - val_loss: 1.3233 - learning_rate: 2.5000e-05
# Epoch 184/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5798 - loss: 0.5067 - val_accuracy: 0.4137 - val_loss: 1.3377 - learning_rate: 2.5000e-05
# Epoch 185/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5779 - loss: 0.5177 - val_accuracy: 0.4096 - val_loss: 1.3404 - learning_rate: 2.5000e-05
# Epoch 186/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5822 - loss: 0.5129 - val_accuracy: 0.4218 - val_loss: 1.3222 - learning_rate: 2.5000e-05
# Epoch 187/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5800 - loss: 0.5032 - val_accuracy: 0.4184 - val_loss: 1.3336 - learning_rate: 2.5000e-05
# Epoch 188/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5722 - loss: 0.4936 - val_accuracy: 0.4108 - val_loss: 1.3572 - learning_rate: 2.5000e-05
# Epoch 189/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5742 - loss: 0.5303 - val_accuracy: 0.4155 - val_loss: 1.3322 - learning_rate: 2.5000e-05
# Epoch 190/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5691 - loss: 0.5128 - val_accuracy: 0.4178 - val_loss: 1.3270 - learning_rate: 2.5000e-05
# Epoch 191/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5756 - loss: 0.5079 - val_accuracy: 0.4149 - val_loss: 1.3254 - learning_rate: 2.5000e-05
# Epoch 192/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5804 - loss: 0.4971 - val_accuracy: 0.4149 - val_loss: 1.3411 - learning_rate: 2.5000e-05
# Epoch 193/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5772 - loss: 0.5022 - val_accuracy: 0.4288 - val_loss: 1.3347 - learning_rate: 2.5000e-05
# Epoch 194/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5816 - loss: 0.5062 - val_accuracy: 0.4230 - val_loss: 1.3513 - learning_rate: 2.5000e-05
# Epoch 195/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5910 - loss: 0.4879 - val_accuracy: 0.4253 - val_loss: 1.3300 - learning_rate: 2.5000e-05
# Epoch 196/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5869 - loss: 0.5064 - val_accuracy: 0.4271 - val_loss: 1.3373 - learning_rate: 2.5000e-05
# Epoch 197/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5814 - loss: 0.4943 - val_accuracy: 0.4242 - val_loss: 1.3470 - learning_rate: 2.5000e-05
# Epoch 198/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5808 - loss: 0.5074 - val_accuracy: 0.4253 - val_loss: 1.3320 - learning_rate: 2.5000e-05
# Epoch 199/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5843 - loss: 0.5172 - val_accuracy: 0.4195 - val_loss: 1.3476 - learning_rate: 2.5000e-05
# Epoch 200/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5985 - loss: 0.4804 - val_accuracy: 0.4172 - val_loss: 1.3562 - learning_rate: 2.5000e-05
# Epoch 201/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5756 - loss: 0.4917 - val_accuracy: 0.4166 - val_loss: 1.3472 - learning_rate: 2.5000e-05
# Epoch 202/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5974 - loss: 0.5014
# Epoch 202: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5973 - loss: 0.5014 - val_accuracy: 0.4195 - val_loss: 1.3497 - learning_rate: 2.5000e-05
# Epoch 203/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5908 - loss: 0.5290 - val_accuracy: 0.4213 - val_loss: 1.3547 - learning_rate: 1.2500e-05
# Epoch 204/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5871 - loss: 0.5070 - val_accuracy: 0.4189 - val_loss: 1.3576 - learning_rate: 1.2500e-05
# Epoch 205/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5680 - loss: 0.4978 - val_accuracy: 0.4248 - val_loss: 1.3499 - learning_rate: 1.2500e-05
# Epoch 206/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5964 - loss: 0.5016 - val_accuracy: 0.4224 - val_loss: 1.3513 - learning_rate: 1.2500e-05
# Epoch 207/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5829 - loss: 0.4891 - val_accuracy: 0.4230 - val_loss: 1.3551 - learning_rate: 1.2500e-05
# Epoch 208/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5894 - loss: 0.4869 - val_accuracy: 0.4218 - val_loss: 1.3534 - learning_rate: 1.2500e-05
# Epoch 209/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5878 - loss: 0.4781 - val_accuracy: 0.4218 - val_loss: 1.3516 - learning_rate: 1.2500e-05
# Epoch 210/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5975 - loss: 0.4761 - val_accuracy: 0.4178 - val_loss: 1.3591 - learning_rate: 1.2500e-05
# Epoch 211/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5887 - loss: 0.4813 - val_accuracy: 0.4166 - val_loss: 1.3617 - learning_rate: 1.2500e-05
# Epoch 212/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5908 - loss: 0.4795 - val_accuracy: 0.4178 - val_loss: 1.3488 - learning_rate: 1.2500e-05
# Epoch 213/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5887 - loss: 0.5001 - val_accuracy: 0.4218 - val_loss: 1.3429 - learning_rate: 1.2500e-05
# Epoch 214/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5851 - loss: 0.4932 - val_accuracy: 0.4195 - val_loss: 1.3546 - learning_rate: 1.2500e-05
# Epoch 215/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5920 - loss: 0.4939 - val_accuracy: 0.4207 - val_loss: 1.3495 - learning_rate: 1.2500e-05
# Epoch 216/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5946 - loss: 0.4745 - val_accuracy: 0.4265 - val_loss: 1.3516 - learning_rate: 1.2500e-05
# Epoch 217/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6038 - loss: 0.4809 - val_accuracy: 0.4230 - val_loss: 1.3550 - learning_rate: 1.2500e-05
# Epoch 218/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5864 - loss: 0.4960 - val_accuracy: 0.4224 - val_loss: 1.3604 - learning_rate: 1.2500e-05
# Epoch 219/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6018 - loss: 0.4847 - val_accuracy: 0.4230 - val_loss: 1.3678 - learning_rate: 1.2500e-05
# Epoch 220/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5793 - loss: 0.4792 - val_accuracy: 0.4282 - val_loss: 1.3551 - learning_rate: 1.2500e-05
# Epoch 221/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5853 - loss: 0.4903 - val_accuracy: 0.4213 - val_loss: 1.3672 - learning_rate: 1.2500e-05
# Epoch 222/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5998 - loss: 0.4994 - val_accuracy: 0.4242 - val_loss: 1.3740 - learning_rate: 1.2500e-05
# Epoch 223/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5881 - loss: 0.4639 - val_accuracy: 0.4300 - val_loss: 1.3645 - learning_rate: 1.2500e-05
# Epoch 224/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5975 - loss: 0.4814 - val_accuracy: 0.4277 - val_loss: 1.3642 - learning_rate: 1.2500e-05
# Epoch 225/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5960 - loss: 0.4954 - val_accuracy: 0.4335 - val_loss: 1.3512 - learning_rate: 1.2500e-05
# Epoch 226/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6017 - loss: 0.4781 - val_accuracy: 0.4265 - val_loss: 1.3646 - learning_rate: 1.2500e-05
# Epoch 227/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5920 - loss: 0.4801 - val_accuracy: 0.4288 - val_loss: 1.3680 - learning_rate: 1.2500e-05
# Epoch 228/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5913 - loss: 0.4934 - val_accuracy: 0.4282 - val_loss: 1.3771 - learning_rate: 1.2500e-05
# Epoch 229/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5984 - loss: 0.4661 - val_accuracy: 0.4277 - val_loss: 1.3757 - learning_rate: 1.2500e-05
# Epoch 230/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5995 - loss: 0.4873 - val_accuracy: 0.4294 - val_loss: 1.3661 - learning_rate: 1.2500e-05
# Epoch 231/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5996 - loss: 0.4806 - val_accuracy: 0.4300 - val_loss: 1.3689 - learning_rate: 1.2500e-05
# Epoch 232/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6036 - loss: 0.5131 - val_accuracy: 0.4248 - val_loss: 1.3804 - learning_rate: 1.2500e-05
# Epoch 233/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5982 - loss: 0.4779 - val_accuracy: 0.4242 - val_loss: 1.3836 - learning_rate: 1.2500e-05
# Epoch 234/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5932 - loss: 0.4807 - val_accuracy: 0.4265 - val_loss: 1.3806 - learning_rate: 1.2500e-05
# Epoch 235/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5910 - loss: 0.4841 - val_accuracy: 0.4271 - val_loss: 1.3719 - learning_rate: 1.2500e-05
# Epoch 236/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5996 - loss: 0.4782 - val_accuracy: 0.4224 - val_loss: 1.3856 - learning_rate: 1.2500e-05
# Epoch 237/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5847 - loss: 0.4969 - val_accuracy: 0.4253 - val_loss: 1.3803 - learning_rate: 1.2500e-05
# Epoch 238/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5952 - loss: 0.4673 - val_accuracy: 0.4253 - val_loss: 1.3729 - learning_rate: 1.2500e-05
# Epoch 239/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5927 - loss: 0.4850 - val_accuracy: 0.4329 - val_loss: 1.3660 - learning_rate: 1.2500e-05
# Epoch 240/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6015 - loss: 0.4866 - val_accuracy: 0.4335 - val_loss: 1.3738 - learning_rate: 1.2500e-05
# Epoch 241/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5862 - loss: 0.4708 - val_accuracy: 0.4277 - val_loss: 1.3791 - learning_rate: 1.2500e-05
# Epoch 242/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5885 - loss: 0.4766 - val_accuracy: 0.4288 - val_loss: 1.3814 - learning_rate: 1.2500e-05
# Epoch 243/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6075 - loss: 0.4555 - val_accuracy: 0.4236 - val_loss: 1.3845 - learning_rate: 1.2500e-05
# Epoch 244/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5871 - loss: 0.4884 - val_accuracy: 0.4277 - val_loss: 1.3832 - learning_rate: 1.2500e-05
# Epoch 245/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5960 - loss: 0.4680 - val_accuracy: 0.4265 - val_loss: 1.3847 - learning_rate: 1.2500e-05
# Epoch 246/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5910 - loss: 0.4886 - val_accuracy: 0.4207 - val_loss: 1.3778 - learning_rate: 1.2500e-05
# Epoch 247/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6093 - loss: 0.4811 - val_accuracy: 0.4265 - val_loss: 1.3798 - learning_rate: 1.2500e-05
# Epoch 248/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5878 - loss: 0.4798 - val_accuracy: 0.4300 - val_loss: 1.3837 - learning_rate: 1.2500e-05
# Epoch 249/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6033 - loss: 0.4820 - val_accuracy: 0.4300 - val_loss: 1.3876 - learning_rate: 1.2500e-05
# Epoch 250/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5938 - loss: 0.4589 - val_accuracy: 0.4253 - val_loss: 1.3926 - learning_rate: 1.2500e-05
# Epoch 251/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5866 - loss: 0.4703 - val_accuracy: 0.4224 - val_loss: 1.3920 - learning_rate: 1.2500e-05
# Epoch 252/500
# 154/172 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5944 - loss: 0.4956
# Epoch 252: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5944 - loss: 0.4934 - val_accuracy: 0.4323 - val_loss: 1.3951 - learning_rate: 1.2500e-05
# Epoch 253/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6011 - loss: 0.4694 - val_accuracy: 0.4329 - val_loss: 1.3919 - learning_rate: 6.2500e-06
# Epoch 254/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5965 - loss: 0.4796 - val_accuracy: 0.4294 - val_loss: 1.3910 - learning_rate: 6.2500e-06
# Epoch 255/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5998 - loss: 0.4748 - val_accuracy: 0.4311 - val_loss: 1.3900 - learning_rate: 6.2500e-06
# Epoch 256/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6122 - loss: 0.4867 - val_accuracy: 0.4271 - val_loss: 1.3930 - learning_rate: 6.2500e-06
# Epoch 257/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6077 - loss: 0.4654 - val_accuracy: 0.4317 - val_loss: 1.3895 - learning_rate: 6.2500e-06
# Epoch 258/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5892 - loss: 0.4682 - val_accuracy: 0.4311 - val_loss: 1.3872 - learning_rate: 6.2500e-06
# Epoch 259/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6018 - loss: 0.4759 - val_accuracy: 0.4300 - val_loss: 1.3892 - learning_rate: 6.2500e-06
# Epoch 260/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6086 - loss: 0.4734 - val_accuracy: 0.4294 - val_loss: 1.3896 - learning_rate: 6.2500e-06
# Epoch 261/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5981 - loss: 0.4595 - val_accuracy: 0.4306 - val_loss: 1.3914 - learning_rate: 6.2500e-06
# Epoch 262/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5896 - loss: 0.4749 - val_accuracy: 0.4300 - val_loss: 1.3998 - learning_rate: 6.2500e-06
# Epoch 263/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5857 - loss: 0.4843 - val_accuracy: 0.4311 - val_loss: 1.3914 - learning_rate: 6.2500e-06
# Epoch 264/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6002 - loss: 0.5059 - val_accuracy: 0.4282 - val_loss: 1.3874 - learning_rate: 6.2500e-06
# Epoch 265/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6106 - loss: 0.4715 - val_accuracy: 0.4294 - val_loss: 1.3873 - learning_rate: 6.2500e-06
# Epoch 266/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6095 - loss: 0.4728 - val_accuracy: 0.4311 - val_loss: 1.3848 - learning_rate: 6.2500e-06
# Epoch 267/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5799 - loss: 0.4864 - val_accuracy: 0.4288 - val_loss: 1.3935 - learning_rate: 6.2500e-06
# Epoch 268/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6082 - loss: 0.4717 - val_accuracy: 0.4306 - val_loss: 1.3913 - learning_rate: 6.2500e-06
# Epoch 269/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6069 - loss: 0.4579 - val_accuracy: 0.4335 - val_loss: 1.3929 - learning_rate: 6.2500e-06
# Epoch 270/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5997 - loss: 0.4697 - val_accuracy: 0.4311 - val_loss: 1.3885 - learning_rate: 6.2500e-06
# Epoch 271/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6024 - loss: 0.4555 - val_accuracy: 0.4352 - val_loss: 1.3829 - learning_rate: 6.2500e-06
# Epoch 272/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6136 - loss: 0.4600 - val_accuracy: 0.4323 - val_loss: 1.3887 - learning_rate: 6.2500e-06
# Epoch 273/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6047 - loss: 0.4803 - val_accuracy: 0.4323 - val_loss: 1.3921 - learning_rate: 6.2500e-06
# Epoch 274/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6000 - loss: 0.4736 - val_accuracy: 0.4323 - val_loss: 1.3933 - learning_rate: 6.2500e-06
# Epoch 275/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5983 - loss: 0.4772 - val_accuracy: 0.4300 - val_loss: 1.3919 - learning_rate: 6.2500e-06
# Epoch 276/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6045 - loss: 0.4585 - val_accuracy: 0.4323 - val_loss: 1.3976 - learning_rate: 6.2500e-06
# Epoch 277/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6086 - loss: 0.4530 - val_accuracy: 0.4317 - val_loss: 1.3971 - learning_rate: 6.2500e-06
# Epoch 278/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6093 - loss: 0.4608 - val_accuracy: 0.4317 - val_loss: 1.4017 - learning_rate: 6.2500e-06
# Epoch 279/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6083 - loss: 0.4598 - val_accuracy: 0.4317 - val_loss: 1.4047 - learning_rate: 6.2500e-06
# Epoch 280/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6174 - loss: 0.4548 - val_accuracy: 0.4317 - val_loss: 1.4020 - learning_rate: 6.2500e-06
# Epoch 281/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5952 - loss: 0.4707 - val_accuracy: 0.4317 - val_loss: 1.4058 - learning_rate: 6.2500e-06
# Epoch 282/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5903 - loss: 0.4835 - val_accuracy: 0.4335 - val_loss: 1.3979 - learning_rate: 6.2500e-06
# Epoch 283/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5991 - loss: 0.4757 - val_accuracy: 0.4317 - val_loss: 1.4005 - learning_rate: 6.2500e-06
# Epoch 284/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5963 - loss: 0.4618 - val_accuracy: 0.4300 - val_loss: 1.3959 - learning_rate: 6.2500e-06
# Epoch 285/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5974 - loss: 0.4717 - val_accuracy: 0.4311 - val_loss: 1.3988 - learning_rate: 6.2500e-06
# Epoch 286/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5859 - loss: 0.4932 - val_accuracy: 0.4248 - val_loss: 1.4087 - learning_rate: 6.2500e-06
# Epoch 287/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6142 - loss: 0.4495 - val_accuracy: 0.4306 - val_loss: 1.4008 - learning_rate: 6.2500e-06
# Epoch 288/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5936 - loss: 0.4611 - val_accuracy: 0.4300 - val_loss: 1.4127 - learning_rate: 6.2500e-06
# Epoch 289/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5936 - loss: 0.4706 - val_accuracy: 0.4288 - val_loss: 1.4153 - learning_rate: 6.2500e-06
# Epoch 290/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6073 - loss: 0.4483 - val_accuracy: 0.4323 - val_loss: 1.4176 - learning_rate: 6.2500e-06
# Epoch 291/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5932 - loss: 0.4807 - val_accuracy: 0.4294 - val_loss: 1.4171 - learning_rate: 6.2500e-06
# Epoch 292/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6019 - loss: 0.4943 - val_accuracy: 0.4294 - val_loss: 1.4187 - learning_rate: 6.2500e-06
# Epoch 293/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5985 - loss: 0.4762 - val_accuracy: 0.4323 - val_loss: 1.4137 - learning_rate: 6.2500e-06
# Epoch 294/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6055 - loss: 0.4666 - val_accuracy: 0.4265 - val_loss: 1.4184 - learning_rate: 6.2500e-06
# Epoch 295/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6031 - loss: 0.4641 - val_accuracy: 0.4300 - val_loss: 1.4147 - learning_rate: 6.2500e-06
# Epoch 296/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6016 - loss: 0.4628 - val_accuracy: 0.4277 - val_loss: 1.4157 - learning_rate: 6.2500e-06
# Epoch 297/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5913 - loss: 0.4760 - val_accuracy: 0.4288 - val_loss: 1.4132 - learning_rate: 6.2500e-06
# Epoch 298/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5985 - loss: 0.4539 - val_accuracy: 0.4300 - val_loss: 1.4135 - learning_rate: 6.2500e-06
# Epoch 299/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6150 - loss: 0.4637 - val_accuracy: 0.4294 - val_loss: 1.4160 - learning_rate: 6.2500e-06
# Epoch 300/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6003 - loss: 0.4729 - val_accuracy: 0.4311 - val_loss: 1.4165 - learning_rate: 6.2500e-06
# Epoch 301/500
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5923 - loss: 0.4698 - val_accuracy: 0.4259 - val_loss: 1.4090 - learning_rate: 6.2500e-06
# Epoch 302/500
# 171/172 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6011 - loss: 0.4627
# Epoch 302: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6011 - loss: 0.4628 - val_accuracy: 0.4282 - val_loss: 1.4169 - learning_rate: 6.2500e-06
# Epoch 302: early stopping
# Restoring model weights from the end of the best epoch: 52.

# %%
# Train Accuracy vs Val Accuracy 
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title(f'Accuracy vs Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Train Loss vs Validation Loss
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title(f'Train Loss vs Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predictions
preds = model.predict(X_test)
final_preds = np.argmax(preds, axis=1)
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_test, final_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.arange(cm.shape[1]), yticklabels=np.arange(cm.shape[0]))
plt.title("Matriz de Confusión")
plt.xlabel("Etiqueta Predicha")
plt.ylabel("Etiqueta Real")
plt.show()

# %%
# Classification report
print(classification_report(y_test, final_preds, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.074     0.154     0.100        13
#            1      0.076     0.256     0.117       121
#            2      0.546     0.437     0.486       887
#            3      0.466     0.382     0.420       701
#
#     accuracy                          0.400      1722
#    macro avg      0.290     0.307     0.281      1722
# weighted avg      0.477     0.400     0.430      1722

# %%
# UAR metric
def uar(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    uar = np.mean(np.diag(cm) / np.sum(cm, axis=1))
    return uar

uar_score = uar(y_test, final_preds)
print(f'UAR: {uar_score:.4f}')
# Out:
# UAR: 0.3074
